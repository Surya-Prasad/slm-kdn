# %% [markdown]
# # Micro-KDN Evaluation Notebook (Colab)
#
# This notebook helps you evaluate model predictions from your implementation using the repository's evaluation logic.
#
# ## Recommended Colab runtime
# - **Runtime type:** Python 3
# - **Hardware accelerator:** **CPU** (recommended for evaluation-only workflows)
# - If you also want to run inference in the same notebook, switch to **T4 GPU**.

# %% [markdown]
# ## 1) Clone (or pull) repo and install dependencies
# Set `REPO_URL` to your fork/repo URL. The cell will clone if missing, otherwise pull latest changes.

# %%
REPO_URL = "https://github.com/Surya-Prasad/slm-kdn.git"
REPO_DIR = "/content/slm-kdn"

from pathlib import Path
import os

if Path(REPO_DIR).exists():
    # %cd $REPO_DIR
    # !git pull
else:
    # !git clone $REPO_URL $REPO_DIR
    # %cd $REPO_DIR

# !python -m pip install --upgrade pip
# !pip install -r requirements.txt
# !pip install matplotlib pandas seaborn
# Out:
# Cloning into '/content/slm-kdn'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 50 (delta 19), reused 48 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 14.38 KiB | 14.38 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
# /content/slm-kdn
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.1.1-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.3 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-26.1.1
# Requirement already satisfied: transformers>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (5.0.0)
# Requirement already satisfied: peft>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.19.1)
# Requirement already satisfied: accelerate>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.13.0)
# Collecting bitsandbytes>=0.43.0 (from -r requirements.txt (line 4))
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: datasets>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: torch>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (2.10.0+cu128)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (1.6.1)
# Requirement already satisfied: nltk>=3.8.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (3.9.1)
# Collecting rouge-score>=0.1.2 (from -r requirements.txt (line 10))
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting psutil>=5.9.8 (from -r requirements.txt (line 11))
#   Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (6.0.3)
# Requirement already satisfied: tqdm>=4.66.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (4.67.3)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0->-r requirements.txt (line 1)) (3.29.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0->-r requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0->-r requirements.txt (line 1)) (26.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0->-r requirements.txt (line 1)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0->-r requirements.txt (line 1)) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0->-r requirements.txt (line 1)) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (0.24.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.2.0->-r requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.19.0->-r requirements.txt (line 5)) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.19.0->-r requirements.txt (line 5)) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.19.0->-r requirements.txt (line 5)) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.19.0->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.19.0->-r requirements.txt (line 5)) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->-r requirements.txt (line 5)) (3.13.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->-r requirements.txt (line 8)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->-r requirements.txt (line 8)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->-r requirements.txt (line 8)) (3.6.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.8.1->-r requirements.txt (line 9)) (8.3.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score>=0.1.2->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score>=0.1.2->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->-r requirements.txt (line 14)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->-r requirements.txt (line 14)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->-r requirements.txt (line 14)) (2026.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->-r requirements.txt (line 5)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->-r requirements.txt (line 5)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->-r requirements.txt (line 5)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->-r requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->-r requirements.txt (line 5)) (1.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.19.0->-r requirements.txt (line 5)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.19.0->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.2.0->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.2.0->-r requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.41.0->-r requirements.txt (line 1)) (0.1.2)
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 113.7 MB/s  0:00:00
# Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (pyproject.toml) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24988 sha256=3f2976b42613daa9709654ee0cb382936e17894b18f9bc34aa3830ce1ba8803e
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# Installing collected packages: psutil, rouge-score, bitsandbytes
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [bitsandbytes]
# Successfully installed bitsandbytes-0.49.2 psutil-7.2.2 rouge-score-0.1.2
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# %%writefile src/load_dataset.py
import argparse, re
from datasets import load_dataset, DatasetDict
from sklearn.model_selection import train_test_split
from utils import ensure_dir, load_config, write_jsonl

def infer_columns(columns):
    lc = {c.lower(): c for c in columns}
    # Included the fix for 'question' and 'answer' mapping!
    intent = next((lc[k] for k in lc if "intent" in k or "query" in k or "question" in k), None)
    cmd = next((lc[k] for k in lc if "command" in k or "config" in k or "label" in k or "answer" in k), None)
    context = next((lc[k] for k in lc if "context" in k or "description" in k or "desc" in k), None)
    return intent, context, cmd

def map_record(row, intent_col, context_col, cmd_col):
    raw_cmd = str(row.get(cmd_col, "")).strip()

    # regex to strip "Use the following command in the [X] mode:"
    clean_cmd = re.sub(r"Use the following command.*?:\s*", "", raw_cmd, flags=re.IGNORECASE | re.DOTALL)
    # Remove any markdown backticks that might be lingering
    clean_cmd = clean_cmd.replace('`', '').strip()

    return {
        "intent": str(row.get(intent_col, "")).strip(),
        "context": str(row.get(context_col, "")).strip() if context_col else "",
        "target_command": clean_cmd,
        "category": str(row.get("category", "")),
    }

def main(args):
    cfg = load_config(args.config)
    ds = load_dataset(cfg["data"]["dataset_name"])
    if not isinstance(ds, DatasetDict):
        ds = DatasetDict({"train": ds})

    sample_split = next(iter(ds.keys()))
    intent_col, context_col, cmd_col = infer_columns(ds[sample_split].column_names)

    mapped = []
    for split_name in ds.keys():
        for row in ds[split_name]:
            mapped.append(map_record(row, intent_col, context_col, cmd_col))

    filtered = [r for r in mapped if r["intent"] and r["target_command"]]
    train_val, test = train_test_split(filtered, test_size=cfg["data"]["test_size"], random_state=cfg["data"]["seed"])
    train, val = train_test_split(train_val, test_size=cfg["data"]["val_size"], random_state=cfg["data"]["seed"])

    out = cfg["data"]["output_dir"]
    ensure_dir(out)
    write_jsonl(f"{out}/train.jsonl", train)
    write_jsonl(f"{out}/val.jsonl", val)
    write_jsonl(f"{out}/test.jsonl", test)

if __name__ == "__main__":
    p = argparse.ArgumentParser()
    p.add_argument("--config", default="config.yaml")
    main(p.parse_args())
# Out:
# Overwriting src/load_dataset.py

# %%
# %%bash
# cd /content/slm-kdn/
#
# # Tell the script to also look for 'question' as the intent column
# sed -i 's/"intent" in k or "query" in k/"intent" in k or "query" in k or "question" in k/g' src/load_dataset.py
#
# # Tell the script to also look for 'answer' as the command column
# sed -i 's/"command" in k or "config" in k or "label" in k/"command" in k or "config" in k or "label" in k or "answer" in k/g' src/load_dataset.py
#
# # Rerun the preprocessing
# ./scripts/run_preprocess.sh

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# # Llama-3-8B pending approval, running with TinyLlama instead

# %%bash
# cd /content/slm-kdn/


# sed -i 's|meta-llama/Meta-Llama-3-8B|TinyLlama/TinyLlama-1.1B-Chat-v1.0|g' config.yaml

# ./scripts/run_train.sh

# %%
# %%bash
# cd /content/slm-kdn/
#
# chmod +x scripts/run_train.sh
# ./scripts/run_train.sh
# Out:
# {'loss': '0.3549', 'grad_norm': '1.107', 'learning_rate': '0.000187', 'epoch': '0.2216'}
# {'loss': '0.1009', 'grad_norm': '0.6595', 'learning_rate': '0.0001725', 'epoch': '0.4432'}
# {'loss': '0.05831', 'grad_norm': '0.704', 'learning_rate': '0.000158', 'epoch': '0.6648'}
# {'loss': '0.0568', 'grad_norm': '0.7071', 'learning_rate': '0.0001435', 'epoch': '0.8864'}
# {'loss': '0.04444', 'grad_norm': '0.1733', 'learning_rate': '0.000129', 'epoch': '1.089'}
# {'loss': '0.06498', 'grad_norm': '0.3107', 'learning_rate': '0.0001145', 'epoch': '1.31'}
# {'loss': '0.03706', 'grad_norm': '0.666', 'learning_rate': '0.0001', 'epoch': '1.532'}
# {'loss': '0.04021', 'grad_norm': '0.302', 'learning_rate': '8.551e-05', 'epoch': '1.753'}
# {'loss': '0.01994', 'grad_norm': '0.04605', 'learning_rate': '7.101e-05', 'epoch': '1.975'}
# {'loss': '0.01752', 'grad_norm': '0.1147', 'learning_rate': '5.652e-05', 'epoch': '2.177'}
# {'loss': '0.02704', 'grad_norm': '0.8935', 'learning_rate': '4.203e-05', 'epoch': '2.399'}
# {'loss': '0.02239', 'grad_norm': '0.3371', 'learning_rate': '2.754e-05', 'epoch': '2.62'}
# {'loss': '0.02478', 'grad_norm': '0.2093', 'learning_rate': '1.304e-05', 'epoch': '2.842'}
# {'train_runtime': '547.8', 'train_samples_per_second': '3.954', 'train_steps_per_second': '0.252', 'train_loss': '0.06446', 'epoch': '3'}
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# Loading weights: 100%|██████████| 291/291 [00:04<00:00, 70.54it/s, Materializing param=model.norm.weight]
# Map: 100%|██████████| 722/722 [00:00<00:00, 1479.32 examples/s]
# 100%|██████████| 138/138 [09:07<00:00,  3.97s/it]

# %%
from google.colab import drive
import shutil

# This will prompt you to authorize Drive access
drive.mount('/content/drive')

# Copy the weights to your Drive
shutil.copytree('/content/slm-kdn/results/lora_adapter', '/content/drive/MyDrive/slm_kdn_adapter', dirs_exist_ok=True)
print("Adapter successfully backed up to Google Drive!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Adapter successfully backed up to Google Drive!

# %%
# The Run-Eval
# !pip install --upgrade torchao
# Out:
# Requirement already satisfied: torchao in /usr/local/lib/python3.12/dist-packages (0.17.0)

# %%
# %%python
# # 1. Fix validate_output.py to allow "show" commands
# with open('src/validate_output.py', 'r') as f:
#     val_code = f.read()
# val_code = val_code.replace("remove|interface", "remove|show|interface")
# with open('src/validate_output.py', 'w') as f:
#     f.write(val_code)
#
# # 2. Fix infer.py to stop chopping off the \ncommit string
# with open('src/infer.py', 'r') as f:
#     inf_code = f.read()
# # Split on double newlines instead of single newlines so \ncommit stays intact
# inf_code = inf_code.replace("split('\\n')[0]", "split('\\n\\n')[0]")
# with open('src/infer.py', 'w') as f:
#     f.write(inf_code)

# %%
# %%writefile src/infer.py
import argparse, json, re, torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
from preprocess import build_prompt
from utils import load_config, read_jsonl, write_jsonl
from tqdm import tqdm

def clean(s):
    # Remove conversational prefixes
    s = re.sub(r'^(Command:|Output:)\s*', '', s.strip(), flags=re.I)

    # CRITICAL FIX: Convert any actual newlines into literal '\n' strings
    # so we can process everything uniformly
    s = s.replace('\n', '\\n')

    # Split by the literal '\n' string
    parts = s.split('\\n')
    if not parts: return ""

    cmd = parts[0].strip()

    # If the model logically output 'commit' as the second command, append it exactly
    # as the ground-truth dataset expects it: with a literal '\n'
    if len(parts) > 1 and parts[1].strip().lower() == 'commit':
        cmd += '\\ncommit'

    return cmd

def main(a):
    c=load_config(a.config); t=c['training']; ic=c['inference']

    tok=AutoTokenizer.from_pretrained(t['base_model'])
    tok.padding_side = 'left'
    if tok.pad_token is None:
        tok.pad_token = tok.eos_token

    base=AutoModelForCausalLM.from_pretrained(t['base_model'],device_map='auto',torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32)
    model=PeftModel.from_pretrained(base, t['output_dir'])
    rows=read_jsonl(a.input_file)
    out=[]

    batch_size = 32
    print(f"\n[INFO] Starting BATCHED inference on {len(rows)} instances for {a.input_file.split('/')[-1]}...")

    for i in tqdm(range(0, len(rows), batch_size), desc="Batches"):
        batch_rows = rows[i:i+batch_size]
        prompts = [build_prompt(r['intent'], r.get('context',''), a.mode) for r in batch_rows]

        inputs = tok(prompts, return_tensors='pt', padding=True).to(model.device)

        with torch.no_grad():
            gens = model.generate(**inputs, max_new_tokens=ic['max_new_tokens'], do_sample=False)

        for j, gen in enumerate(gens):
            text = tok.decode(gen, skip_special_tokens=True)
            pred = clean(text[len(prompts[j]):])
            out.append({**batch_rows[j], 'prediction': pred})

    write_jsonl(a.output_file,out)

if __name__=='__main__':
    p=argparse.ArgumentParser(); p.add_argument('--config',default='config.yaml'); p.add_argument('--input_file',required=True); p.add_argument('--output_file',required=True); p.add_argument('--mode',default='intent_with_context'); main(p.parse_args())
# Out:
# Overwriting src/infer.py

# %%
# %%bash
# cd /content/slm-kdn/

# chmod +x scripts/run_eval.sh
# mkdir -p results/error_analysis
# ./scripts/run_eval.sh

# %%bash
cd /content/slm-kdn/

# Replace the invalid temperature parameters with do_sample=False
sed -i "s/temperature=ic\['temperature'\],top_p=ic\['top_p'\]/do_sample=False/g" src/infer.py

# Run the evaluation again!
./scripts/run_eval.sh
# Out:
# [INFO] Starting BATCHED inference on 150 instances for clean_test.jsonl...
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|██████████| 291/291 [00:04<00:00, 58.83it/s, Materializing param=model.norm.weight]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  20%|██        | 1/5 [00:04<00:17,  4.30s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  40%|████      | 2/5 [00:08<00:11,  3.98s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  60%|██████    | 3/5 [00:11<00:07,  3.88s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  80%|████████  | 4/5 [00:15<00:03,  3.84s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches: 100%|██████████| 5/5 [00:19<00:00,  3.84s/it]

# %%
# %%bash
# cd /content/slm-kdn/
#
# chmod +x scripts/run_robustness.sh
# ./scripts/run_robustness.sh
# Out:
# [INFO] Starting BATCHED inference on 150 instances for clean_test.jsonl...
#
# [INFO] Starting BATCHED inference on 150 instances for paraphrased_test.jsonl...
#
# [INFO] Starting BATCHED inference on 150 instances for noisy_test.jsonl...
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|██████████| 291/291 [00:05<00:00, 55.54it/s, Materializing param=model.norm.weight]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  20%|██        | 1/5 [00:04<00:17,  4.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  40%|████      | 2/5 [00:08<00:12,  4.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  60%|██████    | 3/5 [00:12<00:07,  3.95s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  80%|████████  | 4/5 [00:15<00:03,  3.87s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches: 100%|██████████| 5/5 [00:19<00:00,  3.90s/it]
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|██████████| 291/291 [00:05<00:00, 57.17it/s, Materializing param=model.norm.weight]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  20%|██        | 1/5 [00:04<00:17,  4.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  40%|████      | 2/5 [00:08<00:12,  4.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  60%|██████    | 3/5 [00:12<00:07,  3.97s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  80%|████████  | 4/5 [00:15<00:03,  3.90s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches: 100%|██████████| 5/5 [00:19<00:00,  3.92s/it]
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|██████████| 291/291 [00:05<00:00, 58.09it/s, Materializing param=model.norm.weight]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  20%|██        | 1/5 [00:04<00:17,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  40%|████      | 2/5 [00:08<00:12,  4.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  60%|██████    | 3/5 [00:12<00:07,  3.98s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches:  80%|████████  | 4/5 [00:15<00:03,  3.90s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Batches: 100%|██████████| 5/5 [00:19<00:00,  3.92s/it]

# %% [markdown]
# ## 2) Point to your predictions file
# Your JSONL should contain at least:
# - `intent`
# - `target_command`
# - `prediction`
# - optional: `category`

# %%
from pathlib import Path

PRED_FILE = Path("results/predictions/predictions.jsonl")  # <-- update if needed
assert PRED_FILE.exists(), f"Missing file: {PRED_FILE}"
PRED_FILE
# Out:
# PosixPath('results/predictions/predictions.jsonl')

# %% [markdown]
# ## 3) Run evaluation (same metrics as `src/evaluate.py`)
# Produces:
# - `results/metrics/eval_metrics.json`

# %%
# !python src/evaluate.py --pred_file "$PRED_FILE" --out_dir results/metrics --out_file results/metrics/eval_metrics.json

# %%
import json
from pprint import pprint

with open("results/metrics/eval_metrics.json", "r", encoding="utf-8") as f:
    metrics = json.load(f)

print("Overall metrics")
pprint(metrics["overall"])
# Out:
# Overall metrics
# {'bleu': 0.7077411793432409,
#  'entity_preservation': 0.9933333333333333,
#  'exact_match': 0.013333333333333334,
#  'invalid_output_rate': 0.06666666666666665,
#  'normalized_exact_match': 0.013333333333333334,
#  'token_f1': 0.8471929886999277,
#  'valid_rate': 0.9333333333333333}

# %% [markdown]
# ## 4) Run error analysis
# Produces:
# - `results/error_analysis/error_summary.json`
# - `results/error_analysis/errors.csv`

# %%
# !python src/error_analysis.py   --pred_file "$PRED_FILE"   --out_json results/error_analysis/error_summary.json   --out_csv results/error_analysis/errors.csv

# %%
import json
import pandas as pd

with open("results/error_analysis/error_summary.json", "r", encoding="utf-8") as f:
    err = json.load(f)

err_df = (
    pd.DataFrame(err["counts"].items(), columns=["error_type", "count"])
      .sort_values("count", ascending=False)
)
err_df
# Out:
#                          error_type  count
# 0  semantically_close_but_not_exact    139
# 1                    syntax_invalid     10
# 2                           correct      1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,4))
sns.barplot(data=err_df, x="error_type", y="count")
plt.xticks(rotation=30, ha="right")
plt.title("Error Type Distribution")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5) Inspect failure cases

# %%
errors_csv = "results/error_analysis/errors.csv"
df_err = pd.read_csv(errors_csv)

# Show the most common non-correct errors
df_err[df_err["error_type"] != "correct"].head(20)
# Out:
#                                                intent  \
# 0                       How to display the LED status
# 1   Show sFlow protocol configurations in the oper...
# 2           Set sFlow taceoptions to trace all events
# 3              set a mac moving limit of 2 on vlan HR
# 4   Trace the virtual chassis complete sequence nu...
# 5   put a mac limit of 1 on interface ge-0/0/15 an...
# 6          set the sflow egress sampling rate to 1000
# 7                          Show LCD active menu items
# 8   disable IGMP snooping routing information tace...
# 9   help me configure ntp server on a juniper swit...
# 10  set the SNMP VRRP notifications for the trap-g...
# 11  How to set the RSTP maximum age of received pr...
# 12        Enable sFlow protocol on interface ge-0/0/8
# 13  Notify all logged users when any emergency lev...
# 14   Display IGMP snooping detailed flows information
# 15  Disable IGMPv2 protocol leave group messages t...
# 16  Determine the interface to which the MAC addre...
# 17  set the IGMP protocol expected packet loss on ...
# 18  create SNMP community with the name CAMPUS-COM...
# 19                   how to disable the OSPF protocol
#
#                                        target_command  \
# 0                                    show chassis led
# 1                  show configuration protocols sflow
# 2   set protocols sflow traceoptions flag all\ncommit
# 3   set ethernet-switching-options secure-access-p...
# 4   set virtual-chassis traceoptions flag csn\ncommit
# 5   set ethernet-switching-options secure-access-p...
# 6   set protocols sflow sample-rate egress 1000\nc...
# 7                               show chassis lcd menu
# 8   set protocols igmp-snooping traceoptions flag ...
# 9   set system ntp server <ntp-server-address>\nco...
# 10  set snmp trap-group MONITOR-GROUP categories v...
# 11  set protocols rstp max-age <max-age-interval>\...
# 12    set protocols sflow interfaces ge-0/0/8\ncommit
# 13     set system syslog user * any emergency\ncommit
# 14                    show igmp-snooping flows detail
# 15  set protocols igmp traceoptions flag leave dis...
# 16  show ethernet-switching table | match 00:19:99...
# 17          set protocols igmp robust-count 3\ncommit
# 18  set snmp community CAMPUS-COMMUNITY authorizat...
# 19                 set protocols ospf disable\ncommit
#
#                                            prediction  \
# 0                            show chassis led\ncommit
# 1          show configuration protocols sflow\ncommit
# 2   set protocols sflow traceoptions flag all\ncommit
# 3   set ethernet-switching-options secure-access-p...
# 4   set virtual-chassis traceoptions flag csn\ncommit
# 5   set ethernet-switching-options secure-access-p...
# 6   set protocols sflow sample-rate egress 1000\nc...
# 7                       show chassis lcd menu\ncommit
# 8   set protocols igmp-snooping traceoptions flag ...
# 9   set system ntp server  <ntp-server-address>\nc...
# 10  set snmp trap-group MONITOR-GROUP categories v...
# 11  set protocols rstp max-age <max-age-interval>\...
# 12    set protocols sflow interfaces ge-0/0/8\ncommit
# 13     set system syslog user * any emergency\ncommit
# 14            show igmp-snooping flows detail\ncommit
# 15  set protocols igmp traceoptions flag leave dis...
# 16  show ethernet-switching table | match 00:19:99...
# 17          set protocols igmp robust-count 3\ncommit
# 18  set snmp community CAMPUS-COMMUNITY authorizat...
# 19                 set protocols ospf disable\ncommit
#
#                           error_type
# 0   semantically_close_but_not_exact
# 1   semantically_close_but_not_exact
# 2   semantically_close_but_not_exact
# 3   semantically_close_but_not_exact
# 4   semantically_close_but_not_exact
# 5   semantically_close_but_not_exact
# 6   semantically_close_but_not_exact
# 7   semantically_close_but_not_exact
# 8   semantically_close_but_not_exact
# 9   semantically_close_but_not_exact
# 10  semantically_close_but_not_exact
# 11  semantically_close_but_not_exact
# 12  semantically_close_but_not_exact
# 13  semantically_close_but_not_exact
# 14  semantically_close_but_not_exact
# 15  semantically_close_but_not_exact
# 16  semantically_close_but_not_exact
# 17  semantically_close_but_not_exact
# 18  semantically_close_but_not_exact
# 19  semantically_close_but_not_exact

# %% [markdown]
# ## 6) Optional: per-category leaderboard view

# %%
per_cat = metrics.get("per_category", {})
if per_cat:
    cat_df = pd.DataFrame(per_cat).T.sort_values("normalized_exact_match", ascending=False)
    display(cat_df)
else:
    print("No category field found in predictions.")
# Out:
#   exact_match  normalized_exact_match  token_f1      bleu  valid_rate  \
#      0.013333                0.013333  0.847193  0.707741    0.933333
#
#   entity_preservation  invalid_output_rate
#              0.993333             0.066667

# %%
import pandas as pd

# Load your most recent predictions
df = pd.read_json('/content/slm-kdn/results/predictions/predictions.jsonl', lines=True)

# Function to normalize invisible formatting
def normalize_cmd(cmd):
    if not isinstance(cmd, str): return ""
    # Convert literal '\n' strings into actual newlines
    cmd = cmd.replace('\\n', '\n')
    # Collapse any accidental double spaces into a single space
    cmd = ' '.join(cmd.split())
    return cmd.strip()

# Apply normalization
df['norm_target'] = df['target_command'].apply(normalize_cmd)
df['norm_pred'] = df['prediction'].apply(normalize_cmd)

# Calculate the TRUE Exact Match
exact_matches = (df['norm_target'] == df['norm_pred']).sum()
true_accuracy = exact_matches / len(df)

print(f"=== TRUE NORMALIZED EXACT MATCH ===")
print(f"Accuracy: {true_accuracy * 100:.2f}%\n")

# Let's peek at the real errors (like the 'show' command overfit)
real_errors = df[df['norm_target'] != df['norm_pred']][['intent', 'norm_target', 'norm_pred']]
print(f"Total Actual Errors: {len(real_errors)}")
print("\n=== TOP 5 ACTUAL ERRORS ===")
print(real_errors.head(5).to_string())
# Out:
# === TRUE NORMALIZED EXACT MATCH ===
# Accuracy: 65.33%
#
# Total Actual Errors: 52
#
# === TOP 5 ACTUAL ERRORS ===
#                                                                              intent                                              norm_target                                                              norm_pred
# 0                                                     How to display the LED status                                         show chassis led                                                show chassis led commit
# 1                        Show sFlow protocol configurations in the operational mode                       show configuration protocols sflow                              show configuration protocols sflow commit
# 7                                                        Show LCD active menu items                                    show chassis lcd menu                                           show chassis lcd menu commit
# 14                                 Display IGMP snooping detailed flows information                          show igmp-snooping flows detail                                 show igmp-snooping flows detail commit
# 16  Determine the interface to which the MAC address 00:19:99:93:93:3a is connected  show ethernet-switching table | match 00:19:99:93:93:3a  show ethernet-switching table | match 00:19:99:93:93:3a | ex | commit

# %% [markdown]
# # API verification

# %%
# !pip install -q -U google-genai

# %%
import pandas as pd
import time
import re
from google import genai
from getpass import getpass

# 1. Setup API Client
print("Paste your Gemini API Key:")
api_key = getpass()
client = genai.Client(api_key=api_key)

# 2. Prep Data
def normalize_cmd(cmd):
    if not isinstance(cmd, str): return ""
    return ' '.join(cmd.replace('\\n', '\n').split()).strip()

df = pd.read_json('/content/slm-kdn/results/predictions/predictions.jsonl', lines=True)
df['norm_target'] = df['target_command'].apply(normalize_cmd)
df['norm_pred'] = df['prediction'].apply(normalize_cmd)

# Filter for SLM failures
failed_df = df[df['norm_target'] != df['norm_pred']].copy()
sample_size = min(25, len(failed_df))
test_sample = failed_df.sample(n=sample_size, random_state=42)

print(f"\n[INFO] Testing {sample_size} failures with Rate-Limit Handling...")

results = []
correct_count = 0

# 3. Inference Loop with Automatic Retry
for _, row in test_sample.iterrows():
    prompt = (
        "You are an expert Juniper network engineer. Translate the intent into a raw Juniper CLI command. "
        "Rules: Output ONLY the raw command. If it's a configuration (e.g. 'set'), append '\\ncommit'. "
        "If it's operational (e.g. 'show'), do NOT append a commit.\n\n"
        f"Intent: {row['intent']}"
    )

    while True: # Retry loop for rate limits
        try:
            response = client.models.generate_content(
            model="gemini-2.5-flash",
            contents=prompt
            )

            pred = normalize_cmd(response.text)
            is_match = (pred == row['norm_target'])
            if is_match: correct_count += 1

            results.append({'intent': row['intent'], 'target': row['norm_target'], 'gemini_pred': pred, 'correct': is_match})
            print(f"✓ Processed: {row['intent'][:40]}...")

            # Wait 12 seconds between successful calls (5 per minute)
            time.sleep(12)
            break

        except Exception as e:
            if "429" in str(e):
                print("Rate limit hit! Sleeping for 35 seconds to reset quota...")
                time.sleep(35)
            else:
                print(f"Permanent Error: {e}")
                break

# 4. Final Comparison
print(f"\n=== CLEAN GEMINI BASELINE RESULTS ===")
print(f"Total Tested: {len(results)}")
if len(results) > 0:
    print(f"Accuracy on SLM Failures: {(correct_count/len(results))*100:.2f}%")
else:
    print("No results were processed due to API errors.")
# Out:
# Paste your Gemini API Key:
# ··········
#
# [INFO] Testing 25 failures with Rate-Limit Handling...
# ✓ Processed: Get routing table from local virtual cha...
# ✓ Processed: Disable virtual chassis normal events tr...
# ✓ Processed: Show the virtual chassis routing table...
# ✓ Processed: Show autonomous-system domains...
# ✓ Processed: Halt the system...
# ✓ Processed: Show users who are currently logged in...
# ✓ Processed: configure interface ge-0/0/0 as a part o...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# ✓ Processed: Find the interface to which the MAC addr...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# Rate limit hit! Sleeping for 35 seconds to reset quota...
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_15984/255457741.py in <cell line: 0>()
#      41         try:
# ---> 42             response = client.models.generate_content(
#      43             model="gemini-2.5-flash",
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    6330       i += 1
# -> 6331       response = self._generate_content(
#    6332           model=model, contents=contents, config=parsed_config
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4766
# -> 4767     response = self._api_client.request(
#    4768         'post', path, request_dict, http_options
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1608     )
# -> 1609     response = self._request(http_request, http_options, stream=False)
#    1610     response_body = (
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1401
# -> 1402     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1403
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     469         while True:
# --> 470             do = self.iter(retry_state=retry_state)
#     471             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     370         for action in self.iter_state.actions:
# --> 371             result = action(retry_state)
#     372         return result
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     412                 if self.reraise:
# --> 413                     raise retry_exc.reraise()
#     414                 raise retry_exc from fut.exception()
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     183         if self.last_attempt.failed:
# --> 184             raise self.last_attempt.result()
#     185         raise self
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     472                 try:
# --> 473                     result = fn(*args, **kwargs)
#     474                 except BaseException:  # noqa: B902
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1378       response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1379     errors.APIError.raise_for_response(response)
#    1380     return HttpResponse(
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     154
# --> 155     cls.raise_error(response.status_code, response_json, response)
#     156
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     183     if 400 <= status_code < 500:
# --> 184       raise ClientError(status_code, response_json, response)
#     185     elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 36.516387364s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '36s'}]}}
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15984/255457741.py in <cell line: 0>()
#      59             if "429" in str(e):
#      60                 print("Rate limit hit! Sleeping for 35 seconds to reset quota...")
# ---> 61                 time.sleep(35)
#      62             else:
#      63                 print(f"Permanent Error: {e}")
#
# KeyboardInterrupt:

# %%
from google import genai
client = genai.Client(api_key="YOUR_KEY")
for m in client.models.list():
    print(m.name)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_15984/2510450107.py in <cell line: 0>()
#       1 from google import genai
#       2 client = genai.Client(api_key="YOUR_KEY")
# ----> 3 for m in client.models.list():
#       4     print(m.name)
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in list(self, config)
#    6895         'models',
#    6896         self._list,
# -> 6897         self._list(config=config),
#    6898         config,
#    6899     )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _list(self, config)
#    5630     request_dict = _common.encode_unserializable_types(request_dict)
#    5631
# -> 5632     response = self._api_client.request('get', path, request_dict, http_options)
#    5633
#    5634     response_dict = {} if not response.body else json.loads(response.body)
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1607         http_method, path, request_dict, http_options
#    1608     )
# -> 1609     response = self._request(http_request, http_options, stream=False)
#    1610     response_body = (
#    1611         response.response_stream[0] if response.response_stream else ''
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1400         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1401
# -> 1402     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1403
#    1404   async def _async_request_once(
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     468         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469         while True:
# --> 470             do = self.iter(retry_state=retry_state)
#     471             if isinstance(do, DoAttempt):
#     472                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     369         result = None
#     370         for action in self.iter_state.actions:
# --> 371             result = action(retry_state)
#     372         return result
#     373
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     411                 retry_exc = self.retry_error_cls(fut)
#     412                 if self.reraise:
# --> 413                     raise retry_exc.reraise()
#     414                 raise retry_exc from fut.exception()
#     415
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     182     def reraise(self) -> t.NoReturn:
#     183         if self.last_attempt.failed:
# --> 184             raise self.last_attempt.result()
#     185         raise self
#     186
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     471             if isinstance(do, DoAttempt):
#     472                 try:
# --> 473                     result = fn(*args, **kwargs)
#     474                 except BaseException:  # noqa: B902
#     475                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1377       )
#    1378       response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1379     errors.APIError.raise_for_response(response)
#    1380     return HttpResponse(
#    1381         response.headers, response if stream else [response.text]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     153       response_json = response.body_segments[0].get('error', {})
#     154
# --> 155     cls.raise_error(response.status_code, response_json, response)
#     156
#     157   @classmethod
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     182     """
#     183     if 400 <= status_code < 500:
# --> 184       raise ClientError(status_code, response_json, response)
#     185     elif 500 <= status_code < 600:
#     186       raise ServerError(status_code, response_json, response)
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}

# %%
¸import shutil
from google.colab import files
from datetime import datetime

# Zip the folder
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
shutil.make_archive(f'slm_kdn_backup_{timestamp}', 'zip', '/content/slm-kdn')

# Download it to your computer
files.download(f'slm_kdn_backup_{timestamp}.zip')
