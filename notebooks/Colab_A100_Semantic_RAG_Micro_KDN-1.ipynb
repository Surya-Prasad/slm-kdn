# %% [markdown]
# # SLM-KDN Colab Pro A100: Semantic RAG Micro-KDN
#
# This notebook tests the final architecture:
#
# 1. Fine-tuned Llama-3-8B emits strict semantic JSON only.
# 2. The local command-context/template store retrieves command metadata.
# 3. Python deterministically assembles Junos CLI.
# 4. Guardrails enforce commit and mode validity.
#
# Use the older RAG notebook for the baseline `--use_rag` free-form command path. Use this notebook for the final `--semantic_rag` path.

# %% [markdown]
# ## 1. Check GPU

# %%
# !nvidia-smi
# Out:
# Mon May 11 22:58:35 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             48W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
    print('Capability:', torch.cuda.get_device_capability(0))
# Out:
# CUDA available: True
# GPU: NVIDIA A100-SXM4-40GB
# Capability: (8, 0)

# %% [markdown]
# ## 2. Clone Repo From Master

# %%
# %cd /content
# !rm -rf slm-kdn
# !git clone --branch master https://github.com/Surya-Prasad/slm-kdn.git
# %cd /content/slm-kdn
# !git status --short
# !git rev-parse --abbrev-ref HEAD
# !git log -1 --oneline
# Out:
# /content
# Cloning into 'slm-kdn'...
# remote: Enumerating objects: 222, done.
# remote: Counting objects: 100% (222/222), done.
# remote: Compressing objects: 100% (153/153), done.
# remote: Total 222 (delta 121), reused 139 (delta 64), pack-reused 0 (from 0)
# Receiving objects: 100% (222/222), 2.98 MiB | 18.49 MiB/s, done.
# Resolving deltas: 100% (121/121), done.
# /content/slm-kdn
# master
# afc04f4 (HEAD -> master, origin/master, origin/HEAD) Semantic RAG intermediate form

# %% [markdown]
# ## 3. Install Dependencies

# %%
# !pip install -q -r requirements.txt
# !pip install -q --upgrade transformers peft accelerate bitsandbytes datasets pypdf nltk
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 44.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.8/338.8 kB 35.7 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 110.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 52.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 102.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 57.0 MB/s eta 0:00:00

# %% [markdown]
# ## 4. Hugging Face Login
#
# Run this if your base model or adapter needs gated Hugging Face access.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## 5. Preprocess NIT Dataset
#
# This creates `data/processed/train.jsonl`, `val.jsonl`, `test.jsonl`, and robustness variants when available.

# %%
# !bash scripts/run_preprocess.sh
# !find data/processed -maxdepth 1 -type f -print | sort
# !head -n 1 data/processed/test.jsonl
# Out:
# README.md: 4.31kB [00:00, 7.28MB/s]
# NIT_dataset.json: 273kB [00:00, 132MB/s]
# Generating train split: 100% 1000/1000 [00:00<00:00, 117359.30 examples/s]
# data/processed/clean_test.jsonl
# data/processed/noisy_test.jsonl
# data/processed/paraphrased_test.jsonl
# data/processed/test_intent_only.jsonl
# data/processed/test_intent_with_context.jsonl
# data/processed/test.jsonl
# data/processed/train_intent_only.jsonl
# data/processed/train_intent_with_context.jsonl
# data/processed/train.jsonl
# data/processed/val_intent_only.jsonl
# data/processed/val_intent_with_context.jsonl
# data/processed/val.jsonl
# {"intent": "How to display the LED status", "context": "show chassis led", "target_command": "show chassis led", "target_json": "{\"action\":\"show\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": ""}

# %% [markdown]
# ## 6. Build Command-Context Datastore
#
# This builds `data/juniper_templates.json` from train/val only. It does not use `test.jsonl` unless `--allow-test` is explicitly passed, which you should not use for final evaluation.

# %%
# !python scripts/build_perfect_datastore_v2.py
# !python - <<'PY'
import json
from pathlib import Path
p = Path('data/juniper_templates.json')
payload = json.loads(p.read_text())
print('template_count:', len(payload))
for i, (k, v) in enumerate(payload.items()):
    if i >= 5:
        break
    print(k, '=>', {x: v.get(x) for x in ['template', 'mode', 'requires_commit', 'allowed_params']})
# !wc -l outputs/datastore_conflicts.jsonl || true
# !head -n 5 outputs/datastore_conflicts.jsonl || true
# Out:
# Wrote 194 templates to /content/slm-kdn/data/juniper_templates.json
# Wrote 548 conflicts to /content/slm-kdn/outputs/datastore_conflicts.jsonl
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# template_count: 194
# clear/ethernet-switching/port-error => {'template': 'clear ethernet-switching port-error', 'mode': 'operational', 'requires_commit': False, 'allowed_params': []}
# set/system/ntp => {'template': 'set system ntp server {ip_address} commit comment "configured ntp server"', 'mode': 'configuration', 'requires_commit': True, 'allowed_params': ['ip_address']}
# set/protocols/rstp => {'template': 'set protocols rstp max-age 15', 'mode': 'configuration', 'requires_commit': True, 'allowed_params': []}
# delete/ethernet-switching-options/secure-access-port => {'template': 'delete ethernet-switching-options secure-access-port interface {interface} mac-limit', 'mode': 'configuration', 'requires_commit': True, 'allowed_params': ['interface']}
# set/protocols/sflow => {'template': 'set protocols sflow traceoptions flag interface disable', 'mode': 'configuration', 'requires_commit': True, 'allowed_params': []}
# 548 outputs/datastore_conflicts.jsonl
# {"key": "set/protocols/sflow", "existing": {"action": "set", "domain": "protocols", "sub_domain": "sflow", "template": "set protocols sflow traceoptions flag interface disable", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["Disable sFlow traceoptions for interface events", "set the sflow polling interval to 60", "set the sflow polling interval to 30", "set the sflow ingress sampling rate to 1100", "set the source IP address to be used for the sFlow datagrams to 10.100.1.12", "how to configure the sflow polling interval", "set the sflow ingress sampling rate to 1000", "Set sFlow taceoptions to trace configuration changes", "Set sFlow taceoptions to trace rtsock events", "Set sFlow taceoptions to trace client-server events"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}}, "candidate": {"action": "set", "domain": "protocols", "sub_domain": "sflow", "template": "set protocols sflow polling-interval 60", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}}, "source_file": "data/processed/train.jsonl", "target_command": "set protocols sflow polling-interval 60\ncommit"}
# {"key": "set/interfaces/interface", "existing": {"action": "set", "domain": "interfaces", "sub_domain": "interface", "template": "set interfaces {interface} unit {unit} family ethernet-switching port-mode trunk", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["interface", "unit"], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}}, "candidate": {"action": "set", "domain": "interfaces", "sub_domain": "interface", "template": "set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode access vlan members <vlan-name-or-id>", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}}, "source_file": "data/processed/train.jsonl", "target_command": "set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode access vlan members <vlan-name-or-id>\ncommit"}
# {"key": "set/ethernet-switching-options/secure-access-port", "existing": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "template": "set ethernet-switching-options secure-access-port vlan CAM no-examine-dhcp", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["Disable DHCP snooping on CAM vlan", "how to set a mac limit on an interface and set the action to log on violations", "Disable IP source guard inspection on interface ge-0/0/15", "set a mac limit of 1 on all interfaces", "how to disable DHCP snooping on a vlan", "set a mac limit of 1 on all interfaces and shutdown the interface if a violation occur", "Enable ARP inspection feature on VLAN REG", "Enable DHCP snooping on the vlan with the ID 10", "Do not allow a device to change the port it is connected to more than twice a second", "Limit the number of connected devices to one on each interface on the EX3300 switch"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}}, "candidate": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "template": "set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <limit> action log", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}}, "source_file": "data/processed/train.jsonl", "target_command": "set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <limit> action log\ncommit"}
# {"key": "set/protocols/rstp", "existing": {"action": "set", "domain": "protocols", "sub_domain": "rstp", "template": "set protocols rstp max-age 15", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["Set the RSTP max age of received protocol BPDUs to 15", "set RSTP protocol hello interval to 4 seconds", "Set RSTP taceoptions to  trace port migration state machine", "Set RSTP taceoptions to  trace port role selection state machine", "Set RSTP taceoptions to trace port receive state machine", "Enable RSTP root-protect feature on interface ge-0/0/13", "Set RSTP taceoptions to trace topology change state machine", "Set RSTP taceoptions to trace protocol timers", "Disable RSTP port receive state machine traceoption", "Set RSTP taceoptions to  trace port role transit state machine"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}}, "candidate": {"action": "set", "domain": "protocols", "sub_domain": "rstp", "template": "set protocols rstp hello-time 4", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}}, "source_file": "data/processed/train.jsonl", "target_command": "set protocols rstp hello-time 4\ncommit"}
# {"key": "set/interfaces/interface", "existing": {"action": "set", "domain": "interfaces", "sub_domain": "interface", "template": "set interfaces {interface} unit {unit} family ethernet-switching port-mode trunk", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["interface", "unit"], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}}, "candidate": {"action": "set", "domain": "interfaces", "sub_domain": "interface", "template": "set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode access", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}}, "source_file": "data/processed/train.jsonl", "target_command": "set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode access\ncommit"}

# %% [markdown]
# ## 7. Run Semantic RAG Unit Smoke Tests

# %%
# !pip install --upgrade torchao
# Out:
# Requirement already satisfied: torchao in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Collecting torchao
#   Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 39.9 MB/s eta 0:00:00
# Installing collected packages: torchao
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
# Successfully installed torchao-0.17.0

# %%
# !python tests/test_semantic_rag.py
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# semantic RAG smoke tests passed

# %% [markdown]
# ## 8. Train LoRA Adapter
#
# Run this if your current adapter has not been trained in this runtime. For the semantic architecture, the important thing to inspect is the semantic parser metrics below: if JSON validity is low, the adapter is still behaving like the old command-generation model and needs semantic-JSON supervised examples.

# %%
# !bash scripts/run_train.sh
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# config.json: 100% 654/654 [00:00<00:00, 2.95MB/s]
# tokenizer_config.json: 50.6kB [00:00, 83.8MB/s]
# tokenizer.json: 9.09MB [00:00, 37.5MB/s]
# special_tokens_map.json: 100% 73.0/73.0 [00:00<00:00, 538kB/s]
# model.safetensors.index.json: 23.9kB [00:00, 55.7MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...):  95% 15.3G/16.1G [00:39<00:01, 554MB/s]
# Downloading (incomplete total...): 100% 16.0G/16.1G [00:40<00:00, 589MB/s]
# Fetching 4 files: 100% 4/4 [00:40<00:00, 10.10s/it]
# Download complete: 100% 16.1G/16.1G [00:40<00:00, 397MB/s]
# Loading weights: 100% 291/291 [00:04<00:00, 65.39it/s]
# generation_config.json: 100% 177/177 [00:00<00:00, 1.20MB/s]
# Map: 100% 722/722 [00:00<00:00, 2132.46 examples/s]
# {'loss': '0.3491', 'grad_norm': '0.724', 'learning_rate': '0.000187', 'epoch': '0.2216'}
# {'loss': '0.1041', 'grad_norm': '0.5919', 'learning_rate': '0.0001725', 'epoch': '0.4432'}
# {'loss': '0.06026', 'grad_norm': '1.477', 'learning_rate': '0.000158', 'epoch': '0.6648'}
# {'loss': '0.04241', 'grad_norm': '0.2615', 'learning_rate': '0.0001435', 'epoch': '0.8864'}
# {'loss': '0.03966', 'grad_norm': '0.4893', 'learning_rate': '0.000129', 'epoch': '1.089'}
# {'loss': '0.05848', 'grad_norm': '0.3684', 'learning_rate': '0.0001145', 'epoch': '1.31'}
# {'loss': '0.03863', 'grad_norm': '0.6631', 'learning_rate': '0.0001', 'epoch': '1.532'}
# {'loss': '0.03278', 'grad_norm': '0.2395', 'learning_rate': '8.551e-05', 'epoch': '1.753'}
# {'loss': '0.01616', 'grad_norm': '0.04239', 'learning_rate': '7.101e-05', 'epoch': '1.975'}
# {'loss': '0.01479', 'grad_norm': '0.06468', 'learning_rate': '5.652e-05', 'epoch': '2.177'}
# {'loss': '0.02105', 'grad_norm': '1.297', 'learning_rate': '4.203e-05', 'epoch': '2.399'}
# {'loss': '0.0159', 'grad_norm': '0.3231', 'learning_rate': '2.754e-05', 'epoch': '2.62'}
# {'loss': '0.01879', 'grad_norm': '0.07169', 'learning_rate': '1.304e-05', 'epoch': '2.842'}
# {'train_runtime': '275.8', 'train_samples_per_second': '7.855', 'train_steps_per_second': '0.5', 'train_loss': '0.05951', 'epoch': '3'}
# 100% 138/138 [04:35<00:00,  2.00s/it]

# %% [markdown]
# ## 9. Semantic RAG Smoke Inference
#
# This verifies that `--semantic_rag` writes semantic JSON, command context, assembly errors, commit decisions, and guardrail diagnostics.

# %%
import json, os
os.makedirs('data/processed', exist_ok=True)
rows = [
    {'intent': 'Display chassis LED status', 'context': '', 'target_command': 'show chassis led', 'category': 'semantic_smoke'},
    {'intent': 'Clear all MAC address entries in the ethernet switching table', 'context': '', 'target_command': 'clear ethernet-switching-table', 'category': 'semantic_smoke'},
    {'intent': 'Disable the OSPF protocol', 'context': '', 'target_command': 'set protocols ospf disable\\ncommit', 'category': 'semantic_smoke'},
]
with open('data/processed/semantic_rag_smoke.jsonl', 'w', encoding='utf-8') as f:
    for row in rows:
        f.write(json.dumps(row) + '\n')

# !mkdir -p results/predictions results/metrics results/error_analysis
# !python src/infer.py \
  --input_file data/processed/semantic_rag_smoke.jsonl \
  --output_file results/predictions/semantic_rag_smoke_predictions.jsonl \
  --semantic_rag \
  --mode intent_with_context

# !python scripts/evaluate_semantic_rag.py \
  --pred_file results/predictions/semantic_rag_smoke_predictions.jsonl \
  --out_file results/metrics/semantic_rag_smoke_metrics.json \
  --failures_file results/error_analysis/semantic_rag_smoke_failures.jsonl \
  --summary_file results/error_analysis/semantic_rag_smoke_error_summary.json

# !head -n 3 results/predictions/semantic_rag_smoke_predictions.jsonl
# !cat results/metrics/semantic_rag_smoke_metrics.json
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 60.73it/s]
#
# [INFO] Starting BATCHED inference on 3 instances for semantic_rag_smoke.jsonl...
# Batches:   0% 0/1 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches: 100% 1/1 [00:02<00:00,  2.36s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.6666666666666666,
#     "repaired_parse_rate": 0.3333333333333333,
#     "unrepaired_parse_error_rate": 0.3333333333333333,
#     "action_accuracy": 0.3333333333333333,
#     "domain_accuracy": 0.6666666666666666,
#     "sub_domain_accuracy": 0.3333333333333333,
#     "semantic_frame_exact_match": 0.0,
#     "parameter_precision": 0.3333333333333333,
#     "parameter_recall": 0.3333333333333333,
#     "parameter_f1": 0.3333333333333333,
#     "entity_preservation": 0.6666666666666666,
#     "template_hit_rate": 0.0,
#     "correct_template_rate": 0.0,
#     "template_not_found_rate": 0.6666666666666666,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.0,
#     "missing_parameter_rate": 0.0,
#     "commit_decision_accuracy": 0.6666666666666666,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.3333333333333333,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.0,
#     "normalized_exact_match": 0.0,
#     "token_f1": 0.0,
#     "valid_rate": 0.0,
#     "bleu": 0.0,
#     "invalid_output_rate": 1.0,
#     "failure_stage_counts": {
#       "semantic_parse_error": 1,
#       "template_not_found": 2
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "show/chassis/led": 1,
#       "clear/ethernet-switching/table": 1,
#       "set/protocols/ospf": 1
#     }
#   }
# }
# {"intent": "Display chassis LED status", "context": "", "target_command": "show chassis led", "category": "semantic_smoke", "semantic_json_raw": "{\"action\":\"display chassis led status\", \"domain\": \"monitor\", \"sub_domain\": \"chassis\", \"parameters\": {}}\ncommit", "semantic_json": null, "semantic_parse_warnings": [], "semantic_parse_error": "invalid_enum_action", "command_context": {"found": false, "reason": "semantic_parse_error", "template_key": "", "warnings": [], "mode": "unknown", "requires_commit": false}, "context_warnings": [], "assembly_error": "semantic_parse_error", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": []}
# {"intent": "Clear all MAC address entries in the ethernet switching table", "context": "", "target_command": "clear ethernet-switching-table", "category": "semantic_smoke", "semantic_json_raw": "{\"action\":\"clear ethernet-switching table mac\", \"domain\":\"ethernet-switching\", \"sub_domain\":\"mac\", \"parameters\":{}}\ncommit", "semantic_json": {"action": "clear", "domain": "ethernet-switching", "sub_domain": "mac", "parameters": {}, "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action"]}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action"], "semantic_parse_error": null, "command_context": {"found": false, "reason": "template_not_found", "template_key": "", "action": "clear", "domain": "ethernet-switching", "sub_domain": "mac", "template": "", "mode": "unknown", "requires_commit": false, "default_params": {}, "allowed_params": [], "description": "", "intent_examples": [], "negative_rules": [], "validation_rules": {}, "warnings": []}, "context_warnings": [], "assembly_error": "template_not_found", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": []}
# {"intent": "Disable the OSPF protocol", "context": "", "target_command": "set protocols ospf disable\\ncommit", "category": "semantic_smoke", "semantic_json_raw": "{\"action\":\"commit\", \"domain\":\"protocols\", \"sub_domain\":\"ospf\", \"parameters\": {\"commit\": true}}", "semantic_json": {"action": "commit", "domain": "protocols", "sub_domain": "ospf", "parameters": {"commit": true}}, "semantic_parse_warnings": [], "semantic_parse_error": null, "command_context": {"found": false, "reason": "template_not_found", "template_key": "", "action": "commit", "domain": "protocols", "sub_domain": "ospf", "template": "", "mode": "unknown", "requires_commit": false, "default_params": {}, "allowed_params": [], "description": "", "intent_examples": [], "negative_rules": [], "validation_rules": {}, "warnings": []}, "context_warnings": [], "assembly_error": "template_not_found", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": []}
# {
#   "overall": {
#     "json_valid_rate": 0.6666666666666666,
#     "repaired_parse_rate": 0.3333333333333333,
#     "unrepaired_parse_error_rate": 0.3333333333333333,
#     "action_accuracy": 0.3333333333333333,
#     "domain_accuracy": 0.6666666666666666,
#     "sub_domain_accuracy": 0.3333333333333333,
#     "semantic_frame_exact_match": 0.0,
#     "parameter_precision": 0.3333333333333333,
#     "parameter_recall": 0.3333333333333333,
#     "parameter_f1": 0.3333333333333333,
#     "entity_preservation": 0.6666666666666666,
#     "template_hit_rate": 0.0,
#     "correct_template_rate": 0.0,
#     "template_not_found_rate": 0.6666666666666666,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.0,
#     "missing_parameter_rate": 0.0,
#     "commit_decision_accuracy": 0.6666666666666666,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.3333333333333333,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.0,
#     "normalized_exact_match": 0.0,
#     "token_f1": 0.0,
#     "valid_rate": 0.0,
#     "bleu": 0.0,
#     "invalid_output_rate": 1.0,
#     "failure_stage_counts": {
#       "semantic_parse_error": 1,
#       "template_not_found": 2
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "show/chassis/led": 1,
#       "clear/ethernet-switching/table": 1,
#       "set/protocols/ospf": 1
#     }
#   }
# }

# %% [markdown]
# ## 10. Full Semantic RAG Evaluation
#
# This runs `test.jsonl` plus `clean_test.jsonl`, `paraphrased_test.jsonl`, and `noisy_test.jsonl` if present. Metrics are written under `results/metrics/`; stage failures and summaries are written under `results/error_analysis/`.

# %%
# !scripts/run_semantic_rag_eval.sh
# !cat results/metrics/semantic_rag_metrics.json
# !cat results/error_analysis/semantic_rag_error_summary.json
# !head -n 5 results/error_analysis/semantic_rag_failures.jsonl || true
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 59.78it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:04<00:17,  4.39s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:08<00:12,  4.02s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [00:11<00:07,  3.91s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [00:15<00:03,  3.86s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:19<00:00,  3.87s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.8466666666666667,
#     "repaired_parse_rate": 0.8466666666666667,
#     "unrepaired_parse_error_rate": 0.15333333333333332,
#     "action_accuracy": 0.8466666666666667,
#     "domain_accuracy": 0.4,
#     "sub_domain_accuracy": 0.31333333333333335,
#     "semantic_frame_exact_match": 0.30666666666666664,
#     "parameter_precision": 0.8466666666666667,
#     "parameter_recall": 0.8466666666666667,
#     "parameter_f1": 0.8466666666666667,
#     "entity_preservation": 0.8133333333333334,
#     "template_hit_rate": 0.29333333333333333,
#     "correct_template_rate": 0.28,
#     "template_not_found_rate": 0.5533333333333333,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.2733333333333333,
#     "missing_parameter_rate": 0.02,
#     "commit_decision_accuracy": 0.5,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.5,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.04666666666666667,
#     "normalized_exact_match": 0.04666666666666667,
#     "token_f1": 0.18510172204002687,
#     "valid_rate": 0.04666666666666667,
#     "bleu": 0.11826372176768397,
#     "invalid_output_rate": 0.9533333333333334,
#     "failure_stage_counts": {
#       "ok": 7,
#       "final_command_mismatch": 32,
#       "template_not_found": 83,
#       "semantic_parse_error": 23,
#       "missing_parameter": 3,
#       "wrong_template": 2
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "show/configuration/protocols": 1,
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/protocols/igmp-snooping": 3,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 3,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/lldp/neighbors": 1,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/div-range": 1,
#       "show/dhcp/snooping": 2,
#       "show/ospf/neighbor": 1,
#       "show/system/boot-messages": 1,
#       "delete/system/login": 2,
#       "set/interfaces/interface": 5,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "show/ospf/database": 2,
#       "request/system/software": 2,
#       "run/show/system": 1,
#       "delete/protocols/rstp": 2,
#       "start/shell/sh": 1,
#       "set/interfaces/fin-range": 1,
#       "show/ospf/overview": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/<range-name>": 1,
#       "delete/vlans/it-data": 1,
#       "show/system/software": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "show/virtual-chassis/device-topology": 1,
#       "delete/protocols/sflow": 1,
#       "show/system/login": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "show/lldp/remote-global-statistics": 1,
#       "request/system/halt": 1,
#       "show/virtual-chassis/status": 1,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "show/|/display": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 59.48it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for clean_test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:04<00:17,  4.41s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:08<00:12,  4.18s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [00:12<00:08,  4.08s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [00:16<00:04,  4.00s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:20<00:00,  4.02s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.8466666666666667,
#     "repaired_parse_rate": 0.8466666666666667,
#     "unrepaired_parse_error_rate": 0.15333333333333332,
#     "action_accuracy": 0.8466666666666667,
#     "domain_accuracy": 0.4,
#     "sub_domain_accuracy": 0.31333333333333335,
#     "semantic_frame_exact_match": 0.30666666666666664,
#     "parameter_precision": 0.8466666666666667,
#     "parameter_recall": 0.8466666666666667,
#     "parameter_f1": 0.8466666666666667,
#     "entity_preservation": 0.8133333333333334,
#     "template_hit_rate": 0.29333333333333333,
#     "correct_template_rate": 0.28,
#     "template_not_found_rate": 0.5533333333333333,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.2733333333333333,
#     "missing_parameter_rate": 0.02,
#     "commit_decision_accuracy": 0.5,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.5,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.04666666666666667,
#     "normalized_exact_match": 0.04666666666666667,
#     "token_f1": 0.18510172204002687,
#     "valid_rate": 0.04666666666666667,
#     "bleu": 0.11826372176768397,
#     "invalid_output_rate": 0.9533333333333334,
#     "failure_stage_counts": {
#       "ok": 7,
#       "final_command_mismatch": 32,
#       "template_not_found": 83,
#       "semantic_parse_error": 23,
#       "missing_parameter": 3,
#       "wrong_template": 2
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "show/configuration/protocols": 1,
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/protocols/igmp-snooping": 3,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 3,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/lldp/neighbors": 1,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/div-range": 1,
#       "show/dhcp/snooping": 2,
#       "show/ospf/neighbor": 1,
#       "show/system/boot-messages": 1,
#       "delete/system/login": 2,
#       "set/interfaces/interface": 5,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "show/ospf/database": 2,
#       "request/system/software": 2,
#       "run/show/system": 1,
#       "delete/protocols/rstp": 2,
#       "start/shell/sh": 1,
#       "set/interfaces/fin-range": 1,
#       "show/ospf/overview": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/<range-name>": 1,
#       "delete/vlans/it-data": 1,
#       "show/system/software": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "show/virtual-chassis/device-topology": 1,
#       "delete/protocols/sflow": 1,
#       "show/system/login": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "show/lldp/remote-global-statistics": 1,
#       "request/system/halt": 1,
#       "show/virtual-chassis/status": 1,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "show/|/display": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 60.57it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for paraphrased_test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:04<00:17,  4.37s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:08<00:12,  4.09s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [00:12<00:08,  4.00s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [00:15<00:03,  3.94s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:19<00:00,  3.95s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.8133333333333334,
#     "repaired_parse_rate": 0.8133333333333334,
#     "unrepaired_parse_error_rate": 0.18666666666666668,
#     "action_accuracy": 0.8133333333333334,
#     "domain_accuracy": 0.46,
#     "sub_domain_accuracy": 0.3466666666666667,
#     "semantic_frame_exact_match": 0.3466666666666667,
#     "parameter_precision": 0.8133333333333334,
#     "parameter_recall": 0.8133333333333334,
#     "parameter_f1": 0.8133333333333334,
#     "entity_preservation": 0.8133333333333334,
#     "template_hit_rate": 0.3333333333333333,
#     "correct_template_rate": 0.32,
#     "template_not_found_rate": 0.48,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.31333333333333335,
#     "missing_parameter_rate": 0.02,
#     "commit_decision_accuracy": 0.54,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.46,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.04666666666666667,
#     "normalized_exact_match": 0.04666666666666667,
#     "token_f1": 0.2024403463786512,
#     "valid_rate": 0.04666666666666667,
#     "bleu": 0.12859963690300036,
#     "invalid_output_rate": 0.9533333333333334,
#     "failure_stage_counts": {
#       "ok": 7,
#       "final_command_mismatch": 38,
#       "template_not_found": 72,
#       "semantic_parse_error": 28,
#       "missing_parameter": 3,
#       "wrong_template": 2
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "show/configuration/protocols": 1,
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/protocols/igmp-snooping": 3,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 3,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/lldp/neighbors": 1,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/div-range": 1,
#       "show/dhcp/snooping": 2,
#       "show/ospf/neighbor": 1,
#       "show/system/boot-messages": 1,
#       "delete/system/login": 2,
#       "set/interfaces/interface": 5,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "show/ospf/database": 2,
#       "request/system/software": 2,
#       "run/show/system": 1,
#       "delete/protocols/rstp": 2,
#       "start/shell/sh": 1,
#       "set/interfaces/fin-range": 1,
#       "show/ospf/overview": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/<range-name>": 1,
#       "delete/vlans/it-data": 1,
#       "show/system/software": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "show/virtual-chassis/device-topology": 1,
#       "delete/protocols/sflow": 1,
#       "show/system/login": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "show/lldp/remote-global-statistics": 1,
#       "request/system/halt": 1,
#       "show/virtual-chassis/status": 1,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "show/|/display": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 61.48it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for noisy_test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:04<00:17,  4.47s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:08<00:12,  4.14s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [00:12<00:08,  4.02s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [00:16<00:03,  3.95s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:19<00:00,  3.97s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.8533333333333334,
#     "repaired_parse_rate": 0.8533333333333334,
#     "unrepaired_parse_error_rate": 0.14666666666666667,
#     "action_accuracy": 0.8533333333333334,
#     "domain_accuracy": 0.38666666666666666,
#     "sub_domain_accuracy": 0.3333333333333333,
#     "semantic_frame_exact_match": 0.32,
#     "parameter_precision": 0.8466666666666667,
#     "parameter_recall": 0.8466666666666667,
#     "parameter_f1": 0.8466666666666667,
#     "entity_preservation": 0.8133333333333334,
#     "template_hit_rate": 0.31333333333333335,
#     "correct_template_rate": 0.3,
#     "template_not_found_rate": 0.54,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.29333333333333333,
#     "missing_parameter_rate": 0.02,
#     "commit_decision_accuracy": 0.5266666666666666,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.47333333333333333,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.03333333333333333,
#     "normalized_exact_match": 0.03333333333333333,
#     "token_f1": 0.19463928738411623,
#     "valid_rate": 0.03333333333333333,
#     "bleu": 0.12535055653151977,
#     "invalid_output_rate": 0.9666666666666667,
#     "failure_stage_counts": {
#       "ok": 5,
#       "final_command_mismatch": 37,
#       "template_not_found": 81,
#       "semantic_parse_error": 22,
#       "missing_parameter": 3,
#       "wrong_template": 2
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "show/configuration/protocols": 1,
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/protocols/igmp-snooping": 3,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 3,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/lldp/neighbors": 1,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/div-range": 1,
#       "show/dhcp/snooping": 2,
#       "show/ospf/neighbor": 1,
#       "show/system/boot-messages": 1,
#       "delete/system/login": 2,
#       "set/interfaces/interface": 5,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "show/ospf/database": 2,
#       "request/system/software": 2,
#       "run/show/system": 1,
#       "delete/protocols/rstp": 2,
#       "start/shell/sh": 1,
#       "set/interfaces/fin-range": 1,
#       "show/ospf/overview": 1,
#       "show/ethernet-switching/statistics": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/<range-name>": 1,
#       "delete/vlans/it-data": 1,
#       "show/system/software": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "show/chassis/led": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "show/virtual-chassis/device-topology": 1,
#       "delete/protocols/sflow": 1,
#       "show/system/login": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "show/lldp/remote-global-statistics": 1,
#       "request/system/halt": 1,
#       "show/virtual-chassis/status": 1,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "show/|/display": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }
# {
#   "total": 150,
#   "parse_errors": 23,
#   "template_not_found": 83,
#   "missing_parameters": 3,
#   "guardrail_modifications": 0,
#   "commit_suppressed_for_operational_action": 0,
#   "entity_preservation_failures": 28,
#   "exact_match_failures_by_action_domain_sub_domain": {
#     "show/configuration/protocols": 1,
#     "set/protocols/sflow": 6,
#     "set/ethernet-switching-options/secure-access-port": 11,
#     "set/virtual-chassis/traceoptions": 6,
#     "show/chassis/lcd": 1,
#     "set/protocols/igmp-snooping": 5,
#     "set/system/ntp": 1,
#     "set/snmp/trap-group": 2,
#     "set/protocols/rstp": 13,
#     "set/system/syslog": 7,
#     "show/protocols/igmp-snooping": 3,
#     "set/protocols/igmp": 9,
#     "show/ethernet-switching/table": 3,
#     "set/snmp/community": 2,
#     "set/protocols/ospf": 4,
#     "show/lldp/neighbors": 1,
#     "show/cli/general": 1,
#     "load/factory-default/general": 2,
#     "clear/ethernet-switching/table": 2,
#     "set/virtual-chassis/preprovisioned": 1,
#     "show/poe/telemetries": 1,
#     "delete/system/ntp": 1,
#     "show/chassis/pic-mode": 1,
#     "show/as-path/domain": 1,
#     "set/ethernet-switching-options/mac-table-aging-time": 1,
#     "set/interfaces/div-range": 1,
#     "show/dhcp/snooping": 2,
#     "show/ospf/neighbor": 1,
#     "show/system/boot-messages": 1,
#     "delete/system/login": 2,
#     "set/interfaces/interface": 5,
#     "set/vlans/default": 1,
#     "request/system/power-off": 1,
#     "clear/ethernet-switching/port-error": 2,
#     "set/snmp/contact": 1,
#     "show/ospf/database": 2,
#     "request/system/software": 2,
#     "run/show/system": 1,
#     "delete/protocols/rstp": 2,
#     "start/shell/sh": 1,
#     "set/interfaces/fin-range": 1,
#     "show/ospf/overview": 1,
#     "commit/comment/\"deleted": 1,
#     "set/interfaces/<range-name>": 1,
#     "delete/vlans/it-data": 1,
#     "show/system/software": 1,
#     "set/virtual-chassis/mac-persistence-timer": 1,
#     "delete/snmp/trap-options": 1,
#     "show/configuration/|": 1,
#     "set/poe/interface": 1,
#     "show/virtual-chassis/device-topology": 1,
#     "delete/protocols/sflow": 1,
#     "show/system/login": 1,
#     "set/chassis/auto-image-upgrade": 1,
#     "set/protocols/lldp-med": 1,
#     "show/|/compare": 2,
#     "show/lldp/remote-global-statistics": 1,
#     "request/system/halt": 1,
#     "show/virtual-chassis/status": 1,
#     "set/virtual-chassis/no-auto-conversion": 1,
#     "clear/system/login": 1,
#     "delete/snmp/filter-duplicates": 1,
#     "set/ethernet-switching-options/storm-control": 1,
#     "show/virtual-chassis/protocol": 1,
#     "show/|/display": 1,
#     "clear/ethernet-switching/bpdu-error": 1,
#     "delete/virtual-chassis/fast-failover": 1,
#     "set/ethernet-switching-options/bpdu-block": 1,
#     "delete/snmp/trap-group": 1,
#     "set/virtual-chassis/fast-failover": 1,
#     "set/ethernet-switching-options/voip": 1
#   }
# }
# {
#   "overall": {
#     "json_valid_rate": 0.8466666666666667,
#     "repaired_parse_rate": 0.8466666666666667,
#     "unrepaired_parse_error_rate": 0.15333333333333332,
#     "action_accuracy": 0.8466666666666667,
#     "domain_accuracy": 0.4,
#     "sub_domain_accuracy": 0.31333333333333335,
#     "semantic_frame_exact_match": 0.30666666666666664,
#     "parameter_precision": 0.8466666666666667,
#     "parameter_recall": 0.8466666666666667,
#     "parameter_f1": 0.8466666666666667,
#     "entity_preservation": 0.8133333333333334,
#     "template_hit_rate": 0.29333333333333333,
#     "correct_template_rate": 0.28,
#     "template_not_found_rate": 0.5533333333333333,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.2733333333333333,
#     "missing_parameter_rate": 0.02,
#     "commit_decision_accuracy": 0.5,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.5,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.04666666666666667,
#     "normalized_exact_match": 0.04666666666666667,
#     "token_f1": 0.18510172204002687,
#     "valid_rate": 0.04666666666666667,
#     "bleu": 0.11826372176768397,
#     "invalid_output_rate": 0.9533333333333334,
#     "failure_stage_counts": {
#       "ok": 7,
#       "final_command_mismatch": 32,
#       "template_not_found": 83,
#       "semantic_parse_error": 23,
#       "missing_parameter": 3,
#       "wrong_template": 2
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "show/configuration/protocols": 1,
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/protocols/igmp-snooping": 3,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 3,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/lldp/neighbors": 1,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/div-range": 1,
#       "show/dhcp/snooping": 2,
#       "show/ospf/neighbor": 1,
#       "show/system/boot-messages": 1,
#       "delete/system/login": 2,
#       "set/interfaces/interface": 5,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "show/ospf/database": 2,
#       "request/system/software": 2,
#       "run/show/system": 1,
#       "delete/protocols/rstp": 2,
#       "start/shell/sh": 1,
#       "set/interfaces/fin-range": 1,
#       "show/ospf/overview": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/<range-name>": 1,
#       "delete/vlans/it-data": 1,
#       "show/system/software": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "show/virtual-chassis/device-topology": 1,
#       "delete/protocols/sflow": 1,
#       "show/system/login": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "show/lldp/remote-global-statistics": 1,
#       "request/system/halt": 1,
#       "show/virtual-chassis/status": 1,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "show/|/display": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }{
#   "total": 150,
#   "parse_errors": 23,
#   "template_not_found": 83,
#   "missing_parameters": 3,
#   "guardrail_modifications": 0,
#   "commit_suppressed_for_operational_action": 0,
#   "entity_preservation_failures": 28,
#   "exact_match_failures_by_action_domain_sub_domain": {
#     "show/configuration/protocols": 1,
#     "set/protocols/sflow": 6,
#     "set/ethernet-switching-options/secure-access-port": 11,
#     "set/virtual-chassis/traceoptions": 6,
#     "show/chassis/lcd": 1,
#     "set/protocols/igmp-snooping": 5,
#     "set/system/ntp": 1,
#     "set/snmp/trap-group": 2,
#     "set/protocols/rstp": 13,
#     "set/system/syslog": 7,
#     "show/protocols/igmp-snooping": 3,
#     "set/protocols/igmp": 9,
#     "show/ethernet-switching/table": 3,
#     "set/snmp/community": 2,
#     "set/protocols/ospf": 4,
#     "show/lldp/neighbors": 1,
#     "show/cli/general": 1,
#     "load/factory-default/general": 2,
#     "clear/ethernet-switching/table": 2,
#     "set/virtual-chassis/preprovisioned": 1,
#     "show/poe/telemetries": 1,
#     "delete/system/ntp": 1,
#     "show/chassis/pic-mode": 1,
#     "show/as-path/domain": 1,
#     "set/ethernet-switching-options/mac-table-aging-time": 1,
#     "set/interfaces/div-range": 1,
#     "show/dhcp/snooping": 2,
#     "show/ospf/neighbor": 1,
#     "show/system/boot-messages": 1,
#     "delete/system/login": 2,
#     "set/interfaces/interface": 5,
#     "set/vlans/default": 1,
#     "request/system/power-off": 1,
#     "clear/ethernet-switching/port-error": 2,
#     "set/snmp/contact": 1,
#     "show/ospf/database": 2,
#     "request/system/software": 2,
#     "run/show/system": 1,
#     "delete/protocols/rstp": 2,
#     "start/shell/sh": 1,
#     "set/interfaces/fin-range": 1,
#     "show/ospf/overview": 1,
#     "commit/comment/\"deleted": 1,
#     "set/interfaces/<range-name>": 1,
#     "delete/vlans/it-data": 1,
#     "show/system/software": 1,
#     "set/virtual-chassis/mac-persistence-timer": 1,
#     "delete/snmp/trap-options": 1,
#     "show/configuration/|": 1,
#     "set/poe/interface": 1,
#     "show/virtual-chassis/device-topology": 1,
#     "delete/protocols/sflow": 1,
#     "show/system/login": 1,
#     "set/chassis/auto-image-upgrade": 1,
#     "set/protocols/lldp-med": 1,
#     "show/|/compare": 2,
#     "show/lldp/remote-global-statistics": 1,
#     "request/system/halt": 1,
#     "show/virtual-chassis/status": 1,
#     "set/virtual-chassis/no-auto-conversion": 1,
#     "clear/system/login": 1,
#     "delete/snmp/filter-duplicates": 1,
#     "set/ethernet-switching-options/storm-control": 1,
#     "show/virtual-chassis/protocol": 1,
#     "show/|/display": 1,
#     "clear/ethernet-switching/bpdu-error": 1,
#     "delete/virtual-chassis/fast-failover": 1,
#     "set/ethernet-switching-options/bpdu-block": 1,
#     "delete/snmp/trap-group": 1,
#     "set/virtual-chassis/fast-failover": 1,
#     "set/ethernet-switching-options/voip": 1
#   }
# }{"intent": "Show sFlow protocol configurations in the operational mode", "context": "show configuration protocols sflow", "target_command": "show configuration protocols sflow", "target_json": "{\"action\":\"show\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": "", "semantic_json_raw": "{\"action\":\"show configuration protocols sflow\", \"domain\":\"configuration\", \"sub_domain\":\"protocols\", \"parameters\":{}}\ncommit", "semantic_json": {"action": "show", "domain": "configuration", "sub_domain": "protocols", "parameters": {}, "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action"]}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action"], "semantic_parse_error": null, "command_context": {"action": "show", "domain": "configuration", "sub_domain": "protocols", "template": "show configuration protocols sflow | display set", "mode": "operational", "requires_commit": false, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["show sflow configurations in the set format from the operational mode", "Display RSTP protocol configurations from the operational mode", "how to show RSTP protocol configurations from the operational mode", "Show sFlow protocol configurations in the operational mode in the set format", "show sflow configurations from the operational mode", "Show the current RSTP configuration", "Display RSTP protocol configurations in the operational mode in the set format"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "show", "mode": "operational"}, "found": true, "reason": "", "template_key": "show/configuration/protocols", "warnings": []}, "context_warnings": [], "assembly_error": null, "prediction": "show configuration protocols sflow | display set", "template_key": "show/configuration/protocols", "commit_added": false, "guardrails_applied": [], "failure_stage": "final_command_mismatch", "expected_template_key": "show/configuration/protocols"}
# {"intent": "Set sFlow taceoptions to trace all events", "context": "set protocols sflow traceoptions flag all", "target_command": "set protocols sflow traceoptions flag all\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": "", "semantic_json_raw": "{\"action\":\"set protocols sflow traceoptions flag all\", \"domain\":\"set\", \"sub_domain\":\"protocols sflow traceoptions flag all\", \"parameters\":{}}\ncommit", "semantic_json": {"action": "set", "domain": "set", "sub_domain": "protocols sflow traceoptions flag all", "parameters": {"flag": "all"}, "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action"]}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action"], "semantic_parse_error": null, "command_context": {"found": false, "reason": "template_not_found", "template_key": "", "action": "set", "domain": "set", "sub_domain": "protocols sflow traceoptions flag all", "template": "", "mode": "unknown", "requires_commit": false, "default_params": {}, "allowed_params": [], "description": "", "intent_examples": [], "negative_rules": [], "validation_rules": {}, "warnings": []}, "context_warnings": [], "assembly_error": "template_not_found", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": [], "failure_stage": "template_not_found", "expected_template_key": "set/protocols/sflow"}
# {"intent": "set a mac moving limit of 2 on vlan HR", "context": "set ethernet-switching-options secure-access-port vlan <vlan-id-or-name> mac-move-limit <limit>", "target_command": "set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"vlan\"}", "category": "", "semantic_json_raw": "{\"action\": \"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"domain\": \"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"sub_domain\": \"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"parameters\":", "semantic_json": null, "semantic_parse_warnings": [], "semantic_parse_error": "no_json_object_found", "command_context": {"found": false, "reason": "semantic_parse_error", "template_key": "", "warnings": [], "mode": "unknown", "requires_commit": false}, "context_warnings": [], "assembly_error": "semantic_parse_error", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": [], "failure_stage": "semantic_parse_error", "expected_template_key": "set/ethernet-switching-options/secure-access-port"}
# {"intent": "Trace the virtual chassis complete sequence number (CSN) packets", "context": "set virtual-chassis traceoptions flag csn", "target_command": "set virtual-chassis traceoptions flag csn\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": "", "semantic_json_raw": "{\"action\":\"set virtual-chassis traceoptions flag csn\", \"domain\":\"set\", \"sub_domain\":\"virtual-chassis traceoptions flag csn\", \"parameters\":{}}\ncommit", "semantic_json": {"action": "set", "domain": "set", "sub_domain": "virtual-chassis traceoptions flag csn", "parameters": {"flag": "csn"}, "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action"]}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action"], "semantic_parse_error": null, "command_context": {"found": false, "reason": "template_not_found", "template_key": "", "action": "set", "domain": "set", "sub_domain": "virtual-chassis traceoptions flag csn", "template": "", "mode": "unknown", "requires_commit": false, "default_params": {}, "allowed_params": [], "description": "", "intent_examples": [], "negative_rules": [], "validation_rules": {}, "warnings": []}, "context_warnings": [], "assembly_error": "template_not_found", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": [], "failure_stage": "template_not_found", "expected_template_key": "set/virtual-chassis/traceoptions"}
# {"intent": "put a mac limit of 1 on interface ge-0/0/15 and log the event when the mac limit is exceeded", "context": "set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <limit> action log", "target_command": "set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": "", "semantic_json_raw": "{\"action\": \"set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\", \"domain\": \"set\", \"sub_domain\": \"ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\", \"parameters\":", "semantic_json": null, "semantic_parse_warnings": [], "semantic_parse_error": "no_json_object_found", "command_context": {"found": false, "reason": "semantic_parse_error", "template_key": "", "warnings": [], "mode": "unknown", "requires_commit": false}, "context_warnings": [], "assembly_error": "semantic_parse_error", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": [], "failure_stage": "semantic_parse_error", "expected_template_key": "set/ethernet-switching-options/secure-access-port"}

# %% [markdown]
# ## 11. Compare Against Legacy RAG Baseline Optional
#
# Use this only for comparison. The final architecture is `--semantic_rag` above.

# %%
# !python src/infer.py \
  --input_file data/processed/test.jsonl \
  --output_file results/predictions/rag_predictions_baseline.jsonl \
  --use_rag \
  --rag-corpus train,rag_docs
# !python src/evaluate.py \
  --pred_file results/predictions/rag_predictions_baseline.jsonl \
  --out_file results/metrics/rag_baseline_eval_metrics.json
# !cat results/metrics/rag_baseline_eval_metrics.json
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [RAG] Building index from:
# [RAG]   include data/processed/train.jsonl
# [RAG]   include rag-doc/ex3300.pdf
# [RAG]   exclude data/processed/val.jsonl
# [RAG]   exclude data/processed/test.jsonl
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 59.04it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:23<01:35, 23.84s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:46<01:09, 23.04s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [01:14<00:50, 25.29s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [01:33<00:22, 22.99s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [01:47<00:00, 21.58s/it]
# [EVAL] exact_match_accuracy: 0.2000 (30/150)
# [RAG] retrieved chunk counts:
# [RAG]   ex3300.pdf: 22
# [RAG]   train.jsonl: 728
# [RAG] top-1 source distribution:
# [RAG]   ex3300.pdf: 2
# [RAG]   train.jsonl: 148
# [RAG] top-5 source distribution:
# [RAG]   ex3300.pdf: 22
# [RAG]   train.jsonl: 728
# [RAG] wrote failure analysis to outputs/rag_failures_strict.jsonl
# {
#   "overall": {
#     "exact_match": 0.2,
#     "normalized_exact_match": 0.66,
#     "token_f1": 0.8914521268938137,
#     "bleu": 0.7751241938740012,
#     "valid_rate": 0.2,
#     "entity_preservation": 0.9866666666666667,
#     "invalid_output_rate": 0.8
#   },
#   "per_category": {
#     "": {
#       "exact_match": 0.2,
#       "normalized_exact_match": 0.66,
#       "token_f1": 0.8914521268938137,
#       "bleu": 0.7751241938740012,
#       "valid_rate": 0.2,
#       "entity_preservation": 0.9866666666666667,
#       "invalid_output_rate": 0.8
#     }
#   }
# }

# %% [markdown]
# ## 12. Save Results To Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/slm-kdn-results
# !cp -r results /content/drive/MyDrive/slm-kdn-results/semantic-rag-results-$(date +%Y%m%d-%H%M%S)
# !cp data/juniper_templates.json /content/drive/MyDrive/slm-kdn-results/juniper_templates-$(date +%Y%m%d-%H%M%S).json
# !ls -lh /content/drive/MyDrive/slm-kdn-results
# Out:
# Mounted at /content/drive
# total 342K
# -rw------- 1 root root 155K May 11 22:48 juniper_templates-20260511-224857.json
# -rw------- 1 root root 155K May 11 23:13 juniper_templates-20260511-231309.json
# drwx------ 2 root root 4.0K May 11 18:43 results-rag-20260511-184340
# drwx------ 2 root root 4.0K May 11 19:17 results-rag-20260511-191756
# drwx------ 2 root root 4.0K May 11 19:43 results-rag-20260511-194342
# drwx------ 2 root root 4.0K May 11 20:17 results-rag-20260511-201701
# drwx------ 2 root root 4.0K May 11 20:57 results-rag-20260511-205733
# drwx------ 2 root root 4.0K May 11 21:11 results-rag-20260511-211105
# drwx------ 2 root root 4.0K May 11 22:48 semantic-rag-results-20260511-224855
# drwx------ 6 root root 4.0K May 11 23:13 semantic-rag-results-20260511-231307

# %%
# !head -n 5 results/predictions/semantic_rag_predictions.jsonl | jq '.semantic_json_raw'
# Out:
# "{\"action\":\"show chassis led\", \"domain\":\"chassis\", \"sub_domain\":\"led\", \"parameters\":{}}\ncommit"
# "{\"action\":\"show configuration protocols sflow\", \"domain\":\"configuration\", \"sub_domain\":\"protocols\", \"parameters\":{}}\ncommit"
# "{\"action\":\"set protocols sflow traceoptions flag all\", \"domain\":\"set\", \"sub_domain\":\"protocols sflow traceoptions flag all\", \"parameters\":{}}\ncommit"
# "{\"action\": \"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"domain\": \"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"sub_domain\": \"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"parameters\":"
# "{\"action\":\"set virtual-chassis traceoptions flag csn\", \"domain\":\"set\", \"sub_domain\":\"virtual-chassis traceoptions flag csn\", \"parameters\":{}}\ncommit"
