# %% [markdown]
# # SLM-KDN Colab Pro A100: Semantic RAG Micro-KDN
#
# This notebook tests the final architecture:
#
# 1. Fine-tuned Llama-3-8B emits strict semantic JSON only.
# 2. The local command-context/template store retrieves command metadata.
# 3. Python deterministically assembles Junos CLI.
# 4. Guardrails enforce commit and mode validity.
#
# Use the older RAG notebook for the baseline `--use_rag` free-form command path. Use this notebook for the final `--semantic_rag` path.

# %% [markdown]
# ## 1. Check GPU

# %%
# !nvidia-smi
# Out:
# Tue May 12 00:04:13 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0             47W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
    print('Capability:', torch.cuda.get_device_capability(0))
# Out:
# CUDA available: True
# GPU: NVIDIA A100-SXM4-40GB
# Capability: (8, 0)

# %% [markdown]
# ## 2. Clone Repo From Master

# %%
# %cd /content
# !rm -rf slm-kdn
# !git clone --branch master https://github.com/Surya-Prasad/slm-kdn.git
# %cd /content/slm-kdn
# !git status --short
# !git rev-parse --abbrev-ref HEAD
# !git log -1 --oneline
# Out:
# /content
# Cloning into 'slm-kdn'...
# remote: Enumerating objects: 257, done.
# remote: Counting objects: 100% (257/257), done.
# remote: Compressing objects: 100% (179/179), done.
# remote: Total 257 (delta 149), reused 152 (delta 70), pack-reused 0 (from 0)
# Receiving objects: 100% (257/257), 2.99 MiB | 43.14 MiB/s, done.
# Resolving deltas: 100% (149/149), done.
# /content/slm-kdn
# master
# ab4b151 (HEAD -> master, origin/master, origin/HEAD) Finetuning

# %% [markdown]
# ## 3. Install Dependencies

# %%
# !pip install -q -r requirements.txt
# !pip install -q --upgrade transformers peft accelerate bitsandbytes datasets pypdf nltk
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 45.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.8/338.8 kB 35.1 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 161.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 46.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 92.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 56.6 MB/s eta 0:00:00

# %% [markdown]
# ## 4. Hugging Face Login
#
# Run this if your base model or adapter needs gated Hugging Face access.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## 5. Preprocess NIT Dataset
#
# This creates `data/processed/train.jsonl`, `val.jsonl`, `test.jsonl`, and robustness variants when available.

# %%
# !bash scripts/run_preprocess.sh
# !find data/processed -maxdepth 1 -type f -print | sort
# !head -n 1 data/processed/test.jsonl
# Out:
# README.md: 4.31kB [00:00, 6.57MB/s]
# NIT_dataset.json: 273kB [00:00, 174MB/s]
# Generating train split: 100% 1000/1000 [00:00<00:00, 115835.95 examples/s]
# data/processed/clean_test.jsonl
# data/processed/noisy_test.jsonl
# data/processed/paraphrased_test.jsonl
# data/processed/test_intent_only.jsonl
# data/processed/test_intent_with_context.jsonl
# data/processed/test.jsonl
# data/processed/train_intent_only.jsonl
# data/processed/train_intent_with_context.jsonl
# data/processed/train.jsonl
# data/processed/val_intent_only.jsonl
# data/processed/val_intent_with_context.jsonl
# data/processed/val.jsonl
# {"intent": "How to display the LED status", "context": "show chassis led", "target_command": "show chassis led", "target_json": "{\"action\":\"show\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": ""}

# %% [markdown]
# ## 6. Build Command-Context Datastore
#
# This builds `data/juniper_templates.json` from train/val only. It does not use `test.jsonl` unless `--allow-test` is explicitly passed, which you should not use for final evaluation.

# %%
# !python scripts/build_perfect_datastore_v2.py
# !python - <<'PY'
import json
from pathlib import Path
p = Path('data/juniper_templates.json')
payload = json.loads(p.read_text())
print('template_count:', len(payload))
for i, (k, v) in enumerate(payload.items()):
    if i >= 5:
        break
    print(k, '=>', {x: v.get(x) for x in ['template', 'mode', 'requires_commit', 'allowed_params']})
# !wc -l outputs/datastore_conflicts.jsonl || true
# !head -n 5 outputs/datastore_conflicts.jsonl || true
# Out:
# Wrote 244 templates to /content/slm-kdn/data/juniper_templates.json
# Wrote 384 conflicts to /content/slm-kdn/outputs/datastore_conflicts.jsonl
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# template_count: 244
# clear/ethernet-switching/port-error/clear_ethernet_switching_port_error/plain => {'template': 'clear ethernet-switching port-error', 'mode': 'operational', 'requires_commit': False, 'allowed_params': []}
# set/system/ntp/set_system_ntp/plain => {'template': 'set system ntp server {ip_address} commit comment "configured ntp server"', 'mode': 'configuration', 'requires_commit': True, 'allowed_params': ['description', 'ip_address']}
# set/protocols/rstp/set_protocols_rstp/plain => {'template': 'set protocols rstp max-age 15', 'mode': 'configuration', 'requires_commit': True, 'allowed_params': []}
# delete/ethernet-switching-options/secure-access-port/delete_ethernet_switching_options_secure_access_port/plain => {'template': 'delete ethernet-switching-options secure-access-port interface {interface} mac-limit', 'mode': 'configuration', 'requires_commit': True, 'allowed_params': ['interface']}
# set/protocols/sflow/traceoptions_flag_disable/plain => {'template': 'set protocols sflow traceoptions flag {flag} disable', 'mode': 'configuration', 'requires_commit': True, 'allowed_params': ['flag']}
# 384 outputs/datastore_conflicts.jsonl
# {"key": "set/protocols/rstp", "variant": "plain", "existing": {"action": "set", "domain": "protocols", "sub_domain": "rstp", "template": "set protocols rstp max-age 15", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "required_params": [], "forbidden_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["Set the RSTP max age of received protocol BPDUs to 15", "set RSTP protocol hello interval to 4 seconds", "Enable RSTP root-protect feature on interface ge-0/0/13", "set RSTP protocol hello interval to 5 seconds", "How to set the RSTP interface mode to point to point", "set the RSTP root-protect feature on interface ge-0/0/23", "how to set the RSTP root-protect feature on interface", "how to set RSTP particpating interface in the mode shared", "We will connect a new switch on port ge-0/0/7 configure rstp on this interface as a point to point", "how to set the RSTP bridge port delay during the listening and learning states"], "operation": "set_protocols_rstp", "positive_cues": ["set protocols rstp"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "candidate": {"action": "set", "domain": "protocols", "sub_domain": "rstp", "template": "set protocols rstp hello-time 4", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "required_params": [], "forbidden_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "operation": "set_protocols_rstp", "positive_cues": ["set protocols rstp"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "source_file": "data/processed/train.jsonl", "target_command": "set protocols rstp hello-time 4\ncommit"}
# {"key": "set/interfaces/<interface-name>", "variant": "plain", "existing": {"action": "set", "domain": "interfaces", "sub_domain": "<interface-name>", "template": "set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode access vlan {vlan_name} <vlan-name-or-id>", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["vlan_name"], "required_params": ["interface", "unit", "vlan_id_or_name", "vlan_name"], "forbidden_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["how to assign an interface to a vlan", "How to make an interface an access port", "how to allow an interface to carry traffic from multiple vlans", "how to set IP address to an interface in Juniper ex3300", "How to make an interface carry traffic from all vlans"], "operation": "set_interfaces_<interface_name>", "positive_cues": ["set interfaces <interface name>"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "candidate": {"action": "set", "domain": "interfaces", "sub_domain": "<interface-name>", "template": "set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode access", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "required_params": ["interface", "unit"], "forbidden_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "operation": "set_interfaces_<interface_name>", "positive_cues": ["set interfaces <interface name>"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "source_file": "data/processed/train.jsonl", "target_command": "set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode access\ncommit"}
# {"key": "set/protocols/sflow", "variant": "plain", "existing": {"action": "set", "domain": "protocols", "sub_domain": "sflow", "template": "set protocols sflow polling-interval 60", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["interval"], "required_params": [], "forbidden_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["set the sflow polling interval to 60", "set the sflow polling interval to 30", "how to configure the sflow polling interval"], "operation": "polling_interval", "positive_cues": ["polling interval", "polling-interval"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "candidate": {"action": "set", "domain": "protocols", "sub_domain": "sflow", "template": "set protocols sflow polling-interval 30", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["interval"], "required_params": [], "forbidden_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "operation": "polling_interval", "positive_cues": ["polling interval", "polling-interval"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "source_file": "data/processed/train.jsonl", "target_command": "set protocols sflow polling-interval 30\ncommit"}
# {"key": "set/system/syslog", "variant": "plain", "existing": {"action": "set", "domain": "system", "sub_domain": "syslog", "template": "set system syslog archive world-readable", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "required_params": [], "forbidden_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "operation": "set_system_syslog", "positive_cues": ["set system syslog"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "candidate": {"action": "set", "domain": "system", "sub_domain": "syslog", "template": "set system syslog user {user} ntp any", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["user", "username"], "required_params": ["user"], "forbidden_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "operation": "set_system_syslog", "positive_cues": ["set system syslog"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "source_file": "data/processed/train.jsonl", "target_command": "set system syslog user Sami ntp any\ncommit"}
# {"key": "set/ethernet-switching-options/secure-access-port", "variant": "plain", "existing": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "template": "set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <limit> action log", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "required_params": ["interface", "limit"], "forbidden_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["how to set a mac limit on an interface and set the action to log on violations", "Disable IP source guard inspection on interface ge-0/0/15", "set a mac limit of 1 on all interfaces", "set a mac limit of 1 on all interfaces and shutdown the interface if a violation occur", "Enable ARP inspection feature on VLAN REG", "Enable DHCP snooping on the vlan with the ID 10", "Limit the number of connected devices to one on each interface on the EX3300 switch", "set a mac limit of 2 on all interfaces and drop the packets received at the interface if a violation occur", "how to disable IP source guard on a vlan", "set the no-dhcp-trusted feature on the interface range WIRELESS-RANGE"], "operation": "set_ethernet_switching_options_secure_access_port", "positive_cues": ["set ethernet switching options secure access port"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "candidate": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "template": "set ethernet-switching-options secure-access-port interface {interface} dhcp-trusted", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["interface"], "required_params": ["interface"], "forbidden_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "operation": "set_ethernet_switching_options_secure_access_port", "positive_cues": ["set ethernet switching options secure access port"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "source_file": "data/processed/train.jsonl", "target_command": "set ethernet-switching-options secure-access-port interface ge-0/0/15 dhcp-trusted\ncommit"}

# %% [markdown]
# ## 7. Run Semantic RAG Unit Smoke Tests

# %%
# !pip install --upgrade torchao
# Out:
# Requirement already satisfied: torchao in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Collecting torchao
#   Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 103.3 MB/s eta 0:00:00
# Installing collected packages: torchao
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
# Successfully installed torchao-0.17.0

# %%
# !python tests/test_semantic_rag.py
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# semantic RAG smoke tests passed

# %% [markdown]
# ## 8. Train LoRA Adapter
#
# Run this if your current adapter has not been trained in this runtime. For the semantic architecture, the important thing to inspect is the semantic parser metrics below: if JSON validity is low, the adapter is still behaving like the old command-generation model and needs semantic-JSON supervised examples.

# %%
# !bash scripts/run_train.sh
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# config.json: 100% 654/654 [00:00<00:00, 2.83MB/s]
# tokenizer_config.json: 50.6kB [00:00, 98.0MB/s]
# tokenizer.json: 9.09MB [00:01, 7.28MB/s]
# special_tokens_map.json: 100% 73.0/73.0 [00:00<00:00, 354kB/s]
# model.safetensors.index.json: 23.9kB [00:00, 55.0MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 100% 16.1G/16.1G [00:41<00:00, 708MB/s]
# Fetching 4 files: 100% 4/4 [00:41<00:00, 10.39s/it]
# Download complete: 100% 16.1G/16.1G [00:41<00:00, 386MB/s]
# Loading weights: 100% 291/291 [00:04<00:00, 64.27it/s]
# generation_config.json: 100% 177/177 [00:00<00:00, 762kB/s]
# Map: 100% 722/722 [00:00<00:00, 2109.19 examples/s]
# {'loss': '0.3478', 'grad_norm': '0.6924', 'learning_rate': '0.000187', 'epoch': '0.2216'}
# {'loss': '0.1018', 'grad_norm': '0.8952', 'learning_rate': '0.0001725', 'epoch': '0.4432'}
# {'loss': '0.06099', 'grad_norm': '1.521', 'learning_rate': '0.000158', 'epoch': '0.6648'}
# {'loss': '0.04202', 'grad_norm': '0.1554', 'learning_rate': '0.0001435', 'epoch': '0.8864'}
# {'loss': '0.03819', 'grad_norm': '0.382', 'learning_rate': '0.000129', 'epoch': '1.089'}
# {'loss': '0.05935', 'grad_norm': '0.3349', 'learning_rate': '0.0001145', 'epoch': '1.31'}
# {'loss': '0.03516', 'grad_norm': '0.62', 'learning_rate': '0.0001', 'epoch': '1.532'}
# {'loss': '0.0327', 'grad_norm': '0.248', 'learning_rate': '8.551e-05', 'epoch': '1.753'}
# {'loss': '0.01477', 'grad_norm': '0.03808', 'learning_rate': '7.101e-05', 'epoch': '1.975'}
# {'loss': '0.01459', 'grad_norm': '0.05472', 'learning_rate': '5.652e-05', 'epoch': '2.177'}
# {'loss': '0.02041', 'grad_norm': '1.542', 'learning_rate': '4.203e-05', 'epoch': '2.399'}
# {'loss': '0.01584', 'grad_norm': '0.2907', 'learning_rate': '2.754e-05', 'epoch': '2.62'}
# {'loss': '0.01903', 'grad_norm': '0.1238', 'learning_rate': '1.304e-05', 'epoch': '2.842'}
# {'train_runtime': '286', 'train_samples_per_second': '7.574', 'train_steps_per_second': '0.483', 'train_loss': '0.05877', 'epoch': '3'}
# 100% 138/138 [04:45<00:00,  2.07s/it]

# %% [markdown]
# ## 9. Semantic RAG Smoke Inference
#
# This verifies that `--semantic_rag` writes semantic JSON, command context, assembly errors, commit decisions, and guardrail diagnostics.

# %%
import json, os
os.makedirs('data/processed', exist_ok=True)
rows = [
    {'intent': 'Display chassis LED status', 'context': '', 'target_command': 'show chassis led', 'category': 'semantic_smoke'},
    {'intent': 'Clear all MAC address entries in the ethernet switching table', 'context': '', 'target_command': 'clear ethernet-switching-table', 'category': 'semantic_smoke'},
    {'intent': 'Disable the OSPF protocol', 'context': '', 'target_command': 'set protocols ospf disable\\ncommit', 'category': 'semantic_smoke'},
]
with open('data/processed/semantic_rag_smoke.jsonl', 'w', encoding='utf-8') as f:
    for row in rows:
        f.write(json.dumps(row) + '\n')

# !mkdir -p results/predictions results/metrics results/error_analysis
# !python src/infer.py \
  --input_file data/processed/semantic_rag_smoke.jsonl \
  --output_file results/predictions/semantic_rag_smoke_predictions.jsonl \
  --semantic_rag \
  --mode intent_with_context

# !python scripts/evaluate_semantic_rag.py \
  --pred_file results/predictions/semantic_rag_smoke_predictions.jsonl \
  --out_file results/metrics/semantic_rag_smoke_metrics.json \
  --failures_file results/error_analysis/semantic_rag_smoke_failures.jsonl \
  --summary_file results/error_analysis/semantic_rag_smoke_error_summary.json

# !head -n 3 results/predictions/semantic_rag_smoke_predictions.jsonl
# !cat results/metrics/semantic_rag_smoke_metrics.json
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 60.97it/s]
#
# [INFO] Starting BATCHED inference on 3 instances for semantic_rag_smoke.jsonl...
# Batches:   0% 0/1 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches: 100% 1/1 [00:02<00:00,  2.45s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.6666666666666666,
#     "repaired_parse_rate": 0.3333333333333333,
#     "unrepaired_parse_error_rate": 0.3333333333333333,
#     "action_accuracy": 0.3333333333333333,
#     "domain_accuracy": 0.6666666666666666,
#     "sub_domain_accuracy": 0.6666666666666666,
#     "semantic_frame_exact_match": 0.3333333333333333,
#     "operation_accuracy": 0.0,
#     "operation_inferred_rate": 0.6666666666666666,
#     "parameter_precision": 0.3333333333333333,
#     "parameter_recall": 0.3333333333333333,
#     "parameter_f1": 0.3333333333333333,
#     "entity_preservation": 0.6666666666666666,
#     "template_hit_rate": 0.3333333333333333,
#     "correct_template_rate": 0.0,
#     "family_hit_rate": 0.0,
#     "variant_hit_rate": 0.0,
#     "template_variant_accuracy": 0.0,
#     "template_not_found_rate": 0.3333333333333333,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.3333333333333333,
#     "missing_parameter_rate": 0.0,
#     "unresolved_placeholder_rate": 0.0,
#     "commit_decision_accuracy": 0.6666666666666666,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.3333333333333333,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.0,
#     "normalized_exact_match": 0.0,
#     "token_f1": 0.2564102564102564,
#     "valid_rate": 0.0,
#     "bleu": 0.14490695731499714,
#     "invalid_output_rate": 1.0,
#     "failure_stage_counts": {
#       "semantic_parse_error": 1,
#       "wrong_template": 1,
#       "template_not_found": 1
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "show/chassis/led": 1,
#       "clear/ethernet-switching/table": 1,
#       "set/protocols/ospf": 1
#     }
#   }
# }
# {"intent": "Display chassis LED status", "context": "", "target_command": "show chassis led", "category": "semantic_smoke", "semantic_json_raw": "{\"action\":\"display chassis led status\", \"domain\":\"chassis\", \"sub_domain\":\"led\", \"parameters\":{}}\ncommit", "semantic_json": null, "semantic_parse_warnings": [], "semantic_parse_error": "invalid_enum_action", "command_context": {"found": false, "reason": "semantic_parse_error", "template_key": "", "warnings": [], "mode": "unknown", "requires_commit": false}, "context_warnings": [], "assembly_error": "semantic_parse_error", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": []}
# {"intent": "Clear all MAC address entries in the ethernet switching table", "context": "", "target_command": "clear ethernet-switching-table", "category": "semantic_smoke", "semantic_json_raw": "{\"action\":\"clear ethernet-switching table\", \"domain\":\"junos\", \"sub_domain\":\"ethernet-switching\", \"parameters\":{}}\ncommit", "semantic_json": {"action": "clear", "domain": "ethernet-switching", "sub_domain": "table", "parameters": {}, "operation": "clear_ethernet_switching_table", "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain", "inferred_operation"], "_intent_context": "Clear all MAC address entries in the ethernet switching table "}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain", "inferred_operation"], "semantic_parse_error": null, "command_context": {"action": "clear", "domain": "ethernet-switching", "sub_domain": "port-error", "template": "clear ethernet-switching port-error", "mode": "operational", "requires_commit": false, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["restore the interfaces blocked due to storm control violation", "restore the operation on interface ge-0/0/8", "clear port errors on the interface ge-0/0/9", "clear port errors on specific interface", "Clear port errors on the switch"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "clear", "mode": "operational"}, "variant": "plain", "operation": "clear_ethernet_switching_port_error", "positive_cues": ["clear ethernet switching port error"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "required_params": [], "forbidden_params": [], "found": true, "reason": "fallback_same_action_domain_selected_by_operation_score", "template_key": "clear/ethernet-switching/port-error", "template_variant_key": "clear/ethernet-switching/port-error/clear_ethernet_switching_port_error/plain", "warnings": []}, "context_warnings": [], "assembly_error": null, "prediction": "clear ethernet-switching port-error", "template_key": "clear/ethernet-switching/port-error", "commit_added": false, "guardrails_applied": []}
# {"intent": "Disable the OSPF protocol", "context": "", "target_command": "set protocols ospf disable\\ncommit", "category": "semantic_smoke", "semantic_json_raw": "{\"action\":\"commit\", \"domain\":\"protocols\", \"sub_domain\":\"ospf\", \"parameters\": {\"disable\": true}}\ncommit", "semantic_json": {"action": "commit", "domain": "protocols", "sub_domain": "ospf", "parameters": {"disable": true}, "operation": "commit_protocols_ospf", "_parse_warnings": ["stripped_trailing_text_after_json", "inferred_operation"], "_intent_context": "Disable the OSPF protocol "}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "inferred_operation"], "semantic_parse_error": null, "command_context": {"found": false, "reason": "template_not_found", "template_key": "", "action": "commit", "domain": "protocols", "sub_domain": "ospf", "template": "", "mode": "unknown", "requires_commit": false, "default_params": {}, "allowed_params": [], "description": "", "intent_examples": [], "negative_rules": [], "validation_rules": {}, "operation": "commit_protocols_ospf", "variant": "plain", "positive_cues": [], "negative_cues": [], "required_params": [], "forbidden_params": [], "warnings": []}, "context_warnings": [], "assembly_error": "template_not_found", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": []}
# {
#   "overall": {
#     "json_valid_rate": 0.6666666666666666,
#     "repaired_parse_rate": 0.3333333333333333,
#     "unrepaired_parse_error_rate": 0.3333333333333333,
#     "action_accuracy": 0.3333333333333333,
#     "domain_accuracy": 0.6666666666666666,
#     "sub_domain_accuracy": 0.6666666666666666,
#     "semantic_frame_exact_match": 0.3333333333333333,
#     "operation_accuracy": 0.0,
#     "operation_inferred_rate": 0.6666666666666666,
#     "parameter_precision": 0.3333333333333333,
#     "parameter_recall": 0.3333333333333333,
#     "parameter_f1": 0.3333333333333333,
#     "entity_preservation": 0.6666666666666666,
#     "template_hit_rate": 0.3333333333333333,
#     "correct_template_rate": 0.0,
#     "family_hit_rate": 0.0,
#     "variant_hit_rate": 0.0,
#     "template_variant_accuracy": 0.0,
#     "template_not_found_rate": 0.3333333333333333,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.3333333333333333,
#     "missing_parameter_rate": 0.0,
#     "unresolved_placeholder_rate": 0.0,
#     "commit_decision_accuracy": 0.6666666666666666,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.3333333333333333,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.0,
#     "normalized_exact_match": 0.0,
#     "token_f1": 0.2564102564102564,
#     "valid_rate": 0.0,
#     "bleu": 0.14490695731499714,
#     "invalid_output_rate": 1.0,
#     "failure_stage_counts": {
#       "semantic_parse_error": 1,
#       "wrong_template": 1,
#       "template_not_found": 1
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "show/chassis/led": 1,
#       "clear/ethernet-switching/table": 1,
#       "set/protocols/ospf": 1
#     }
#   }
# }

# %% [markdown]
# ## 10. Full Semantic RAG Evaluation
#
# This runs `test.jsonl` plus `clean_test.jsonl`, `paraphrased_test.jsonl`, and `noisy_test.jsonl` if present. Metrics are written under `results/metrics/`; stage failures and summaries are written under `results/error_analysis/`.

# %%
# !scripts/run_semantic_rag_eval.sh
# !cat results/metrics/semantic_rag_metrics.json
# !cat results/error_analysis/semantic_rag_error_summary.json
# !head -n 5 results/error_analysis/semantic_rag_failures.jsonl || true
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 59.37it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:07<00:29,  7.48s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:14<00:20,  6.94s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [00:21<00:14,  7.30s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [00:27<00:06,  6.79s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:33<00:00,  6.74s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.8866666666666667,
#     "repaired_parse_rate": 0.88,
#     "unrepaired_parse_error_rate": 0.11333333333333333,
#     "action_accuracy": 0.88,
#     "domain_accuracy": 0.8866666666666667,
#     "sub_domain_accuracy": 0.86,
#     "semantic_frame_exact_match": 0.86,
#     "operation_accuracy": 0.8466666666666667,
#     "operation_inferred_rate": 0.8866666666666667,
#     "parameter_precision": 0.8711111111111113,
#     "parameter_recall": 0.8711111111111113,
#     "parameter_f1": 0.8711111111111113,
#     "entity_preservation": 0.8933333333333333,
#     "template_hit_rate": 0.8733333333333333,
#     "correct_template_rate": 0.8,
#     "family_hit_rate": 0.8,
#     "variant_hit_rate": 0.76,
#     "template_variant_accuracy": 0.76,
#     "template_not_found_rate": 0.013333333333333334,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.74,
#     "missing_parameter_rate": 0.13333333333333333,
#     "unresolved_placeholder_rate": 0.0,
#     "commit_decision_accuracy": 0.7733333333333333,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.22666666666666666,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.17333333333333334,
#     "normalized_exact_match": 0.17333333333333334,
#     "token_f1": 0.5728386547506746,
#     "valid_rate": 0.17333333333333334,
#     "bleu": 0.4436467837384507,
#     "invalid_output_rate": 0.8266666666666667,
#     "failure_stage_counts": {
#       "ok": 26,
#       "final_command_mismatch": 75,
#       "semantic_parse_error": 17,
#       "missing_parameter": 19,
#       "template_not_found": 2,
#       "wrong_template": 11
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/igmp-snooping/flows": 1,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 2,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/interface-range": 3,
#       "show/igmp-snooping/memberships": 1,
#       "delete/system/login": 2,
#       "set/interfaces/<interface-name>": 3,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "delete/protocols/rstp": 2,
#       "request/system/software": 1,
#       "start/shell/sh": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/ge-2/0/25": 1,
#       "delete/vlans/it-data": 1,
#       "show/dhcp/snooping": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "delete/protocols/sflow": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "set/interfaces/ge-1/0/12": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 60.99it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for clean_test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:07<00:29,  7.28s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:13<00:20,  6.67s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [00:20<00:14,  7.04s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [00:26<00:06,  6.55s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:32<00:00,  6.48s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.8866666666666667,
#     "repaired_parse_rate": 0.88,
#     "unrepaired_parse_error_rate": 0.11333333333333333,
#     "action_accuracy": 0.88,
#     "domain_accuracy": 0.8866666666666667,
#     "sub_domain_accuracy": 0.86,
#     "semantic_frame_exact_match": 0.86,
#     "operation_accuracy": 0.8466666666666667,
#     "operation_inferred_rate": 0.8866666666666667,
#     "parameter_precision": 0.8711111111111113,
#     "parameter_recall": 0.8711111111111113,
#     "parameter_f1": 0.8711111111111113,
#     "entity_preservation": 0.8933333333333333,
#     "template_hit_rate": 0.8733333333333333,
#     "correct_template_rate": 0.8,
#     "family_hit_rate": 0.8,
#     "variant_hit_rate": 0.76,
#     "template_variant_accuracy": 0.76,
#     "template_not_found_rate": 0.013333333333333334,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.74,
#     "missing_parameter_rate": 0.13333333333333333,
#     "unresolved_placeholder_rate": 0.0,
#     "commit_decision_accuracy": 0.7733333333333333,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.22666666666666666,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.17333333333333334,
#     "normalized_exact_match": 0.17333333333333334,
#     "token_f1": 0.5728386547506746,
#     "valid_rate": 0.17333333333333334,
#     "bleu": 0.4436467837384507,
#     "invalid_output_rate": 0.8266666666666667,
#     "failure_stage_counts": {
#       "ok": 26,
#       "final_command_mismatch": 75,
#       "semantic_parse_error": 17,
#       "missing_parameter": 19,
#       "template_not_found": 2,
#       "wrong_template": 11
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/igmp-snooping/flows": 1,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 2,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/interface-range": 3,
#       "show/igmp-snooping/memberships": 1,
#       "delete/system/login": 2,
#       "set/interfaces/<interface-name>": 3,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "delete/protocols/rstp": 2,
#       "request/system/software": 1,
#       "start/shell/sh": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/ge-2/0/25": 1,
#       "delete/vlans/it-data": 1,
#       "show/dhcp/snooping": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "delete/protocols/sflow": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "set/interfaces/ge-1/0/12": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 59.12it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for paraphrased_test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:07<00:29,  7.32s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:13<00:20,  6.78s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [00:21<00:14,  7.12s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [00:27<00:06,  6.67s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:32<00:00,  6.60s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.8733333333333333,
#     "repaired_parse_rate": 0.8666666666666667,
#     "unrepaired_parse_error_rate": 0.12666666666666668,
#     "action_accuracy": 0.8666666666666667,
#     "domain_accuracy": 0.8733333333333333,
#     "sub_domain_accuracy": 0.8466666666666667,
#     "semantic_frame_exact_match": 0.8466666666666667,
#     "operation_accuracy": 0.8333333333333334,
#     "operation_inferred_rate": 0.8733333333333333,
#     "parameter_precision": 0.8627777777777778,
#     "parameter_recall": 0.8627777777777778,
#     "parameter_f1": 0.8627777777777778,
#     "entity_preservation": 0.8933333333333333,
#     "template_hit_rate": 0.86,
#     "correct_template_rate": 0.7866666666666666,
#     "family_hit_rate": 0.7866666666666666,
#     "variant_hit_rate": 0.7533333333333333,
#     "template_variant_accuracy": 0.7533333333333333,
#     "template_not_found_rate": 0.013333333333333334,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.7266666666666667,
#     "missing_parameter_rate": 0.13333333333333333,
#     "unresolved_placeholder_rate": 0.0,
#     "commit_decision_accuracy": 0.76,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.24,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.17333333333333334,
#     "normalized_exact_match": 0.17333333333333334,
#     "token_f1": 0.561913348173194,
#     "valid_rate": 0.17333333333333334,
#     "bleu": 0.4339838983072295,
#     "invalid_output_rate": 0.8266666666666667,
#     "failure_stage_counts": {
#       "ok": 26,
#       "final_command_mismatch": 73,
#       "semantic_parse_error": 19,
#       "missing_parameter": 19,
#       "template_not_found": 2,
#       "wrong_template": 11
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/igmp-snooping/flows": 1,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 2,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/interface-range": 3,
#       "show/igmp-snooping/memberships": 1,
#       "delete/system/login": 2,
#       "set/interfaces/<interface-name>": 3,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "delete/protocols/rstp": 2,
#       "request/system/software": 1,
#       "start/shell/sh": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/ge-2/0/25": 1,
#       "delete/vlans/it-data": 1,
#       "show/dhcp/snooping": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "delete/protocols/sflow": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "set/interfaces/ge-1/0/12": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 60.56it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for noisy_test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:07<00:28,  7.19s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:13<00:19,  6.59s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [00:20<00:13,  6.70s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [00:26<00:06,  6.37s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:31<00:00,  6.34s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.84,
#     "repaired_parse_rate": 0.8266666666666667,
#     "unrepaired_parse_error_rate": 0.16,
#     "action_accuracy": 0.8266666666666667,
#     "domain_accuracy": 0.8266666666666667,
#     "sub_domain_accuracy": 0.8066666666666666,
#     "semantic_frame_exact_match": 0.8066666666666666,
#     "operation_accuracy": 0.7933333333333333,
#     "operation_inferred_rate": 0.84,
#     "parameter_precision": 0.8283333333333334,
#     "parameter_recall": 0.8283333333333334,
#     "parameter_f1": 0.8283333333333334,
#     "entity_preservation": 0.88,
#     "template_hit_rate": 0.82,
#     "correct_template_rate": 0.7666666666666667,
#     "family_hit_rate": 0.7666666666666667,
#     "variant_hit_rate": 0.7333333333333333,
#     "template_variant_accuracy": 0.7333333333333333,
#     "template_not_found_rate": 0.02,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.68,
#     "missing_parameter_rate": 0.14,
#     "unresolved_placeholder_rate": 0.0,
#     "commit_decision_accuracy": 0.7333333333333333,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.26666666666666666,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.16666666666666666,
#     "normalized_exact_match": 0.16666666666666666,
#     "token_f1": 0.5357020461135635,
#     "valid_rate": 0.16666666666666666,
#     "bleu": 0.420411618377923,
#     "invalid_output_rate": 0.8333333333333334,
#     "failure_stage_counts": {
#       "ok": 25,
#       "final_command_mismatch": 70,
#       "semantic_parse_error": 24,
#       "missing_parameter": 20,
#       "template_not_found": 3,
#       "wrong_template": 8
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/igmp-snooping/flows": 1,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 2,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/interface-range": 3,
#       "show/dhcp/snooping": 2,
#       "show/igmp-snooping/memberships": 1,
#       "delete/system/login": 2,
#       "set/interfaces/<interface-name>": 3,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "delete/protocols/rstp": 2,
#       "request/system/software": 1,
#       "start/shell/sh": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/ge-2/0/25": 1,
#       "delete/vlans/it-data": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "delete/protocols/sflow": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "set/interfaces/ge-1/0/12": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }
# {
#   "total": 150,
#   "parse_errors": 17,
#   "template_not_found": 2,
#   "missing_parameters": 20,
#   "guardrail_modifications": 0,
#   "commit_suppressed_for_operational_action": 0,
#   "domain_equals_action": 0,
#   "sub_domain_gt_4_tokens": 0,
#   "unresolved_placeholder_count": 0,
#   "entity_preservation_failures": 16,
#   "exact_match_failures_by_action_domain_sub_domain": {
#     "set/protocols/sflow": 6,
#     "set/ethernet-switching-options/secure-access-port": 11,
#     "set/virtual-chassis/traceoptions": 6,
#     "show/chassis/lcd": 1,
#     "set/protocols/igmp-snooping": 5,
#     "set/system/ntp": 1,
#     "set/snmp/trap-group": 2,
#     "set/protocols/rstp": 13,
#     "set/system/syslog": 7,
#     "show/igmp-snooping/flows": 1,
#     "set/protocols/igmp": 9,
#     "show/ethernet-switching/table": 2,
#     "set/snmp/community": 2,
#     "set/protocols/ospf": 4,
#     "show/cli/general": 1,
#     "load/factory-default/general": 2,
#     "clear/ethernet-switching/table": 2,
#     "set/virtual-chassis/preprovisioned": 1,
#     "show/poe/telemetries": 1,
#     "delete/system/ntp": 1,
#     "show/chassis/pic-mode": 1,
#     "show/as-path/domain": 1,
#     "set/ethernet-switching-options/mac-table-aging-time": 1,
#     "set/interfaces/interface-range": 3,
#     "show/igmp-snooping/memberships": 1,
#     "delete/system/login": 2,
#     "set/interfaces/<interface-name>": 3,
#     "set/vlans/default": 1,
#     "request/system/power-off": 1,
#     "clear/ethernet-switching/port-error": 2,
#     "set/snmp/contact": 1,
#     "delete/protocols/rstp": 2,
#     "request/system/software": 1,
#     "start/shell/sh": 1,
#     "commit/comment/\"deleted": 1,
#     "set/interfaces/ge-2/0/25": 1,
#     "delete/vlans/it-data": 1,
#     "show/dhcp/snooping": 1,
#     "set/virtual-chassis/mac-persistence-timer": 1,
#     "delete/snmp/trap-options": 1,
#     "show/configuration/|": 1,
#     "set/poe/interface": 1,
#     "delete/protocols/sflow": 1,
#     "set/chassis/auto-image-upgrade": 1,
#     "set/protocols/lldp-med": 1,
#     "show/|/compare": 2,
#     "set/virtual-chassis/no-auto-conversion": 1,
#     "clear/system/login": 1,
#     "delete/snmp/filter-duplicates": 1,
#     "set/ethernet-switching-options/storm-control": 1,
#     "show/virtual-chassis/protocol": 1,
#     "clear/ethernet-switching/bpdu-error": 1,
#     "set/interfaces/ge-1/0/12": 1,
#     "delete/virtual-chassis/fast-failover": 1,
#     "set/ethernet-switching-options/bpdu-block": 1,
#     "delete/snmp/trap-group": 1,
#     "set/virtual-chassis/fast-failover": 1,
#     "set/ethernet-switching-options/voip": 1
#   },
#   "top_template_not_found_keys": {
#     "show/cli/general": 1,
#     "commit/system/commit": 1
#   },
#   "top_final_command_mismatch_templates": {
#     "set/protocols/igmp": 8,
#     "set/protocols/rstp": 8,
#     "set/ethernet-switching-options/secure-access-port": 7,
#     "set/system/syslog": 7,
#     "set/virtual-chassis/traceoptions": 4,
#     "set/protocols/igmp-snooping": 4,
#     "set/protocols/sflow": 3,
#     "set/snmp/trap-group": 2,
#     "show/ethernet-switching/table": 2,
#     "load/factory-default/general": 2,
#     "delete/system/login": 2,
#     "clear/ethernet-switching/port-error": 2,
#     "delete/protocols/rstp": 2,
#     "show/|/compare": 2,
#     "show/chassis/lcd": 1,
#     "show/igmp-snooping/flows": 1,
#     "set/snmp/community": 1,
#     "set/virtual-chassis/preprovisioned": 1,
#     "show/chassis/pic-mode": 1,
#     "set/ethernet-switching-options/mac-table-aging-time": 1
#   },
#   "examples_by_failure_stage": {
#     "final_command_mismatch": [
#       {
#         "intent": "Set sFlow taceoptions to trace all events",
#         "prediction": "set protocols sflow traceoptions flag all\\ncommit",
#         "target_command": "set protocols sflow traceoptions flag all\ncommit",
#         "template_key": "set/protocols/sflow",
#         "parsed_key": "set/protocols/sflow",
#         "assembly_error": null
#       },
#       {
#         "intent": "set a mac moving limit of 2 on vlan HR",
#         "prediction": "set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\\ncommit",
#         "target_command": "set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\ncommit",
#         "template_key": "set/ethernet-switching-options/secure-access-port",
#         "parsed_key": "set/ethernet-switching-options/secure-access-port",
#         "assembly_error": null
#       },
#       {
#         "intent": "Trace the virtual chassis complete sequence number (CSN) packets",
#         "prediction": "set virtual-chassis traceoptions flag csn\\ncommit",
#         "target_command": "set virtual-chassis traceoptions flag csn\ncommit",
#         "template_key": "set/virtual-chassis/traceoptions",
#         "parsed_key": "set/virtual-chassis/traceoptions",
#         "assembly_error": null
#       },
#       {
#         "intent": "put a mac limit of 1 on interface ge-0/0/15 and log the event when the mac limit is exceeded",
#         "prediction": "set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\\ncommit",
#         "target_command": "set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\ncommit",
#         "template_key": "set/ethernet-switching-options/secure-access-port",
#         "parsed_key": "set/ethernet-switching-options/secure-access-port",
#         "assembly_error": null
#       },
#       {
#         "intent": "set the sflow egress sampling rate to 1000",
#         "prediction": "set protocols sflow sample-rate egress 1000\\ncommit",
#         "target_command": "set protocols sflow sample-rate egress 1000\ncommit",
#         "template_key": "set/protocols/sflow",
#         "parsed_key": "set/protocols/sflow",
#         "assembly_error": null
#       }
#     ],
#     "semantic_parse_error": [
#       {
#         "intent": "help me configure ntp server on a juniper switch using command line",
#         "prediction": "",
#         "target_command": "set system ntp server <ntp-server-address>\ncommit",
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       },
#       {
#         "intent": "How to set the RSTP maximum age of received protocol BPDUs",
#         "prediction": "",
#         "target_command": "set protocols rstp max-age <max-age-interval>\ncommit",
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       },
#       {
#         "intent": "show 2 records of POE telemetry of all interfaces",
#         "prediction": "",
#         "target_command": "show poe telemetries interface all count 2",
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       },
#       {
#         "intent": "how to configure ospf hello interval",
#         "prediction": "",
#         "target_command": "set protocols ospf area <area-number> interface <interface-name> hello-interval <interval>\ncommit",
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       },
#       {
#         "intent": "set the IGMP protocol to send group-specific query messages every 3 seconds",
#         "prediction": "",
#         "target_command": "set protocols igmp query-last-member-interval 3\ncommit",
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       }
#     ],
#     "missing_parameter": [
#       {
#         "intent": "Enable sFlow protocol on interface ge-0/0/8",
#         "prediction": "",
#         "target_command": "set protocols sflow interfaces ge-0/0/8\ncommit",
#         "template_key": "set/protocols/sflow",
#         "parsed_key": "set/protocols/sflow",
#         "assembly_error": "missing_parameter:ip_address"
#       },
#       {
#         "intent": "how to disable the OSPF protocol",
#         "prediction": "",
#         "target_command": "set protocols ospf disable\ncommit",
#         "template_key": "set/protocols/ospf",
#         "parsed_key": "set/protocols/ospf",
#         "assembly_error": "missing_parameter:ip_address"
#       },
#       {
#         "intent": "how to set the sflow collector IP address and port number",
#         "prediction": "",
#         "target_command": "set protocols sflow collector <collector-IP> udp-port <udp-port>\ncommit",
#         "template_key": "set/protocols/sflow",
#         "parsed_key": "set/protocols/sflow",
#         "assembly_error": "missing_parameter:ip_address"
#       },
#       {
#         "intent": "how to configure persistent mac learning on an interface",
#         "prediction": "",
#         "target_command": "set ethernet-switching-options secure-access-port interface <interface-name> persistent-learning\ncommit",
#         "template_key": "set/ethernet-switching-options/secure-access-port",
#         "parsed_key": "set/ethernet-switching-options/secure-access-port",
#         "assembly_error": "missing_parameter:limit"
#       },
#       {
#         "intent": "make the interface range DIV-RANGE member of vlan DATA",
#         "prediction": "",
#         "target_command": "set interfaces interface-range DIV-RANGE unit 0 family ethernet-switching vlan members DATA\ncommit",
#         "template_key": "set/interfaces/interface-range",
#         "parsed_key": "set/interfaces/interface-range",
#         "assembly_error": "missing_parameter:range_name,valn_name_or_id"
#       }
#     ],
#     "template_not_found": [
#       {
#         "intent": "Show command-line interface settings",
#         "prediction": "",
#         "target_command": "show cli",
#         "template_key": "",
#         "parsed_key": "show/cli/general",
#         "assembly_error": "template_not_found"
#       },
#       {
#         "intent": "remove the configured ntp server",
#         "prediction": "",
#         "target_command": "delete system ntp server <ntp-server-address>\ncommit",
#         "template_key": "",
#         "parsed_key": "commit/system/commit",
#         "assembly_error": "template_not_found"
#       }
#     ],
#     "wrong_template": [
#       {
#         "intent": "Clear all MAC address entries in the ethernet switching table",
#         "prediction": "clear ethernet-switching port-error",
#         "target_command": "clear ethernet-switching-table",
#         "template_key": "clear/ethernet-switching/port-error",
#         "parsed_key": "clear/ethernet-switching/table",
#         "assembly_error": null
#       },
#       {
#         "intent": "Show autonomous-system domains",
#         "prediction": "show as-path",
#         "target_command": "show as-path domain",
#         "template_key": "show/as-path/general",
#         "parsed_key": "show/as-path/domain",
#         "assembly_error": null
#       },
#       {
#         "intent": "Display igmp-snooping membership",
#         "prediction": "show igmp-snooping task timers",
#         "target_command": "show igmp-snooping memberships",
#         "template_key": "show/igmp-snooping/task",
#         "parsed_key": "show/igmp-snooping/membership",
#         "assembly_error": null
#       },
#       {
#         "intent": "how to tag the default vlan with vlan id of 100",
#         "prediction": "set vlans IT_DEP l3-interface vlan.3010\\ncommit",
#         "target_command": "set vlans default vlan-id 100\ncommit",
#         "template_key": "set/vlans/it-dep",
#         "parsed_key": "set/vlans/default",
#         "assembly_error": null
#       },
#       {
#         "intent": "Clear all MAC address entries in the forwarding table",
#         "prediction": "clear ethernet-switching port-error",
#         "target_command": "clear ethernet-switching-table",
#         "template_key": "clear/ethernet-switching/port-error",
#         "parsed_key": "clear/ethernet-switching/table",
#         "assembly_error": null
#       }
#     ]
#   },
#   "unresolved_placeholder_rate": 0.0,
#   "unresolved_placeholders_by_name": {},
#   "unresolved_placeholder_examples": []
# }
# {
#   "overall": {
#     "json_valid_rate": 0.8866666666666667,
#     "repaired_parse_rate": 0.88,
#     "unrepaired_parse_error_rate": 0.11333333333333333,
#     "action_accuracy": 0.88,
#     "domain_accuracy": 0.8866666666666667,
#     "sub_domain_accuracy": 0.86,
#     "semantic_frame_exact_match": 0.86,
#     "operation_accuracy": 0.8466666666666667,
#     "operation_inferred_rate": 0.8866666666666667,
#     "parameter_precision": 0.8711111111111113,
#     "parameter_recall": 0.8711111111111113,
#     "parameter_f1": 0.8711111111111113,
#     "entity_preservation": 0.8933333333333333,
#     "template_hit_rate": 0.8733333333333333,
#     "correct_template_rate": 0.8,
#     "family_hit_rate": 0.8,
#     "variant_hit_rate": 0.76,
#     "template_variant_accuracy": 0.76,
#     "template_not_found_rate": 0.013333333333333334,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.74,
#     "missing_parameter_rate": 0.13333333333333333,
#     "unresolved_placeholder_rate": 0.0,
#     "commit_decision_accuracy": 0.7733333333333333,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.22666666666666666,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.17333333333333334,
#     "normalized_exact_match": 0.17333333333333334,
#     "token_f1": 0.5728386547506746,
#     "valid_rate": 0.17333333333333334,
#     "bleu": 0.4436467837384507,
#     "invalid_output_rate": 0.8266666666666667,
#     "failure_stage_counts": {
#       "ok": 26,
#       "final_command_mismatch": 75,
#       "semantic_parse_error": 17,
#       "missing_parameter": 19,
#       "template_not_found": 2,
#       "wrong_template": 11
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/igmp-snooping/flows": 1,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 2,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/interface-range": 3,
#       "show/igmp-snooping/memberships": 1,
#       "delete/system/login": 2,
#       "set/interfaces/<interface-name>": 3,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "delete/protocols/rstp": 2,
#       "request/system/software": 1,
#       "start/shell/sh": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/ge-2/0/25": 1,
#       "delete/vlans/it-data": 1,
#       "show/dhcp/snooping": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "delete/protocols/sflow": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "set/interfaces/ge-1/0/12": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }{
#   "total": 150,
#   "parse_errors": 17,
#   "template_not_found": 2,
#   "missing_parameters": 20,
#   "guardrail_modifications": 0,
#   "commit_suppressed_for_operational_action": 0,
#   "domain_equals_action": 0,
#   "sub_domain_gt_4_tokens": 0,
#   "unresolved_placeholder_count": 0,
#   "entity_preservation_failures": 16,
#   "exact_match_failures_by_action_domain_sub_domain": {
#     "set/protocols/sflow": 6,
#     "set/ethernet-switching-options/secure-access-port": 11,
#     "set/virtual-chassis/traceoptions": 6,
#     "show/chassis/lcd": 1,
#     "set/protocols/igmp-snooping": 5,
#     "set/system/ntp": 1,
#     "set/snmp/trap-group": 2,
#     "set/protocols/rstp": 13,
#     "set/system/syslog": 7,
#     "show/igmp-snooping/flows": 1,
#     "set/protocols/igmp": 9,
#     "show/ethernet-switching/table": 2,
#     "set/snmp/community": 2,
#     "set/protocols/ospf": 4,
#     "show/cli/general": 1,
#     "load/factory-default/general": 2,
#     "clear/ethernet-switching/table": 2,
#     "set/virtual-chassis/preprovisioned": 1,
#     "show/poe/telemetries": 1,
#     "delete/system/ntp": 1,
#     "show/chassis/pic-mode": 1,
#     "show/as-path/domain": 1,
#     "set/ethernet-switching-options/mac-table-aging-time": 1,
#     "set/interfaces/interface-range": 3,
#     "show/igmp-snooping/memberships": 1,
#     "delete/system/login": 2,
#     "set/interfaces/<interface-name>": 3,
#     "set/vlans/default": 1,
#     "request/system/power-off": 1,
#     "clear/ethernet-switching/port-error": 2,
#     "set/snmp/contact": 1,
#     "delete/protocols/rstp": 2,
#     "request/system/software": 1,
#     "start/shell/sh": 1,
#     "commit/comment/\"deleted": 1,
#     "set/interfaces/ge-2/0/25": 1,
#     "delete/vlans/it-data": 1,
#     "show/dhcp/snooping": 1,
#     "set/virtual-chassis/mac-persistence-timer": 1,
#     "delete/snmp/trap-options": 1,
#     "show/configuration/|": 1,
#     "set/poe/interface": 1,
#     "delete/protocols/sflow": 1,
#     "set/chassis/auto-image-upgrade": 1,
#     "set/protocols/lldp-med": 1,
#     "show/|/compare": 2,
#     "set/virtual-chassis/no-auto-conversion": 1,
#     "clear/system/login": 1,
#     "delete/snmp/filter-duplicates": 1,
#     "set/ethernet-switching-options/storm-control": 1,
#     "show/virtual-chassis/protocol": 1,
#     "clear/ethernet-switching/bpdu-error": 1,
#     "set/interfaces/ge-1/0/12": 1,
#     "delete/virtual-chassis/fast-failover": 1,
#     "set/ethernet-switching-options/bpdu-block": 1,
#     "delete/snmp/trap-group": 1,
#     "set/virtual-chassis/fast-failover": 1,
#     "set/ethernet-switching-options/voip": 1
#   },
#   "top_template_not_found_keys": {
#     "show/cli/general": 1,
#     "commit/system/commit": 1
#   },
#   "top_final_command_mismatch_templates": {
#     "set/protocols/igmp": 8,
#     "set/protocols/rstp": 8,
#     "set/ethernet-switching-options/secure-access-port": 7,
#     "set/system/syslog": 7,
#     "set/virtual-chassis/traceoptions": 4,
#     "set/protocols/igmp-snooping": 4,
#     "set/protocols/sflow": 3,
#     "set/snmp/trap-group": 2,
#     "show/ethernet-switching/table": 2,
#     "load/factory-default/general": 2,
#     "delete/system/login": 2,
#     "clear/ethernet-switching/port-error": 2,
#     "delete/protocols/rstp": 2,
#     "show/|/compare": 2,
#     "show/chassis/lcd": 1,
#     "show/igmp-snooping/flows": 1,
#     "set/snmp/community": 1,
#     "set/virtual-chassis/preprovisioned": 1,
#     "show/chassis/pic-mode": 1,
#     "set/ethernet-switching-options/mac-table-aging-time": 1
#   },
#   "examples_by_failure_stage": {
#     "final_command_mismatch": [
#       {
#         "intent": "Set sFlow taceoptions to trace all events",
#         "prediction": "set protocols sflow traceoptions flag all\\ncommit",
#         "target_command": "set protocols sflow traceoptions flag all\ncommit",
#         "template_key": "set/protocols/sflow",
#         "parsed_key": "set/protocols/sflow",
#         "assembly_error": null
#       },
#       {
#         "intent": "set a mac moving limit of 2 on vlan HR",
#         "prediction": "set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\\ncommit",
#         "target_command": "set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\ncommit",
#         "template_key": "set/ethernet-switching-options/secure-access-port",
#         "parsed_key": "set/ethernet-switching-options/secure-access-port",
#         "assembly_error": null
#       },
#       {
#         "intent": "Trace the virtual chassis complete sequence number (CSN) packets",
#         "prediction": "set virtual-chassis traceoptions flag csn\\ncommit",
#         "target_command": "set virtual-chassis traceoptions flag csn\ncommit",
#         "template_key": "set/virtual-chassis/traceoptions",
#         "parsed_key": "set/virtual-chassis/traceoptions",
#         "assembly_error": null
#       },
#       {
#         "intent": "put a mac limit of 1 on interface ge-0/0/15 and log the event when the mac limit is exceeded",
#         "prediction": "set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\\ncommit",
#         "target_command": "set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\ncommit",
#         "template_key": "set/ethernet-switching-options/secure-access-port",
#         "parsed_key": "set/ethernet-switching-options/secure-access-port",
#         "assembly_error": null
#       },
#       {
#         "intent": "set the sflow egress sampling rate to 1000",
#         "prediction": "set protocols sflow sample-rate egress 1000\\ncommit",
#         "target_command": "set protocols sflow sample-rate egress 1000\ncommit",
#         "template_key": "set/protocols/sflow",
#         "parsed_key": "set/protocols/sflow",
#         "assembly_error": null
#       }
#     ],
#     "semantic_parse_error": [
#       {
#         "intent": "help me configure ntp server on a juniper switch using command line",
#         "prediction": "",
# ...
#         "template_key": "set/vlans/it-dep",
#         "parsed_key": "set/vlans/default",
#         "assembly_error": null
#       },
#       {
#         "intent": "Clear all MAC address entries in the forwarding table",
#         "prediction": "clear ethernet-switching port-error",
#         "target_command": "clear ethernet-switching-table",
#         "template_key": "clear/ethernet-switching/port-error",
#         "parsed_key": "clear/ethernet-switching/table",
#         "assembly_error": null
#       }
#     ]
#   },
#   "unresolved_placeholder_rate": 0.0,
#   "unresolved_placeholders_by_name": {},
#   "unresolved_placeholder_examples": []
# }{"intent": "Set sFlow taceoptions to trace all events", "context": "set protocols sflow traceoptions flag all", "target_command": "set protocols sflow traceoptions flag all\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": "", "semantic_json_raw": "{\"action\":\"set protocols sflow traceoptions flag all\", \"domain\":\"set\", \"sub_domain\":\"protocols sflow traceoptions flag all\", \"parameters\":{}}\ncommit", "semantic_json": {"action": "set", "domain": "protocols", "sub_domain": "sflow", "parameters": {"flag": "all"}, "operation": "traceoptions_flag_enable", "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain", "inferred_operation"], "_intent_context": "Set sFlow taceoptions to trace all events set protocols sflow traceoptions flag all"}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain", "inferred_operation"], "semantic_parse_error": null, "command_context": {"action": "set", "domain": "protocols", "sub_domain": "sflow", "template": "set protocols sflow traceoptions flag {flag}", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["flag"], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["Set sFlow taceoptions to trace configuration changes", "Set sFlow taceoptions to trace rtsock events", "Set sFlow taceoptions to trace client-server events", "Set sFlow taceoptions to trace interface events"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain", "operation": "traceoptions_flag_enable", "positive_cues": ["trace", "traceoptions", "flag"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "required_params": ["flag"], "forbidden_params": [], "found": true, "reason": "selected_by_operation_score", "template_key": "set/protocols/sflow", "template_variant_key": "set/protocols/sflow/traceoptions_flag_enable/plain", "warnings": []}, "context_warnings": [], "assembly_error": null, "prediction": "set protocols sflow traceoptions flag all\\ncommit", "template_key": "set/protocols/sflow", "commit_added": true, "guardrails_applied": [], "failure_stage": "final_command_mismatch", "expected_template_key": "set/protocols/sflow"}
# {"intent": "set a mac moving limit of 2 on vlan HR", "context": "set ethernet-switching-options secure-access-port vlan <vlan-id-or-name> mac-move-limit <limit>", "target_command": "set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"vlan\"}", "category": "", "semantic_json_raw": "{\"action\":\"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"domain\": \"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"sub_domain\": \"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"parameters\": {}}\ncommit", "semantic_json": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "parameters": {"vlan_name": "HR", "limit": 2}, "operation": "mac_move_limit", "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain", "inferred_operation"], "_intent_context": "set a mac moving limit of 2 on vlan HR set ethernet-switching-options secure-access-port vlan <vlan-id-or-name> mac-move-limit <limit>"}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain", "inferred_operation"], "semantic_parse_error": null, "command_context": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "template": "set ethernet-switching-options secure-access-port vlan <vlan-name-or-id> mac-move-limit {limit}", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["limit"], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["Do not allow a device to change the port it is connected to more than twice a second", "set a mac moving limit of 5 on vlan 10 and generate a systme log entry whenever the limit is reached", "Do not allow mac movements in VLAN 10", "limit the number of MAC movements that can be made by individual MAC addresses within VLAN FIN to 1", "set a mac moving limit of 3 on vlan 20", "limit the number of MAC movements that can be made by individual MAC addresses within all VLANs to 2", "how to configure a mac moving limit on a vlan"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain", "operation": "mac_move_limit", "positive_cues": ["mac moving limit", "mac-move-limit"], "negative_cues": ["disable", "no-examine-dhcp"], "required_params": ["limit", "vlan_id_or_name"], "forbidden_params": [], "found": true, "reason": "selected_by_operation_score", "template_key": "set/ethernet-switching-options/secure-access-port", "template_variant_key": "set/ethernet-switching-options/secure-access-port/mac_move_limit/plain", "warnings": []}, "context_warnings": [], "assembly_error": null, "prediction": "set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\\ncommit", "template_key": "set/ethernet-switching-options/secure-access-port", "commit_added": true, "guardrails_applied": [], "failure_stage": "final_command_mismatch", "expected_template_key": "set/ethernet-switching-options/secure-access-port"}
# {"intent": "Trace the virtual chassis complete sequence number (CSN) packets", "context": "set virtual-chassis traceoptions flag csn", "target_command": "set virtual-chassis traceoptions flag csn\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": "", "semantic_json_raw": "{\"action\":\"set virtual-chassis traceoptions flag csn\", \"domain\":\"set\", \"sub_domain\":\"virtual-chassis traceoptions flag csn\", \"parameters\":{}}\ncommit", "semantic_json": {"action": "set", "domain": "virtual-chassis", "sub_domain": "traceoptions", "parameters": {"flag": "csn"}, "operation": "traceoptions_flag_enable", "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain", "inferred_operation"], "_intent_context": "Trace the virtual chassis complete sequence number (CSN) packets set virtual-chassis traceoptions flag csn"}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain", "inferred_operation"], "semantic_parse_error": null, "command_context": {"action": "set", "domain": "virtual-chassis", "sub_domain": "traceoptions", "template": "set virtual-chassis traceoptions flag {flag}", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["flag"], "description": "Template inferred from data/processed/val.jsonl", "intent_examples": ["Trace virtual chassis kernel events", "Trace virtual chassis LSP generation", "Trace virtual chassis master election events", "Trace virtual chassis packets", "Trace the virtual chassis  dcp infrastructure configuration", "trace virtual chassis ports auto configuration", "Trace virtual chassis graceful restart events", "Trace virtual chassis normal events", "Trace virtual chassis partial sequence number (PSN) packets", "Trace virtual chassis SPF events"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain", "operation": "traceoptions_flag_enable", "positive_cues": ["trace", "traceoptions", "flag"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "required_params": ["flag"], "forbidden_params": [], "found": true, "reason": "selected_by_operation_score", "template_key": "set/virtual-chassis/traceoptions", "template_variant_key": "set/virtual-chassis/traceoptions/traceoptions_flag_enable/plain", "warnings": []}, "context_warnings": [], "assembly_error": null, "prediction": "set virtual-chassis traceoptions flag csn\\ncommit", "template_key": "set/virtual-chassis/traceoptions", "commit_added": true, "guardrails_applied": [], "failure_stage": "final_command_mismatch", "expected_template_key": "set/virtual-chassis/traceoptions"}
# {"intent": "put a mac limit of 1 on interface ge-0/0/15 and log the event when the mac limit is exceeded", "context": "set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <limit> action log", "target_command": "set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": "", "semantic_json_raw": "{\"action\": \"set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\", \"domain\": \"set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\", \"sub_domain\": \"set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\", \"parameters\": { \"interface-name\": \"ge-0/0/15\", \"limit\": \"1\", \"action\": \"log\" } }", "semantic_json": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "parameters": {"interface": "ge-0/0/15", "limit": 1, "interface-name": "ge-0/0/15", "action": "log"}, "operation": "set_ethernet_switching_options_secure_access_port", "_parse_warnings": ["repaired_full_command_action", "inferred_domain_sub_domain", "inferred_operation"], "_intent_context": "put a mac limit of 1 on interface ge-0/0/15 and log the event when the mac limit is exceeded set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <limit> action log"}, "semantic_parse_warnings": ["repaired_full_command_action", "inferred_domain_sub_domain", "inferred_operation"], "semantic_parse_error": null, "command_context": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "template": "set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <limit> action log", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["how to set a mac limit on an interface and set the action to log on violations", "Disable IP source guard inspection on interface ge-0/0/15", "set a mac limit of 1 on all interfaces", "set a mac limit of 1 on all interfaces and shutdown the interface if a violation occur", "Enable ARP inspection feature on VLAN REG", "Enable DHCP snooping on the vlan with the ID 10", "Limit the number of connected devices to one on each interface on the EX3300 switch", "set a mac limit of 2 on all interfaces and drop the packets received at the interface if a violation occur", "how to disable IP source guard on a vlan", "set the no-dhcp-trusted feature on the interface range WIRELESS-RANGE"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain", "operation": "set_ethernet_switching_options_secure_access_port", "positive_cues": ["set ethernet switching options secure access port"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "required_params": ["interface", "limit"], "forbidden_params": [], "found": true, "reason": "selected_by_operation_score", "template_key": "set/ethernet-switching-options/secure-access-port", "template_variant_key": "set/ethernet-switching-options/secure-access-port/set_ethernet_switching_options_secure_access_port/plain", "warnings": []}, "context_warnings": [], "assembly_error": null, "prediction": "set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\\ncommit", "template_key": "set/ethernet-switching-options/secure-access-port", "commit_added": true, "guardrails_applied": [], "failure_stage": "final_command_mismatch", "expected_template_key": "set/ethernet-switching-options/secure-access-port"}
# {"intent": "set the sflow egress sampling rate to 1000", "context": "set protocols sflow sample-rate egress <rate>", "target_command": "set protocols sflow sample-rate egress 1000\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": "", "semantic_json_raw": "{\"action\": \"set protocols sflow sample-rate egress 1000\", \"domain\": \"set\", \"sub_domain\": \"protocols sflow sample-rate egress\", \"parameters\": {\"rate\": 1000}}\ncommit", "semantic_json": {"action": "set", "domain": "protocols", "sub_domain": "sflow", "parameters": {"rate": 1000}, "operation": "sample_rate_egress", "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain", "inferred_operation"], "_intent_context": "set the sflow egress sampling rate to 1000 set protocols sflow sample-rate egress <rate>"}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain", "inferred_operation"], "semantic_parse_error": null, "command_context": {"action": "set", "domain": "protocols", "sub_domain": "sflow", "template": "set protocols sflow sample-rate egress <rate>", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["how to set the sflow egress sampling rate", "set the sflow egress sampling rate to 1100"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain", "operation": "sample_rate_egress", "positive_cues": ["sample-rate", "egress"], "negative_cues": ["disable", "no-examine-dhcp", "mac-move-limit"], "required_params": ["rate"], "forbidden_params": [], "found": true, "reason": "selected_by_operation_score", "template_key": "set/protocols/sflow", "template_variant_key": "set/protocols/sflow/sample_rate_egress/plain", "warnings": []}, "context_warnings": [], "assembly_error": null, "prediction": "set protocols sflow sample-rate egress 1000\\ncommit", "template_key": "set/protocols/sflow", "commit_added": true, "guardrails_applied": [], "failure_stage": "final_command_mismatch", "expected_template_key": "set/protocols/sflow"}

# %% [markdown]
# ## 11. Compare Against Legacy RAG Baseline Optional
#
# Use this only for comparison. The final architecture is `--semantic_rag` above.

# %%
# !python src/infer.py \
  --input_file data/processed/test.jsonl \
  --output_file results/predictions/rag_predictions_baseline.jsonl \
  --use_rag \
  --rag-corpus train,rag_docs
# !python src/evaluate.py \
  --pred_file results/predictions/rag_predictions_baseline.jsonl \
  --out_file results/metrics/rag_baseline_eval_metrics.json
# !cat results/metrics/rag_baseline_eval_metrics.json
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [RAG] Building index from:
# [RAG]   include data/processed/train.jsonl
# [RAG]   include rag-doc/ex3300.pdf
# [RAG]   exclude data/processed/val.jsonl
# [RAG]   exclude data/processed/test.jsonl
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:05<00:00, 58.02it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:22<01:28, 22.10s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:44<01:05, 21.98s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [01:11<00:49, 24.71s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [01:31<00:22, 22.49s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [01:45<00:00, 21.04s/it]
# [EVAL] exact_match_accuracy: 0.1933 (29/150)
# [RAG] retrieved chunk counts:
# [RAG]   ex3300.pdf: 22
# [RAG]   train.jsonl: 728
# [RAG] top-1 source distribution:
# [RAG]   ex3300.pdf: 2
# [RAG]   train.jsonl: 148
# [RAG] top-5 source distribution:
# [RAG]   ex3300.pdf: 22
# [RAG]   train.jsonl: 728
# [RAG] wrote failure analysis to outputs/rag_failures_strict.jsonl
# {
#   "overall": {
#     "exact_match": 0.19333333333333333,
#     "normalized_exact_match": 0.64,
#     "token_f1": 0.8625172072722016,
#     "bleu": 0.7474639458899086,
#     "valid_rate": 0.19333333333333333,
#     "entity_preservation": 0.98,
#     "invalid_output_rate": 0.8066666666666666
#   },
#   "per_category": {
#     "": {
#       "exact_match": 0.19333333333333333,
#       "normalized_exact_match": 0.64,
#       "token_f1": 0.8625172072722016,
#       "bleu": 0.7474639458899086,
#       "valid_rate": 0.19333333333333333,
#       "entity_preservation": 0.98,
#       "invalid_output_rate": 0.8066666666666666
#     }
#   }
# }

# %% [markdown]
# ## 12. Save Results To Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/slm-kdn-results
# !cp -r results /content/drive/MyDrive/slm-kdn-results/semantic-rag-results-$(date +%Y%m%d-%H%M%S)
# !cp data/juniper_templates.json /content/drive/MyDrive/slm-kdn-results/juniper_templates-$(date +%Y%m%d-%H%M%S).json
# !ls -lh /content/drive/MyDrive/slm-kdn-results
# Out:
# Mounted at /content/drive
# total 1.1M
# -rw------- 1 root root 155K May 11 22:48 juniper_templates-20260511-224857.json
# -rw------- 1 root root 155K May 11 23:13 juniper_templates-20260511-231309.json
# -rw------- 1 root root 181K May 11 23:37 juniper_templates-20260511-233741.json
# -rw------- 1 root root 271K May 12 00:02 juniper_templates-20260512-000206.json
# -rw------- 1 root root 273K May 12 00:18 juniper_templates-20260512-001848.json
# drwx------ 2 root root 4.0K May 11 18:43 results-rag-20260511-184340
# drwx------ 2 root root 4.0K May 11 19:17 results-rag-20260511-191756
# drwx------ 2 root root 4.0K May 11 19:43 results-rag-20260511-194342
# drwx------ 2 root root 4.0K May 11 20:17 results-rag-20260511-201701
# drwx------ 2 root root 4.0K May 11 20:57 results-rag-20260511-205733
# drwx------ 2 root root 4.0K May 11 21:11 results-rag-20260511-211105
# drwx------ 2 root root 4.0K May 11 22:48 semantic-rag-results-20260511-224855
# drwx------ 2 root root 4.0K May 11 23:13 semantic-rag-results-20260511-231307
# drwx------ 2 root root 4.0K May 11 23:37 semantic-rag-results-20260511-233739
# drwx------ 2 root root 4.0K May 12 00:02 semantic-rag-results-20260512-000203
# drwx------ 6 root root 4.0K May 12 00:18 semantic-rag-results-20260512-001846

# %%
# !head -n 5 results/predictions/semantic_rag_predictions.jsonl | jq '.semantic_json_raw'
# Out:
# "{\"action\":\"show chassis led\", \"domain\":\"chassis\", \"sub_domain\":\"led\", \"parameters\":{}}\ncommit"
# "{\"action\": \"show configuration protocols sflow\", \"domain\": \"configuration\", \"sub_domain\": \"protocols\", \"parameters\": {\"name\": \"sflow\"}}"
# "{\"action\":\"set protocols sflow traceoptions flag all\", \"domain\":\"set\", \"sub_domain\":\"protocols sflow traceoptions flag all\", \"parameters\":{}}\ncommit"
# "{\"action\":\"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"domain\": \"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"sub_domain\": \"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"parameters\": {}}\ncommit"
# "{\"action\":\"set virtual-chassis traceoptions flag csn\", \"domain\":\"set\", \"sub_domain\":\"virtual-chassis traceoptions flag csn\", \"parameters\":{}}\ncommit"

# %%
import json, re
from pathlib import Path

pred_file = "results/predictions/semantic_rag_predictions.jsonl"

def norm(x):
    x = str(x or "")
    x = x.replace("\\\\n", "\n")
    x = x.replace("\\n", "\n")
    x = re.sub(r"[ \t]+", " ", x)
    x = re.sub(r"\s*\n\s*", "\n", x)
    x = x.strip()
    return x

total = 0
raw_em = 0
norm_em = 0
examples = []

for line in Path(pred_file).read_text().splitlines():
    row = json.loads(line)
    p = row.get("prediction", "")
    t = row.get("target_command", "")
    total += 1
    raw_em += int(p == t)
    norm_em += int(norm(p) == norm(t))

    if norm(p) == norm(t) and p != t and len(examples) < 10:
        examples.append({
            "intent": row.get("intent"),
            "prediction_raw": repr(p),
            "target_raw": repr(t),
            "prediction_norm": norm(p),
            "target_norm": norm(t),
        })

print("total", total)
print("raw_em", raw_em, raw_em / total)
print("norm_em", norm_em, norm_em / total)
print("\nexamples where normalized matches but raw fails:")
for e in examples:
    print(json.dumps(e, indent=2))
# Out:
# total 150
# raw_em 26 0.17333333333333334
# norm_em 61 0.4066666666666667
#
# examples where normalized matches but raw fails:
# {
#   "intent": "Set sFlow taceoptions to trace all events",
#   "prediction_raw": "'set protocols sflow traceoptions flag all\\\\ncommit'",
#   "target_raw": "'set protocols sflow traceoptions flag all\\ncommit'",
#   "prediction_norm": "set protocols sflow traceoptions flag all\ncommit",
#   "target_norm": "set protocols sflow traceoptions flag all\ncommit"
# }
# {
#   "intent": "set a mac moving limit of 2 on vlan HR",
#   "prediction_raw": "'set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\\\\ncommit'",
#   "target_raw": "'set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\\ncommit'",
#   "prediction_norm": "set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\ncommit",
#   "target_norm": "set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\ncommit"
# }
# {
#   "intent": "Trace the virtual chassis complete sequence number (CSN) packets",
#   "prediction_raw": "'set virtual-chassis traceoptions flag csn\\\\ncommit'",
#   "target_raw": "'set virtual-chassis traceoptions flag csn\\ncommit'",
#   "prediction_norm": "set virtual-chassis traceoptions flag csn\ncommit",
#   "target_norm": "set virtual-chassis traceoptions flag csn\ncommit"
# }
# {
#   "intent": "put a mac limit of 1 on interface ge-0/0/15 and log the event when the mac limit is exceeded",
#   "prediction_raw": "'set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\\\\ncommit'",
#   "target_raw": "'set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\\ncommit'",
#   "prediction_norm": "set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\ncommit",
#   "target_norm": "set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\ncommit"
# }
# {
#   "intent": "set the sflow egress sampling rate to 1000",
#   "prediction_raw": "'set protocols sflow sample-rate egress 1000\\\\ncommit'",
#   "target_raw": "'set protocols sflow sample-rate egress 1000\\ncommit'",
#   "prediction_norm": "set protocols sflow sample-rate egress 1000\ncommit",
#   "target_norm": "set protocols sflow sample-rate egress 1000\ncommit"
# }
# {
#   "intent": "disable IGMP snooping routing information taceoption",
#   "prediction_raw": "'set protocols igmp-snooping traceoptions flag route disable\\\\ncommit'",
#   "target_raw": "'set protocols igmp-snooping traceoptions flag route disable\\ncommit'",
#   "prediction_norm": "set protocols igmp-snooping traceoptions flag route disable\ncommit",
#   "target_norm": "set protocols igmp-snooping traceoptions flag route disable\ncommit"
# }
# {
#   "intent": "Disable IGMPv2 protocol leave group messages traceoptions",
#   "prediction_raw": "'set protocols igmp traceoptions flag leave disable\\\\ncommit'",
#   "target_raw": "'set protocols igmp traceoptions flag leave disable\\ncommit'",
#   "prediction_norm": "set protocols igmp traceoptions flag leave disable\ncommit",
#   "target_norm": "set protocols igmp traceoptions flag leave disable\ncommit"
# }
# {
#   "intent": "create SNMP community with the name CAMPUS-COMMUNITY and set authorization to read only",
#   "prediction_raw": "'set snmp community CAMPUS-COMMUNITY authorization read-only\\\\ncommit'",
#   "target_raw": "'set snmp community CAMPUS-COMMUNITY authorization read-only\\ncommit'",
#   "prediction_norm": "set snmp community CAMPUS-COMMUNITY authorization read-only\ncommit",
#   "target_norm": "set snmp community CAMPUS-COMMUNITY authorization read-only\ncommit"
# }
# {
#   "intent": "Override existing configuration with factory default",
#   "prediction_raw": "'load factory-default\\\\ncommit'",
#   "target_raw": "'load factory-default\\ncommit'",
#   "prediction_norm": "load factory-default\ncommit",
#   "target_norm": "load factory-default\ncommit"
# }
# {
#   "intent": "enable the virtual chassis preprovisioned mode",
#   "prediction_raw": "'set virtual-chassis preprovisioned\\\\ncommit'",
#   "target_raw": "'set virtual-chassis preprovisioned\\ncommit'",
#   "prediction_norm": "set virtual-chassis preprovisioned\ncommit",
#   "target_norm": "set virtual-chassis preprovisioned\ncommit"
# }
