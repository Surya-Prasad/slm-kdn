# %% [markdown]
# # SLM-KDN Colab Pro A100: Semantic RAG Micro-KDN
#
# This notebook tests the final architecture:
#
# 1. Fine-tuned Llama-3-8B emits strict semantic JSON only.
# 2. The local command-context/template store retrieves command metadata.
# 3. Python deterministically assembles Junos CLI.
# 4. Guardrails enforce commit and mode validity.
#
# Use the older RAG notebook for the baseline `--use_rag` free-form command path. Use this notebook for the final `--semantic_rag` path.

# %% [markdown]
# ## 1. Check GPU

# %%
# !nvidia-smi
# Out:
# Mon May 11 23:23:08 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             45W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
    print('Capability:', torch.cuda.get_device_capability(0))
# Out:
# CUDA available: True
# GPU: NVIDIA A100-SXM4-40GB
# Capability: (8, 0)

# %% [markdown]
# ## 2. Clone Repo From Master

# %%
# %cd /content
# !rm -rf slm-kdn
# !git clone --branch master https://github.com/Surya-Prasad/slm-kdn.git
# %cd /content/slm-kdn
# !git status --short
# !git rev-parse --abbrev-ref HEAD
# !git log -1 --oneline
# Out:
# /content
# Cloning into 'slm-kdn'...
# remote: Enumerating objects: 234, done.
# remote: Counting objects: 100% (234/234), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 234 (delta 131), reused 147 (delta 70), pack-reused 0 (from 0)
# Receiving objects: 100% (234/234), 2.98 MiB | 19.84 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# /content/slm-kdn
# master
# dbc3256 (HEAD -> master, origin/master, origin/HEAD) Refining Semantic RAG

# %% [markdown]
# ## 3. Install Dependencies

# %%
# !pip install -q -r requirements.txt
# !pip install -q --upgrade transformers peft accelerate bitsandbytes datasets pypdf nltk
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 43.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.8/338.8 kB 36.7 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 113.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 47.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 46.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 57.1 MB/s eta 0:00:00

# %% [markdown]
# ## 4. Hugging Face Login
#
# Run this if your base model or adapter needs gated Hugging Face access.

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# ## 5. Preprocess NIT Dataset
#
# This creates `data/processed/train.jsonl`, `val.jsonl`, `test.jsonl`, and robustness variants when available.

# %%
# !bash scripts/run_preprocess.sh
# !find data/processed -maxdepth 1 -type f -print | sort
# !head -n 1 data/processed/test.jsonl
# Out:
# README.md: 4.31kB [00:00, 6.42MB/s]
# NIT_dataset.json: 273kB [00:00, 138MB/s]
# Generating train split: 100% 1000/1000 [00:00<00:00, 118033.04 examples/s]
# data/processed/clean_test.jsonl
# data/processed/noisy_test.jsonl
# data/processed/paraphrased_test.jsonl
# data/processed/test_intent_only.jsonl
# data/processed/test_intent_with_context.jsonl
# data/processed/test.jsonl
# data/processed/train_intent_only.jsonl
# data/processed/train_intent_with_context.jsonl
# data/processed/train.jsonl
# data/processed/val_intent_only.jsonl
# data/processed/val_intent_with_context.jsonl
# data/processed/val.jsonl
# {"intent": "How to display the LED status", "context": "show chassis led", "target_command": "show chassis led", "target_json": "{\"action\":\"show\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": ""}

# %% [markdown]
# ## 6. Build Command-Context Datastore
#
# This builds `data/juniper_templates.json` from train/val only. It does not use `test.jsonl` unless `--allow-test` is explicitly passed, which you should not use for final evaluation.

# %%
# !python scripts/build_perfect_datastore_v2.py
# !python - <<'PY'
import json
from pathlib import Path
p = Path('data/juniper_templates.json')
payload = json.loads(p.read_text())
print('template_count:', len(payload))
for i, (k, v) in enumerate(payload.items()):
    if i >= 5:
        break
    print(k, '=>', {x: v.get(x) for x in ['template', 'mode', 'requires_commit', 'allowed_params']})
# !wc -l outputs/datastore_conflicts.jsonl || true
# !head -n 5 outputs/datastore_conflicts.jsonl || true
# Out:
# Wrote 220 templates to /content/slm-kdn/data/juniper_templates.json
# Wrote 483 conflicts to /content/slm-kdn/outputs/datastore_conflicts.jsonl
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# template_count: 220
# clear/ethernet-switching/port-error/plain => {'template': 'clear ethernet-switching port-error', 'mode': 'operational', 'requires_commit': False, 'allowed_params': []}
# set/system/ntp/plain => {'template': 'set system ntp server {ip_address} commit comment "configured ntp server"', 'mode': 'configuration', 'requires_commit': True, 'allowed_params': ['ip_address']}
# set/protocols/rstp/plain => {'template': 'set protocols rstp max-age 15', 'mode': 'configuration', 'requires_commit': True, 'allowed_params': []}
# delete/ethernet-switching-options/secure-access-port/plain => {'template': 'delete ethernet-switching-options secure-access-port interface {interface} mac-limit', 'mode': 'configuration', 'requires_commit': True, 'allowed_params': ['interface']}
# set/protocols/sflow/plain => {'template': 'set protocols sflow traceoptions flag {flag} disable', 'mode': 'configuration', 'requires_commit': True, 'allowed_params': ['flag']}
# 483 outputs/datastore_conflicts.jsonl
# {"key": "set/protocols/sflow", "variant": "plain", "existing": {"action": "set", "domain": "protocols", "sub_domain": "sflow", "template": "set protocols sflow traceoptions flag {flag} disable", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["flag"], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "candidate": {"action": "set", "domain": "protocols", "sub_domain": "sflow", "template": "set protocols sflow polling-interval 60", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "source_file": "data/processed/train.jsonl", "target_command": "set protocols sflow polling-interval 60\ncommit"}
# {"key": "set/ethernet-switching-options/secure-access-port", "variant": "plain", "existing": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "template": "set ethernet-switching-options secure-access-port vlan {vlan_name} no-examine-dhcp", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["vlan_name"], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["Disable DHCP snooping on CAM vlan", "how to set a mac limit on an interface and set the action to log on violations", "Disable IP source guard inspection on interface ge-0/0/15", "set a mac limit of 1 on all interfaces", "how to disable DHCP snooping on a vlan", "set a mac limit of 1 on all interfaces and shutdown the interface if a violation occur", "Enable ARP inspection feature on VLAN REG", "Enable DHCP snooping on the vlan with the ID 10", "Do not allow a device to change the port it is connected to more than twice a second", "Limit the number of connected devices to one on each interface on the EX3300 switch"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "candidate": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "template": "set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <limit> action log", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "source_file": "data/processed/train.jsonl", "target_command": "set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <limit> action log\ncommit"}
# {"key": "set/protocols/rstp", "variant": "plain", "existing": {"action": "set", "domain": "protocols", "sub_domain": "rstp", "template": "set protocols rstp max-age 15", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["Set the RSTP max age of received protocol BPDUs to 15", "set RSTP protocol hello interval to 4 seconds", "Set RSTP taceoptions to  trace port migration state machine", "Set RSTP taceoptions to  trace port role selection state machine", "Set RSTP taceoptions to trace port receive state machine", "Enable RSTP root-protect feature on interface ge-0/0/13", "Set RSTP taceoptions to trace topology change state machine", "Set RSTP taceoptions to trace protocol timers", "Disable RSTP port receive state machine traceoption", "Set RSTP taceoptions to  trace port role transit state machine"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "candidate": {"action": "set", "domain": "protocols", "sub_domain": "rstp", "template": "set protocols rstp hello-time 4", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "source_file": "data/processed/train.jsonl", "target_command": "set protocols rstp hello-time 4\ncommit"}
# {"key": "set/interfaces/<interface-name>", "variant": "plain", "existing": {"action": "set", "domain": "interfaces", "sub_domain": "<interface-name>", "template": "set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode access vlan {vlan_name} <vlan-name-or-id>", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["vlan_name"], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["how to assign an interface to a vlan", "How to make an interface an access port", "how to allow an interface to carry traffic from multiple vlans", "how to set IP address to an interface in Juniper ex3300", "how to disable an interface", "How to make an interface carry traffic from all vlans"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "candidate": {"action": "set", "domain": "interfaces", "sub_domain": "<interface-name>", "template": "set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode access", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "source_file": "data/processed/train.jsonl", "target_command": "set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode access\ncommit"}
# {"key": "set/protocols/rstp", "variant": "plain", "existing": {"action": "set", "domain": "protocols", "sub_domain": "rstp", "template": "set protocols rstp max-age 15", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": [], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["Set the RSTP max age of received protocol BPDUs to 15", "set RSTP protocol hello interval to 4 seconds", "Set RSTP taceoptions to  trace port migration state machine", "Set RSTP taceoptions to  trace port role selection state machine", "Set RSTP taceoptions to trace port receive state machine", "Enable RSTP root-protect feature on interface ge-0/0/13", "Set RSTP taceoptions to trace topology change state machine", "Set RSTP taceoptions to trace protocol timers", "Disable RSTP port receive state machine traceoption", "Set RSTP taceoptions to  trace port role transit state machine"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "candidate": {"action": "set", "domain": "protocols", "sub_domain": "rstp", "template": "set protocols rstp traceoptions flag {flag}", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["flag"], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": [], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain"}, "source_file": "data/processed/train.jsonl", "target_command": "set protocols rstp traceoptions flag port-migration-state-machine\ncommit"}

# %% [markdown]
# ## 7. Run Semantic RAG Unit Smoke Tests

# %%
# !pip install --upgrade torchao
# Out:
# Requirement already satisfied: torchao in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Collecting torchao
#   Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 35.5 MB/s eta 0:00:00
# Installing collected packages: torchao
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
# Successfully installed torchao-0.17.0

# %%
# !python tests/test_semantic_rag.py
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# semantic RAG smoke tests passed

# %% [markdown]
# ## 8. Train LoRA Adapter
#
# Run this if your current adapter has not been trained in this runtime. For the semantic architecture, the important thing to inspect is the semantic parser metrics below: if JSON validity is low, the adapter is still behaving like the old command-generation model and needs semantic-JSON supervised examples.

# %%
# !bash scripts/run_train.sh
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# config.json: 100% 654/654 [00:00<00:00, 3.09MB/s]
# tokenizer_config.json: 50.6kB [00:00, 104MB/s]
# tokenizer.json: 9.09MB [00:00, 28.2MB/s]
# special_tokens_map.json: 100% 73.0/73.0 [00:00<00:00, 332kB/s]
# model.safetensors.index.json: 23.9kB [00:00, 64.3MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...):  89% 14.2G/16.1G [00:39<00:06, 292MB/s]
# Downloading (incomplete total...): 100% 16.1G/16.1G [00:42<00:00, 400MB/s]
# Fetching 4 files: 100% 4/4 [00:42<00:00, 10.54s/it]
# Download complete: 100% 16.1G/16.1G [00:42<00:00, 381MB/s]
# Loading weights: 100% 291/291 [00:04<00:00, 65.62it/s]
# generation_config.json: 100% 177/177 [00:00<00:00, 996kB/s]
# Map: 100% 722/722 [00:00<00:00, 2135.95 examples/s]
# {'loss': '0.3477', 'grad_norm': '0.6891', 'learning_rate': '0.000187', 'epoch': '0.2216'}
# {'loss': '0.105', 'grad_norm': '0.7494', 'learning_rate': '0.0001725', 'epoch': '0.4432'}
# {'loss': '0.05967', 'grad_norm': '1.38', 'learning_rate': '0.000158', 'epoch': '0.6648'}
# {'loss': '0.04175', 'grad_norm': '0.1918', 'learning_rate': '0.0001435', 'epoch': '0.8864'}
# {'loss': '0.03691', 'grad_norm': '0.3708', 'learning_rate': '0.000129', 'epoch': '1.089'}
# {'loss': '0.05898', 'grad_norm': '0.3438', 'learning_rate': '0.0001145', 'epoch': '1.31'}
# {'loss': '0.03402', 'grad_norm': '0.6195', 'learning_rate': '0.0001', 'epoch': '1.532'}
# {'loss': '0.03309', 'grad_norm': '0.2428', 'learning_rate': '8.551e-05', 'epoch': '1.753'}
# {'loss': '0.01502', 'grad_norm': '0.07167', 'learning_rate': '7.101e-05', 'epoch': '1.975'}
# {'loss': '0.01288', 'grad_norm': '0.0603', 'learning_rate': '5.652e-05', 'epoch': '2.177'}
# {'loss': '0.0213', 'grad_norm': '1.133', 'learning_rate': '4.203e-05', 'epoch': '2.399'}
# {'loss': '0.01729', 'grad_norm': '0.2733', 'learning_rate': '2.754e-05', 'epoch': '2.62'}
# {'loss': '0.01938', 'grad_norm': '0.124', 'learning_rate': '1.304e-05', 'epoch': '2.842'}
# {'train_runtime': '284.8', 'train_samples_per_second': '7.605', 'train_steps_per_second': '0.485', 'train_loss': '0.05885', 'epoch': '3'}
# 100% 138/138 [04:44<00:00,  2.06s/it]

# %% [markdown]
# ## 9. Semantic RAG Smoke Inference
#
# This verifies that `--semantic_rag` writes semantic JSON, command context, assembly errors, commit decisions, and guardrail diagnostics.

# %%
import json, os
os.makedirs('data/processed', exist_ok=True)
rows = [
    {'intent': 'Display chassis LED status', 'context': '', 'target_command': 'show chassis led', 'category': 'semantic_smoke'},
    {'intent': 'Clear all MAC address entries in the ethernet switching table', 'context': '', 'target_command': 'clear ethernet-switching-table', 'category': 'semantic_smoke'},
    {'intent': 'Disable the OSPF protocol', 'context': '', 'target_command': 'set protocols ospf disable\\ncommit', 'category': 'semantic_smoke'},
]
with open('data/processed/semantic_rag_smoke.jsonl', 'w', encoding='utf-8') as f:
    for row in rows:
        f.write(json.dumps(row) + '\n')

# !mkdir -p results/predictions results/metrics results/error_analysis
# !python src/infer.py \
  --input_file data/processed/semantic_rag_smoke.jsonl \
  --output_file results/predictions/semantic_rag_smoke_predictions.jsonl \
  --semantic_rag \
  --mode intent_with_context

# !python scripts/evaluate_semantic_rag.py \
  --pred_file results/predictions/semantic_rag_smoke_predictions.jsonl \
  --out_file results/metrics/semantic_rag_smoke_metrics.json \
  --failures_file results/error_analysis/semantic_rag_smoke_failures.jsonl \
  --summary_file results/error_analysis/semantic_rag_smoke_error_summary.json

# !head -n 3 results/predictions/semantic_rag_smoke_predictions.jsonl
# !cat results/metrics/semantic_rag_smoke_metrics.json
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 60.81it/s]
#
# [INFO] Starting BATCHED inference on 3 instances for semantic_rag_smoke.jsonl...
# Batches:   0% 0/1 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches: 100% 1/1 [00:02<00:00,  2.38s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.3333333333333333,
#     "repaired_parse_rate": 0.3333333333333333,
#     "unrepaired_parse_error_rate": 0.6666666666666666,
#     "action_accuracy": 0.3333333333333333,
#     "domain_accuracy": 0.3333333333333333,
#     "sub_domain_accuracy": 0.3333333333333333,
#     "semantic_frame_exact_match": 0.3333333333333333,
#     "parameter_precision": 0.3333333333333333,
#     "parameter_recall": 0.3333333333333333,
#     "parameter_f1": 0.3333333333333333,
#     "entity_preservation": 0.6666666666666666,
#     "template_hit_rate": 0.0,
#     "correct_template_rate": 0.0,
#     "template_not_found_rate": 0.3333333333333333,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.0,
#     "missing_parameter_rate": 0.0,
#     "commit_decision_accuracy": 0.6666666666666666,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.3333333333333333,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.0,
#     "normalized_exact_match": 0.0,
#     "token_f1": 0.0,
#     "valid_rate": 0.0,
#     "bleu": 0.0,
#     "invalid_output_rate": 1.0,
#     "failure_stage_counts": {
#       "semantic_parse_error": 2,
#       "template_not_found": 1
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "show/chassis/led": 1,
#       "clear/ethernet-switching/table": 1,
#       "set/protocols/ospf": 1
#     }
#   }
# }
# {"intent": "Display chassis LED status", "context": "", "target_command": "show chassis led", "category": "semantic_smoke", "semantic_json_raw": "{\"action\":\"display chassis led status\", \"domain\":\"chassis\", \"sub_domain\":\"led\", \"parameters\":{}}\ncommit", "semantic_json": null, "semantic_parse_warnings": [], "semantic_parse_error": "invalid_enum_action", "command_context": {"found": false, "reason": "semantic_parse_error", "template_key": "", "warnings": [], "mode": "unknown", "requires_commit": false}, "context_warnings": [], "assembly_error": "semantic_parse_error", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": []}
# {"intent": "Clear all MAC address entries in the ethernet switching table", "context": "", "target_command": "clear ethernet-switching-table", "category": "semantic_smoke", "semantic_json_raw": "{\"action\":\"clear ethernet-switching table\", \"domain\":\"ethernet-switching\", \"sub_domain\":\"table\", \"parameters\":{}}\ncommit", "semantic_json": {"action": "clear", "domain": "ethernet-switching", "sub_domain": "table", "parameters": {}, "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action"], "_intent_context": "Clear all MAC address entries in the ethernet switching table "}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action"], "semantic_parse_error": null, "command_context": {"found": false, "reason": "template_not_found", "template_key": "", "action": "clear", "domain": "ethernet-switching", "sub_domain": "table", "template": "", "mode": "unknown", "requires_commit": false, "default_params": {}, "allowed_params": [], "description": "", "intent_examples": [], "negative_rules": [], "validation_rules": {}, "warnings": []}, "context_warnings": [], "assembly_error": "template_not_found", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": []}
# {"intent": "Disable the OSPF protocol", "context": "", "target_command": "set protocols ospf disable\\ncommit", "category": "semantic_smoke", "semantic_json_raw": "{\"action\":\"disable\",\"domain\":\"protocols\",\"sub_domain\":\"ospf\",\"parameters\":{}}\ncommit", "semantic_json": null, "semantic_parse_warnings": [], "semantic_parse_error": "invalid_enum_action", "command_context": {"found": false, "reason": "semantic_parse_error", "template_key": "", "warnings": [], "mode": "unknown", "requires_commit": false}, "context_warnings": [], "assembly_error": "semantic_parse_error", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": []}
# {
#   "overall": {
#     "json_valid_rate": 0.3333333333333333,
#     "repaired_parse_rate": 0.3333333333333333,
#     "unrepaired_parse_error_rate": 0.6666666666666666,
#     "action_accuracy": 0.3333333333333333,
#     "domain_accuracy": 0.3333333333333333,
#     "sub_domain_accuracy": 0.3333333333333333,
#     "semantic_frame_exact_match": 0.3333333333333333,
#     "parameter_precision": 0.3333333333333333,
#     "parameter_recall": 0.3333333333333333,
#     "parameter_f1": 0.3333333333333333,
#     "entity_preservation": 0.6666666666666666,
#     "template_hit_rate": 0.0,
#     "correct_template_rate": 0.0,
#     "template_not_found_rate": 0.3333333333333333,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.0,
#     "missing_parameter_rate": 0.0,
#     "commit_decision_accuracy": 0.6666666666666666,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.3333333333333333,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.0,
#     "normalized_exact_match": 0.0,
#     "token_f1": 0.0,
#     "valid_rate": 0.0,
#     "bleu": 0.0,
#     "invalid_output_rate": 1.0,
#     "failure_stage_counts": {
#       "semantic_parse_error": 2,
#       "template_not_found": 1
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "show/chassis/led": 1,
#       "clear/ethernet-switching/table": 1,
#       "set/protocols/ospf": 1
#     }
#   }
# }

# %% [markdown]
# ## 10. Full Semantic RAG Evaluation
#
# This runs `test.jsonl` plus `clean_test.jsonl`, `paraphrased_test.jsonl`, and `noisy_test.jsonl` if present. Metrics are written under `results/metrics/`; stage failures and summaries are written under `results/error_analysis/`.

# %%
# !scripts/run_semantic_rag_eval.sh
# !cat results/metrics/semantic_rag_metrics.json
# !cat results/error_analysis/semantic_rag_error_summary.json
# !head -n 5 results/error_analysis/semantic_rag_failures.jsonl || true
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 63.38it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:07<00:28,  7.10s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:14<00:22,  7.36s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [00:21<00:14,  7.34s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [00:28<00:06,  6.84s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:33<00:00,  6.74s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.82,
#     "repaired_parse_rate": 0.82,
#     "unrepaired_parse_error_rate": 0.18,
#     "action_accuracy": 0.82,
#     "domain_accuracy": 0.82,
#     "sub_domain_accuracy": 0.8,
#     "semantic_frame_exact_match": 0.8,
#     "parameter_precision": 0.8111111111111111,
#     "parameter_recall": 0.8111111111111111,
#     "parameter_f1": 0.8111111111111111,
#     "entity_preservation": 0.84,
#     "template_hit_rate": 0.7666666666666667,
#     "correct_template_rate": 0.7466666666666667,
#     "template_not_found_rate": 0.05333333333333334,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.6733333333333333,
#     "missing_parameter_rate": 0.09333333333333334,
#     "commit_decision_accuracy": 0.7266666666666667,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.2733333333333333,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.16666666666666666,
#     "normalized_exact_match": 0.16666666666666666,
#     "token_f1": 0.49175728025689497,
#     "valid_rate": 0.16666666666666666,
#     "bleu": 0.36006916701307745,
#     "invalid_output_rate": 0.8333333333333334,
#     "failure_stage_counts": {
#       "ok": 25,
#       "final_command_mismatch": 73,
#       "missing_parameter": 14,
#       "semantic_parse_error": 27,
#       "template_not_found": 8,
#       "wrong_template": 3
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/igmp-snooping/flows": 1,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 2,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/interface-range": 3,
#       "show/igmp-snooping/memberships": 1,
#       "delete/system/login": 2,
#       "set/interfaces/<interface-name>": 3,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "delete/protocols/rstp": 2,
#       "request/system/software": 1,
#       "start/shell/sh": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/ge-2/0/25": 1,
#       "delete/vlans/it-data": 1,
#       "show/dhcp/snooping": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "delete/protocols/sflow": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "show/|/display": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "set/interfaces/ge-1/0/12": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 60.10it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for clean_test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:07<00:28,  7.16s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:14<00:21,  7.31s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [00:22<00:14,  7.40s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [00:28<00:06,  6.94s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:33<00:00,  6.79s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.82,
#     "repaired_parse_rate": 0.82,
#     "unrepaired_parse_error_rate": 0.18,
#     "action_accuracy": 0.82,
#     "domain_accuracy": 0.82,
#     "sub_domain_accuracy": 0.8,
#     "semantic_frame_exact_match": 0.8,
#     "parameter_precision": 0.8111111111111111,
#     "parameter_recall": 0.8111111111111111,
#     "parameter_f1": 0.8111111111111111,
#     "entity_preservation": 0.84,
#     "template_hit_rate": 0.7666666666666667,
#     "correct_template_rate": 0.7466666666666667,
#     "template_not_found_rate": 0.05333333333333334,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.6733333333333333,
#     "missing_parameter_rate": 0.09333333333333334,
#     "commit_decision_accuracy": 0.7266666666666667,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.2733333333333333,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.16666666666666666,
#     "normalized_exact_match": 0.16666666666666666,
#     "token_f1": 0.49175728025689497,
#     "valid_rate": 0.16666666666666666,
#     "bleu": 0.36006916701307745,
#     "invalid_output_rate": 0.8333333333333334,
#     "failure_stage_counts": {
#       "ok": 25,
#       "final_command_mismatch": 73,
#       "missing_parameter": 14,
#       "semantic_parse_error": 27,
#       "template_not_found": 8,
#       "wrong_template": 3
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/igmp-snooping/flows": 1,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 2,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/interface-range": 3,
#       "show/igmp-snooping/memberships": 1,
#       "delete/system/login": 2,
#       "set/interfaces/<interface-name>": 3,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "delete/protocols/rstp": 2,
#       "request/system/software": 1,
#       "start/shell/sh": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/ge-2/0/25": 1,
#       "delete/vlans/it-data": 1,
#       "show/dhcp/snooping": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "delete/protocols/sflow": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "show/|/display": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "set/interfaces/ge-1/0/12": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 59.08it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for paraphrased_test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:07<00:28,  7.14s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:14<00:21,  7.27s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [00:21<00:14,  7.35s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [00:27<00:06,  6.70s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:33<00:00,  6.64s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.8333333333333334,
#     "repaired_parse_rate": 0.8333333333333334,
#     "unrepaired_parse_error_rate": 0.16666666666666666,
#     "action_accuracy": 0.8333333333333334,
#     "domain_accuracy": 0.8333333333333334,
#     "sub_domain_accuracy": 0.8133333333333334,
#     "semantic_frame_exact_match": 0.8133333333333334,
#     "parameter_precision": 0.8277777777777778,
#     "parameter_recall": 0.8277777777777778,
#     "parameter_f1": 0.8277777777777778,
#     "entity_preservation": 0.84,
#     "template_hit_rate": 0.78,
#     "correct_template_rate": 0.76,
#     "template_not_found_rate": 0.05333333333333334,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.68,
#     "missing_parameter_rate": 0.1,
#     "commit_decision_accuracy": 0.7333333333333333,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.26666666666666666,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.16666666666666666,
#     "normalized_exact_match": 0.16666666666666666,
#     "token_f1": 0.495797684297299,
#     "valid_rate": 0.16666666666666666,
#     "bleu": 0.36253516094259913,
#     "invalid_output_rate": 0.8333333333333334,
#     "failure_stage_counts": {
#       "ok": 25,
#       "final_command_mismatch": 74,
#       "missing_parameter": 15,
#       "semantic_parse_error": 25,
#       "template_not_found": 8,
#       "wrong_template": 3
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/igmp-snooping/flows": 1,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 2,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/interface-range": 3,
#       "show/igmp-snooping/memberships": 1,
#       "delete/system/login": 2,
#       "set/interfaces/<interface-name>": 3,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "delete/protocols/rstp": 2,
#       "request/system/software": 1,
#       "start/shell/sh": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/ge-2/0/25": 1,
#       "delete/vlans/it-data": 1,
#       "show/dhcp/snooping": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "delete/protocols/sflow": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "show/|/display": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "set/interfaces/ge-1/0/12": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 59.76it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for noisy_test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:05<00:22,  5.68s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:12<00:19,  6.61s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [00:20<00:14,  7.01s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [00:26<00:06,  6.52s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:31<00:00,  6.33s/it]
# {
#   "overall": {
#     "json_valid_rate": 0.8266666666666667,
#     "repaired_parse_rate": 0.8266666666666667,
#     "unrepaired_parse_error_rate": 0.17333333333333334,
#     "action_accuracy": 0.8266666666666667,
#     "domain_accuracy": 0.8266666666666667,
#     "sub_domain_accuracy": 0.8066666666666666,
#     "semantic_frame_exact_match": 0.8066666666666666,
#     "parameter_precision": 0.8177777777777778,
#     "parameter_recall": 0.8177777777777778,
#     "parameter_f1": 0.8177777777777778,
#     "entity_preservation": 0.84,
#     "template_hit_rate": 0.78,
#     "correct_template_rate": 0.76,
#     "template_not_found_rate": 0.04666666666666667,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.68,
#     "missing_parameter_rate": 0.1,
#     "commit_decision_accuracy": 0.74,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.26,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.16666666666666666,
#     "normalized_exact_match": 0.16666666666666666,
#     "token_f1": 0.49714819206266736,
#     "valid_rate": 0.16666666666666666,
#     "bleu": 0.3656105554720084,
#     "invalid_output_rate": 0.8333333333333334,
#     "failure_stage_counts": {
#       "ok": 25,
#       "final_command_mismatch": 74,
#       "missing_parameter": 15,
#       "semantic_parse_error": 26,
#       "template_not_found": 7,
#       "wrong_template": 3
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/igmp-snooping/flows": 1,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 2,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/interface-range": 3,
#       "show/igmp-snooping/memberships": 1,
#       "delete/system/login": 2,
#       "set/interfaces/<interface-name>": 3,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "delete/protocols/rstp": 2,
#       "request/system/software": 1,
#       "start/shell/sh": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/ge-2/0/25": 1,
#       "delete/vlans/it-data": 1,
#       "show/dhcp/snooping": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "delete/protocols/sflow": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "show/|/display": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "set/interfaces/ge-1/0/12": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }
# {
#   "total": 150,
#   "parse_errors": 27,
#   "template_not_found": 8,
#   "missing_parameters": 14,
#   "guardrail_modifications": 0,
#   "commit_suppressed_for_operational_action": 0,
#   "domain_equals_action": 0,
#   "sub_domain_gt_4_tokens": 0,
#   "entity_preservation_failures": 24,
#   "exact_match_failures_by_action_domain_sub_domain": {
#     "set/protocols/sflow": 6,
#     "set/ethernet-switching-options/secure-access-port": 11,
#     "set/virtual-chassis/traceoptions": 6,
#     "show/chassis/lcd": 1,
#     "set/protocols/igmp-snooping": 5,
#     "set/system/ntp": 1,
#     "set/snmp/trap-group": 2,
#     "set/protocols/rstp": 13,
#     "set/system/syslog": 7,
#     "show/igmp-snooping/flows": 1,
#     "set/protocols/igmp": 9,
#     "show/ethernet-switching/table": 2,
#     "set/snmp/community": 2,
#     "set/protocols/ospf": 4,
#     "show/cli/general": 1,
#     "load/factory-default/general": 2,
#     "clear/ethernet-switching/table": 2,
#     "set/virtual-chassis/preprovisioned": 1,
#     "show/poe/telemetries": 1,
#     "delete/system/ntp": 1,
#     "show/chassis/pic-mode": 1,
#     "show/as-path/domain": 1,
#     "set/ethernet-switching-options/mac-table-aging-time": 1,
#     "set/interfaces/interface-range": 3,
#     "show/igmp-snooping/memberships": 1,
#     "delete/system/login": 2,
#     "set/interfaces/<interface-name>": 3,
#     "set/vlans/default": 1,
#     "request/system/power-off": 1,
#     "clear/ethernet-switching/port-error": 2,
#     "set/snmp/contact": 1,
#     "delete/protocols/rstp": 2,
#     "request/system/software": 1,
#     "start/shell/sh": 1,
#     "commit/comment/\"deleted": 1,
#     "set/interfaces/ge-2/0/25": 1,
#     "delete/vlans/it-data": 1,
#     "show/dhcp/snooping": 1,
#     "set/virtual-chassis/mac-persistence-timer": 1,
#     "delete/snmp/trap-options": 1,
#     "show/configuration/|": 1,
#     "set/poe/interface": 1,
#     "delete/protocols/sflow": 1,
#     "set/chassis/auto-image-upgrade": 1,
#     "set/protocols/lldp-med": 1,
#     "show/|/compare": 2,
#     "set/virtual-chassis/no-auto-conversion": 1,
#     "clear/system/login": 1,
#     "delete/snmp/filter-duplicates": 1,
#     "set/ethernet-switching-options/storm-control": 1,
#     "show/virtual-chassis/protocol": 1,
#     "show/|/display": 1,
#     "clear/ethernet-switching/bpdu-error": 1,
#     "set/interfaces/ge-1/0/12": 1,
#     "delete/virtual-chassis/fast-failover": 1,
#     "set/ethernet-switching-options/bpdu-block": 1,
#     "delete/snmp/trap-group": 1,
#     "set/virtual-chassis/fast-failover": 1,
#     "set/ethernet-switching-options/voip": 1
#   },
#   "top_template_not_found_keys": {
#     "clear/ethernet-switching/table": 2,
#     "show/cli/general": 1,
#     "show/igmp-snooping/membership": 1,
#     "set/vlans/default": 1,
#     "start/shell/sh": 1,
#     "set/interfaces/ge-2/0/25": 1,
#     "set/interfaces/ge-1/0/12": 1
#   },
#   "top_final_command_mismatch_templates": {
#     "set/protocols/rstp": 8,
#     "set/system/syslog": 7,
#     "set/protocols/igmp": 7,
#     "set/ethernet-switching-options/secure-access-port": 4,
#     "set/virtual-chassis/traceoptions": 4,
#     "set/protocols/igmp-snooping": 4,
#     "set/protocols/sflow": 2,
#     "set/snmp/trap-group": 2,
#     "show/ethernet-switching/table": 2,
#     "load/factory-default/general": 2,
#     "delete/system/login": 2,
#     "clear/ethernet-switching/port-error": 2,
#     "show/|/compare": 2,
#     "show/chassis/lcd": 1,
#     "show/igmp-snooping/flows": 1,
#     "set/snmp/community": 1,
#     "set/virtual-chassis/preprovisioned": 1,
#     "show/chassis/pic-mode": 1,
#     "set/ethernet-switching-options/mac-table-aging-time": 1,
#     "set/interfaces/interface-range": 1
#   },
#   "examples_by_failure_stage": {
#     "final_command_mismatch": [
#       {
#         "intent": "Set sFlow taceoptions to trace all events",
#         "prediction": "set protocols sflow traceoptions flag all disable\\ncommit",
#         "target_command": "set protocols sflow traceoptions flag all\ncommit",
#         "template_key": "set/protocols/sflow",
#         "parsed_key": "set/protocols/sflow",
#         "assembly_error": null
#       },
#       {
#         "intent": "set a mac moving limit of 2 on vlan HR",
#         "prediction": "set ethernet-switching-options secure-access-port vlan HR no-examine-dhcp\\ncommit",
#         "target_command": "set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\ncommit",
#         "template_key": "set/ethernet-switching-options/secure-access-port",
#         "parsed_key": "set/ethernet-switching-options/secure-access-port",
#         "assembly_error": null
#       },
#       {
#         "intent": "Trace the virtual chassis complete sequence number (CSN) packets",
#         "prediction": "set virtual-chassis traceoptions flag csn disable\\ncommit",
#         "target_command": "set virtual-chassis traceoptions flag csn\ncommit",
#         "template_key": "set/virtual-chassis/traceoptions",
#         "parsed_key": "set/virtual-chassis/traceoptions",
#         "assembly_error": null
#       },
#       {
#         "intent": "Show LCD active menu items",
#         "prediction": "show chassis lcd",
#         "target_command": "show chassis lcd menu",
#         "template_key": "show/chassis/lcd",
#         "parsed_key": "show/chassis/lcd",
#         "assembly_error": null
#       },
#       {
#         "intent": "disable IGMP snooping routing information taceoption",
#         "prediction": "set protocols igmp-snooping traceoptions flag route disable\\ncommit",
#         "target_command": "set protocols igmp-snooping traceoptions flag route disable\ncommit",
#         "template_key": "set/protocols/igmp-snooping",
#         "parsed_key": "set/protocols/igmp-snooping",
#         "assembly_error": null
#       }
#     ],
#     "missing_parameter": [
#       {
#         "intent": "put a mac limit of 1 on interface ge-0/0/15 and log the event when the mac limit is exceeded",
#         "prediction": "",
#         "target_command": "set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\ncommit",
#         "template_key": "set/ethernet-switching-options/secure-access-port",
#         "parsed_key": "set/ethernet-switching-options/secure-access-port",
#         "assembly_error": "missing_parameter:vlan_name"
#       },
#       {
#         "intent": "Enable sFlow protocol on interface ge-0/0/8",
#         "prediction": "",
#         "target_command": "set protocols sflow interfaces ge-0/0/8\ncommit",
#         "template_key": "set/protocols/sflow",
#         "parsed_key": "set/protocols/sflow",
#         "assembly_error": "missing_parameter:flag"
#       },
#       {
#         "intent": "set the IGMP protocol expected packet loss on a subnet to 3",
#         "prediction": "",
#         "target_command": "set protocols igmp robust-count 3\ncommit",
#         "template_key": "set/protocols/igmp",
#         "parsed_key": "set/protocols/igmp",
#         "assembly_error": "missing_parameter:flag"
#       },
#       {
#         "intent": "how to disable the OSPF protocol",
#         "prediction": "",
#         "target_command": "set protocols ospf disable\ncommit",
#         "template_key": "set/protocols/ospf",
#         "parsed_key": "set/protocols/ospf",
#         "assembly_error": "missing_parameter:ip_address"
#       },
#       {
#         "intent": "how to enable ARP inspection feature on a VLAN",
#         "prediction": "",
#         "target_command": "set ethernet-switching-options secure-access-port vlan <vlan-name-or-id> arp-inspection\ncommit",
#         "template_key": "set/ethernet-switching-options/secure-access-port",
#         "parsed_key": "set/ethernet-switching-options/secure-access-port",
#         "assembly_error": "missing_parameter:vlan_name"
#       }
#     ],
#     "semantic_parse_error": [
#       {
#         "intent": "set the sflow egress sampling rate to 1000",
#         "prediction": "",
#         "target_command": "set protocols sflow sample-rate egress 1000\ncommit",
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       },
#       {
#         "intent": "help me configure ntp server on a juniper switch using command line",
#         "prediction": "",
#         "target_command": "set system ntp server <ntp-server-address>\ncommit",
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       },
#       {
#         "intent": "How to set the RSTP maximum age of received protocol BPDUs",
#         "prediction": "",
#         "target_command": "set protocols rstp max-age <max-age-interval>\ncommit",
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       },
#       {
#         "intent": "show 2 records of POE telemetry of all interfaces",
#         "prediction": "",
#         "target_command": "show poe telemetries interface all count 2",
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       },
#       {
#         "intent": "remove the configured ntp server",
#         "prediction": "",
#         "target_command": "delete system ntp server <ntp-server-address>\ncommit",
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       }
#     ],
#     "template_not_found": [
#       {
#         "intent": "Show command-line interface settings",
#         "prediction": "",
#         "target_command": "show cli",
#         "template_key": "",
#         "parsed_key": "show/cli/general",
#         "assembly_error": "template_not_found"
#       },
#       {
#         "intent": "Clear all MAC address entries in the ethernet switching table",
#         "prediction": "",
#         "target_command": "clear ethernet-switching-table",
#         "template_key": "",
#         "parsed_key": "clear/ethernet-switching/table",
#         "assembly_error": "template_not_found"
#       },
#       {
#         "intent": "Display igmp-snooping membership",
#         "prediction": "",
#         "target_command": "show igmp-snooping memberships",
#         "template_key": "",
#         "parsed_key": "show/igmp-snooping/membership",
#         "assembly_error": "template_not_found"
#       },
#       {
#         "intent": "how to tag the default vlan with vlan id of 100",
#         "prediction": "",
#         "target_command": "set vlans default vlan-id 100\ncommit",
#         "template_key": "",
#         "parsed_key": "set/vlans/default",
#         "assembly_error": "template_not_found"
#       },
#       {
#         "intent": "Clear all MAC address entries in the forwarding table",
#         "prediction": "",
#         "target_command": "clear ethernet-switching-table",
#         "template_key": "",
#         "parsed_key": "clear/ethernet-switching/table",
#         "assembly_error": "template_not_found"
#       }
#     ],
#     "wrong_template": [
#       {
#         "intent": "Show autonomous-system domains",
#         "prediction": "show as-path",
#         "target_command": "show as-path domain",
#         "template_key": "show/as-path/general",
#         "parsed_key": "show/as-path/domain",
#         "assembly_error": null
#       },
#       {
#         "intent": "how to add the comment\"deleted commit synchronize\" to the commit command",
#         "prediction": "commit comment <\"string-comment\">",
#         "target_command": "commit comment \"deleted commit synchronize\"",
#         "template_key": "commit/comment/<\"string-comment\">",
#         "parsed_key": "commit/comment/<\"string-comment\">",
#         "assembly_error": null
#       },
#       {
#         "intent": "delete the vlan with the vlan-name IT-DATA",
#         "prediction": "delete vlans <vlan-name>\\ncommit",
#         "target_command": "delete vlans IT-DATA\ncommit",
#         "template_key": "delete/vlans/<vlan-name>",
#         "parsed_key": "delete/vlans/<vlan-name>",
#         "assembly_error": null
#       }
#     ]
#   }
# }
# {
#   "overall": {
#     "json_valid_rate": 0.82,
#     "repaired_parse_rate": 0.82,
#     "unrepaired_parse_error_rate": 0.18,
#     "action_accuracy": 0.82,
#     "domain_accuracy": 0.82,
#     "sub_domain_accuracy": 0.8,
#     "semantic_frame_exact_match": 0.8,
#     "parameter_precision": 0.8111111111111111,
#     "parameter_recall": 0.8111111111111111,
#     "parameter_f1": 0.8111111111111111,
#     "entity_preservation": 0.84,
#     "template_hit_rate": 0.7666666666666667,
#     "correct_template_rate": 0.7466666666666667,
#     "template_not_found_rate": 0.05333333333333334,
#     "ambiguous_template_rate": 0.0,
#     "assembly_success_rate": 0.6733333333333333,
#     "missing_parameter_rate": 0.09333333333333334,
#     "commit_decision_accuracy": 0.7266666666666667,
#     "commit_false_positive_rate": 0.0,
#     "commit_false_negative_rate": 0.2733333333333333,
#     "guardrail_application_rate": 0.0,
#     "exact_match": 0.16666666666666666,
#     "normalized_exact_match": 0.16666666666666666,
#     "token_f1": 0.49175728025689497,
#     "valid_rate": 0.16666666666666666,
#     "bleu": 0.36006916701307745,
#     "invalid_output_rate": 0.8333333333333334,
#     "failure_stage_counts": {
#       "ok": 25,
#       "final_command_mismatch": 73,
#       "missing_parameter": 14,
#       "semantic_parse_error": 27,
#       "template_not_found": 8,
#       "wrong_template": 3
#     },
#     "exact_match_failures_by_action_domain_sub_domain": {
#       "set/protocols/sflow": 6,
#       "set/ethernet-switching-options/secure-access-port": 11,
#       "set/virtual-chassis/traceoptions": 6,
#       "show/chassis/lcd": 1,
#       "set/protocols/igmp-snooping": 5,
#       "set/system/ntp": 1,
#       "set/snmp/trap-group": 2,
#       "set/protocols/rstp": 13,
#       "set/system/syslog": 7,
#       "show/igmp-snooping/flows": 1,
#       "set/protocols/igmp": 9,
#       "show/ethernet-switching/table": 2,
#       "set/snmp/community": 2,
#       "set/protocols/ospf": 4,
#       "show/cli/general": 1,
#       "load/factory-default/general": 2,
#       "clear/ethernet-switching/table": 2,
#       "set/virtual-chassis/preprovisioned": 1,
#       "show/poe/telemetries": 1,
#       "delete/system/ntp": 1,
#       "show/chassis/pic-mode": 1,
#       "show/as-path/domain": 1,
#       "set/ethernet-switching-options/mac-table-aging-time": 1,
#       "set/interfaces/interface-range": 3,
#       "show/igmp-snooping/memberships": 1,
#       "delete/system/login": 2,
#       "set/interfaces/<interface-name>": 3,
#       "set/vlans/default": 1,
#       "request/system/power-off": 1,
#       "clear/ethernet-switching/port-error": 2,
#       "set/snmp/contact": 1,
#       "delete/protocols/rstp": 2,
#       "request/system/software": 1,
#       "start/shell/sh": 1,
#       "commit/comment/\"deleted": 1,
#       "set/interfaces/ge-2/0/25": 1,
#       "delete/vlans/it-data": 1,
#       "show/dhcp/snooping": 1,
#       "set/virtual-chassis/mac-persistence-timer": 1,
#       "delete/snmp/trap-options": 1,
#       "show/configuration/|": 1,
#       "set/poe/interface": 1,
#       "delete/protocols/sflow": 1,
#       "set/chassis/auto-image-upgrade": 1,
#       "set/protocols/lldp-med": 1,
#       "show/|/compare": 2,
#       "set/virtual-chassis/no-auto-conversion": 1,
#       "clear/system/login": 1,
#       "delete/snmp/filter-duplicates": 1,
#       "set/ethernet-switching-options/storm-control": 1,
#       "show/virtual-chassis/protocol": 1,
#       "show/|/display": 1,
#       "clear/ethernet-switching/bpdu-error": 1,
#       "set/interfaces/ge-1/0/12": 1,
#       "delete/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/bpdu-block": 1,
#       "delete/snmp/trap-group": 1,
#       "set/virtual-chassis/fast-failover": 1,
#       "set/ethernet-switching-options/voip": 1
#     }
#   }
# }{
#   "total": 150,
#   "parse_errors": 27,
#   "template_not_found": 8,
#   "missing_parameters": 14,
#   "guardrail_modifications": 0,
#   "commit_suppressed_for_operational_action": 0,
#   "domain_equals_action": 0,
#   "sub_domain_gt_4_tokens": 0,
#   "entity_preservation_failures": 24,
#   "exact_match_failures_by_action_domain_sub_domain": {
#     "set/protocols/sflow": 6,
#     "set/ethernet-switching-options/secure-access-port": 11,
#     "set/virtual-chassis/traceoptions": 6,
#     "show/chassis/lcd": 1,
#     "set/protocols/igmp-snooping": 5,
#     "set/system/ntp": 1,
#     "set/snmp/trap-group": 2,
#     "set/protocols/rstp": 13,
#     "set/system/syslog": 7,
#     "show/igmp-snooping/flows": 1,
#     "set/protocols/igmp": 9,
#     "show/ethernet-switching/table": 2,
#     "set/snmp/community": 2,
#     "set/protocols/ospf": 4,
#     "show/cli/general": 1,
#     "load/factory-default/general": 2,
#     "clear/ethernet-switching/table": 2,
#     "set/virtual-chassis/preprovisioned": 1,
#     "show/poe/telemetries": 1,
#     "delete/system/ntp": 1,
#     "show/chassis/pic-mode": 1,
#     "show/as-path/domain": 1,
#     "set/ethernet-switching-options/mac-table-aging-time": 1,
#     "set/interfaces/interface-range": 3,
#     "show/igmp-snooping/memberships": 1,
#     "delete/system/login": 2,
#     "set/interfaces/<interface-name>": 3,
#     "set/vlans/default": 1,
#     "request/system/power-off": 1,
#     "clear/ethernet-switching/port-error": 2,
#     "set/snmp/contact": 1,
#     "delete/protocols/rstp": 2,
#     "request/system/software": 1,
#     "start/shell/sh": 1,
#     "commit/comment/\"deleted": 1,
#     "set/interfaces/ge-2/0/25": 1,
#     "delete/vlans/it-data": 1,
#     "show/dhcp/snooping": 1,
#     "set/virtual-chassis/mac-persistence-timer": 1,
#     "delete/snmp/trap-options": 1,
#     "show/configuration/|": 1,
#     "set/poe/interface": 1,
#     "delete/protocols/sflow": 1,
#     "set/chassis/auto-image-upgrade": 1,
#     "set/protocols/lldp-med": 1,
#     "show/|/compare": 2,
#     "set/virtual-chassis/no-auto-conversion": 1,
#     "clear/system/login": 1,
#     "delete/snmp/filter-duplicates": 1,
#     "set/ethernet-switching-options/storm-control": 1,
#     "show/virtual-chassis/protocol": 1,
#     "show/|/display": 1,
#     "clear/ethernet-switching/bpdu-error": 1,
#     "set/interfaces/ge-1/0/12": 1,
#     "delete/virtual-chassis/fast-failover": 1,
#     "set/ethernet-switching-options/bpdu-block": 1,
#     "delete/snmp/trap-group": 1,
#     "set/virtual-chassis/fast-failover": 1,
#     "set/ethernet-switching-options/voip": 1
#   },
#   "top_template_not_found_keys": {
#     "clear/ethernet-switching/table": 2,
#     "show/cli/general": 1,
#     "show/igmp-snooping/membership": 1,
#     "set/vlans/default": 1,
#     "start/shell/sh": 1,
#     "set/interfaces/ge-2/0/25": 1,
#     "set/interfaces/ge-1/0/12": 1
#   },
#   "top_final_command_mismatch_templates": {
#     "set/protocols/rstp": 8,
#     "set/system/syslog": 7,
#     "set/protocols/igmp": 7,
#     "set/ethernet-switching-options/secure-access-port": 4,
#     "set/virtual-chassis/traceoptions": 4,
#     "set/protocols/igmp-snooping": 4,
#     "set/protocols/sflow": 2,
#     "set/snmp/trap-group": 2,
#     "show/ethernet-switching/table": 2,
#     "load/factory-default/general": 2,
#     "delete/system/login": 2,
#     "clear/ethernet-switching/port-error": 2,
#     "show/|/compare": 2,
#     "show/chassis/lcd": 1,
#     "show/igmp-snooping/flows": 1,
#     "set/snmp/community": 1,
#     "set/virtual-chassis/preprovisioned": 1,
#     "show/chassis/pic-mode": 1,
#     "set/ethernet-switching-options/mac-table-aging-time": 1,
#     "set/interfaces/interface-range": 1
#   },
#   "examples_by_failure_stage": {
#     "final_command_mismatch": [
#       {
#         "intent": "Set sFlow taceoptions to trace all events",
#         "prediction": "set protocols sflow traceoptions flag all disable\\ncommit",
#         "target_command": "set protocols sflow traceoptions flag all\ncommit",
#         "template_key": "set/protocols/sflow",
#         "parsed_key": "set/protocols/sflow",
#         "assembly_error": null
#       },
#       {
#         "intent": "set a mac moving limit of 2 on vlan HR",
#         "prediction": "set ethernet-switching-options secure-access-port vlan HR no-examine-dhcp\\ncommit",
#         "target_command": "set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\ncommit",
#         "template_key": "set/ethernet-switching-options/secure-access-port",
#         "parsed_key": "set/ethernet-switching-options/secure-access-port",
#         "assembly_error": null
#       },
#       {
#         "intent": "Trace the virtual chassis complete sequence number (CSN) packets",
#         "prediction": "set virtual-chassis traceoptions flag csn disable\\ncommit",
#         "target_command": "set virtual-chassis traceoptions flag csn\ncommit",
#         "template_key": "set/virtual-chassis/traceoptions",
#         "parsed_key": "set/virtual-chassis/traceoptions",
#         "assembly_error": null
#       },
#       {
#         "intent": "Show LCD active menu items",
#         "prediction": "show chassis lcd",
#         "target_command": "show chassis lcd menu",
#         "template_key": "show/chassis/lcd",
#         "parsed_key": "show/chassis/lcd",
#         "assembly_error": null
#       },
#       {
#         "intent": "disable IGMP snooping routing information taceoption",
#         "prediction": "set protocols igmp-snooping traceoptions flag route disable\\ncommit",
#         "target_command": "set protocols igmp-snooping traceoptions flag route disable\ncommit",
#         "template_key": "set/protocols/igmp-snooping",
#         "parsed_key": "set/protocols/igmp-snooping",
#         "assembly_error": null
#       }
#     ],
#     "missing_parameter": [
#       {
#         "intent": "put a mac limit of 1 on interface ge-0/0/15 and log the event when the mac limit is exceeded",
#         "prediction": "",
#         "target_command": "set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\ncommit",
#         "template_key": "set/ethernet-switching-options/secure-access-port",
#         "parsed_key": "set/ethernet-switching-options/secure-access-port",
#         "assembly_error": "missing_parameter:vlan_name"
#       },
#       {
#         "intent": "Enable sFlow protocol on interface ge-0/0/8",
#         "prediction": "",
#         "target_command": "set protocols sflow interfaces ge-0/0/8\ncommit",
#         "template_key": "set/protocols/sflow",
#         "parsed_key": "set/protocols/sflow",
#         "assembly_error": "missing_parameter:flag"
#       },
#       {
#         "intent": "set the IGMP protocol expected packet loss on a subnet to 3",
#         "prediction": "",
#         "target_command": "set protocols igmp robust-count 3\ncommit",
#         "template_key": "set/protocols/igmp",
#         "parsed_key": "set/protocols/igmp",
#         "assembly_error": "missing_parameter:flag"
#       },
#       {
#         "intent": "how to disable the OSPF protocol",
#         "prediction": "",
#         "target_command": "set protocols ospf disable\ncommit",
#         "template_key": "set/protocols/ospf",
#         "parsed_key": "set/protocols/ospf",
# ...
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       },
#       {
#         "intent": "show 2 records of POE telemetry of all interfaces",
#         "prediction": "",
#         "target_command": "show poe telemetries interface all count 2",
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       },
#       {
#         "intent": "remove the configured ntp server",
#         "prediction": "",
#         "target_command": "delete system ntp server <ntp-server-address>\ncommit",
#         "template_key": "",
#         "parsed_key": "//",
#         "assembly_error": "semantic_parse_error"
#       }
#     ],
#     "template_not_found": [
#       {
#         "intent": "Show command-line interface settings",
#         "prediction": "",
#         "target_command": "show cli",
#         "template_key": "",
#         "parsed_key": "show/cli/general",
#         "assembly_error": "template_not_found"
#       },
#       {
#         "intent": "Clear all MAC address entries in the ethernet switching table",
#         "prediction": "",
#         "target_command": "clear ethernet-switching-table",
#         "template_key": "",
#         "parsed_key": "clear/ethernet-switching/table",
#         "assembly_error": "template_not_found"
#       },
#       {
#         "intent": "Display igmp-snooping membership",
#         "prediction": "",
#         "target_command": "show igmp-snooping memberships",
#         "template_key": "",
#         "parsed_key": "show/igmp-snooping/membership",
#         "assembly_error": "template_not_found"
#       },
#       {
#         "intent": "how to tag the default vlan with vlan id of 100",
#         "prediction": "",
#         "target_command": "set vlans default vlan-id 100\ncommit",
#         "template_key": "",
#         "parsed_key": "set/vlans/default",
#         "assembly_error": "template_not_found"
#       },
#       {
#         "intent": "Clear all MAC address entries in the forwarding table",
#         "prediction": "",
#         "target_command": "clear ethernet-switching-table",
#         "template_key": "",
#         "parsed_key": "clear/ethernet-switching/table",
#         "assembly_error": "template_not_found"
#       }
#     ],
#     "wrong_template": [
#       {
#         "intent": "Show autonomous-system domains",
#         "prediction": "show as-path",
#         "target_command": "show as-path domain",
#         "template_key": "show/as-path/general",
#         "parsed_key": "show/as-path/domain",
#         "assembly_error": null
#       },
#       {
#         "intent": "how to add the comment\"deleted commit synchronize\" to the commit command",
#         "prediction": "commit comment <\"string-comment\">",
#         "target_command": "commit comment \"deleted commit synchronize\"",
#         "template_key": "commit/comment/<\"string-comment\">",
#         "parsed_key": "commit/comment/<\"string-comment\">",
#         "assembly_error": null
#       },
#       {
#         "intent": "delete the vlan with the vlan-name IT-DATA",
#         "prediction": "delete vlans <vlan-name>\\ncommit",
#         "target_command": "delete vlans IT-DATA\ncommit",
#         "template_key": "delete/vlans/<vlan-name>",
#         "parsed_key": "delete/vlans/<vlan-name>",
#         "assembly_error": null
#       }
#     ]
#   }
# }{"intent": "Set sFlow taceoptions to trace all events", "context": "set protocols sflow traceoptions flag all", "target_command": "set protocols sflow traceoptions flag all\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": "", "semantic_json_raw": "{\"action\":\"set protocols sflow traceoptions flag all\", \"domain\":\"set\", \"sub_domain\":\"protocols sflow traceoptions flag all\", \"parameters\":{}}\ncommit", "semantic_json": {"action": "set", "domain": "protocols", "sub_domain": "sflow", "parameters": {"flag": "all"}, "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain"], "_intent_context": "Set sFlow taceoptions to trace all events set protocols sflow traceoptions flag all"}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain"], "semantic_parse_error": null, "command_context": {"action": "set", "domain": "protocols", "sub_domain": "sflow", "template": "set protocols sflow traceoptions flag {flag} disable", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["flag"], "description": "Template inferred from data/processed/val.jsonl", "intent_examples": ["Disable sFlow traceoptions for interface events", "set the sflow polling interval to 60", "set the sflow polling interval to 30", "set the sflow ingress sampling rate to 1100", "set the source IP address to be used for the sFlow datagrams to 10.100.1.12", "how to configure the sflow polling interval", "set the sflow ingress sampling rate to 1000", "Set sFlow taceoptions to trace configuration changes", "Set sFlow taceoptions to trace rtsock events", "Set sFlow taceoptions to trace client-server events"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain", "found": true, "reason": "", "template_key": "set/protocols/sflow", "warnings": []}, "context_warnings": [], "assembly_error": null, "prediction": "set protocols sflow traceoptions flag all disable\\ncommit", "template_key": "set/protocols/sflow", "commit_added": true, "guardrails_applied": [], "failure_stage": "final_command_mismatch", "expected_template_key": "set/protocols/sflow"}
# {"intent": "set a mac moving limit of 2 on vlan HR", "context": "set ethernet-switching-options secure-access-port vlan <vlan-id-or-name> mac-move-limit <limit>", "target_command": "set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"vlan\"}", "category": "", "semantic_json_raw": "{\"action\":\"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"domain\":\"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"sub_domain\":\"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"parameters\":{}}\ncommit", "semantic_json": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "parameters": {"vlan_name": "HR", "limit": 2}, "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain"], "_intent_context": "set a mac moving limit of 2 on vlan HR set ethernet-switching-options secure-access-port vlan <vlan-id-or-name> mac-move-limit <limit>"}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain"], "semantic_parse_error": null, "command_context": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "template": "set ethernet-switching-options secure-access-port vlan {vlan_name} no-examine-dhcp", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["vlan_name"], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["Disable DHCP snooping on CAM vlan", "how to set a mac limit on an interface and set the action to log on violations", "Disable IP source guard inspection on interface ge-0/0/15", "set a mac limit of 1 on all interfaces", "how to disable DHCP snooping on a vlan", "set a mac limit of 1 on all interfaces and shutdown the interface if a violation occur", "Enable ARP inspection feature on VLAN REG", "Enable DHCP snooping on the vlan with the ID 10", "Do not allow a device to change the port it is connected to more than twice a second", "Limit the number of connected devices to one on each interface on the EX3300 switch"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain", "found": true, "reason": "", "template_key": "set/ethernet-switching-options/secure-access-port", "warnings": []}, "context_warnings": [], "assembly_error": null, "prediction": "set ethernet-switching-options secure-access-port vlan HR no-examine-dhcp\\ncommit", "template_key": "set/ethernet-switching-options/secure-access-port", "commit_added": true, "guardrails_applied": [], "failure_stage": "final_command_mismatch", "expected_template_key": "set/ethernet-switching-options/secure-access-port"}
# {"intent": "Trace the virtual chassis complete sequence number (CSN) packets", "context": "set virtual-chassis traceoptions flag csn", "target_command": "set virtual-chassis traceoptions flag csn\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": "", "semantic_json_raw": "{\"action\":\"set virtual-chassis traceoptions flag csn\", \"domain\":\"set virtual-chassis traceoptions flag csn\", \"sub_domain\":\"set virtual-chassis traceoptions flag csn\", \"parameters\":{}}\ncommit", "semantic_json": {"action": "set", "domain": "virtual-chassis", "sub_domain": "traceoptions", "parameters": {"flag": "csn"}, "_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain"], "_intent_context": "Trace the virtual chassis complete sequence number (CSN) packets set virtual-chassis traceoptions flag csn"}, "semantic_parse_warnings": ["stripped_trailing_text_after_json", "repaired_full_command_action", "inferred_domain_sub_domain"], "semantic_parse_error": null, "command_context": {"action": "set", "domain": "virtual-chassis", "sub_domain": "traceoptions", "template": "set virtual-chassis traceoptions flag {flag} disable", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["flag"], "description": "Template inferred from data/processed/val.jsonl", "intent_examples": ["Disable virtual chassis link-state packets traceoption", "Trace virtual chassis kernel events", "Disable virtual chassis SPF events traceoption", "Disable virtual chassis state transitions traceoption", "Disable virtual chassis errors traceoption", "Trace virtual chassis LSP generation", "Disable virtual chassis partial sequence number (PSN) packets traceoption", "Disable the virtual chassis dcp infrastructure configuration state traceoption", "Trace virtual chassis master election events", "Disable virtual chassis hello packets traceoption"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain", "found": true, "reason": "", "template_key": "set/virtual-chassis/traceoptions", "warnings": []}, "context_warnings": [], "assembly_error": null, "prediction": "set virtual-chassis traceoptions flag csn disable\\ncommit", "template_key": "set/virtual-chassis/traceoptions", "commit_added": true, "guardrails_applied": [], "failure_stage": "final_command_mismatch", "expected_template_key": "set/virtual-chassis/traceoptions"}
# {"intent": "put a mac limit of 1 on interface ge-0/0/15 and log the event when the mac limit is exceeded", "context": "set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <limit> action log", "target_command": "set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": "", "semantic_json_raw": "{\"action\": \"set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\", \"domain\": \"set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\", \"sub_domain\": \"set ethernet-switching-options secure-access-port interface ge-0/0/15 mac-limit 1 action log\", \"parameters\": { \"interface-name\": \"ge-0/0/15\", \"limit\": 1, \"action\": \"log\" }}", "semantic_json": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "parameters": {"interface": "ge-0/0/15", "limit": 1, "interface-name": "ge-0/0/15", "action": "log"}, "_parse_warnings": ["repaired_full_command_action", "inferred_domain_sub_domain"], "_intent_context": "put a mac limit of 1 on interface ge-0/0/15 and log the event when the mac limit is exceeded set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <limit> action log"}, "semantic_parse_warnings": ["repaired_full_command_action", "inferred_domain_sub_domain"], "semantic_parse_error": null, "command_context": {"action": "set", "domain": "ethernet-switching-options", "sub_domain": "secure-access-port", "template": "set ethernet-switching-options secure-access-port vlan {vlan_name} no-examine-dhcp", "mode": "configuration", "requires_commit": true, "default_params": {}, "allowed_params": ["vlan_name"], "description": "Template inferred from data/processed/train.jsonl", "intent_examples": ["Disable DHCP snooping on CAM vlan", "how to set a mac limit on an interface and set the action to log on violations", "Disable IP source guard inspection on interface ge-0/0/15", "set a mac limit of 1 on all interfaces", "how to disable DHCP snooping on a vlan", "set a mac limit of 1 on all interfaces and shutdown the interface if a violation occur", "Enable ARP inspection feature on VLAN REG", "Enable DHCP snooping on the vlan with the ID 10", "Do not allow a device to change the port it is connected to more than twice a second", "Limit the number of connected devices to one on each interface on the EX3300 switch"], "negative_rules": ["never_append_commit_for_operational_mode", "commit_required_only_when_requires_commit_true"], "validation_rules": {"action": "set", "mode": "configuration"}, "variant": "plain", "found": true, "reason": "", "template_key": "set/ethernet-switching-options/secure-access-port", "warnings": []}, "context_warnings": [], "assembly_error": "missing_parameter:vlan_name", "prediction": "", "template_key": "set/ethernet-switching-options/secure-access-port", "commit_added": false, "guardrails_applied": [], "failure_stage": "missing_parameter", "expected_template_key": "set/ethernet-switching-options/secure-access-port"}
# {"intent": "set the sflow egress sampling rate to 1000", "context": "set protocols sflow sample-rate egress <rate>", "target_command": "set protocols sflow sample-rate egress 1000\ncommit", "target_json": "{\"action\":\"set\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": "", "semantic_json_raw": "{\"action\": \"set protocols sflow sample-rate egress 1000\", \"domain\": \"set protocols sflow sample-rate egress\", \"sub_domain\": \"set protocols sflow sample-rate egress 1000\", \"parameters\": {\"set protocols sflow sample-rate egress 1000\"}}", "semantic_json": null, "semantic_parse_warnings": [], "semantic_parse_error": "Expecting ':' delimiter: line 1 column 232 (char 231)", "command_context": {"found": false, "reason": "semantic_parse_error", "template_key": "", "warnings": [], "mode": "unknown", "requires_commit": false}, "context_warnings": [], "assembly_error": "semantic_parse_error", "prediction": "", "template_key": "", "commit_added": false, "guardrails_applied": [], "failure_stage": "semantic_parse_error", "expected_template_key": "set/protocols/sflow"}

# %% [markdown]
# ## 11. Compare Against Legacy RAG Baseline Optional
#
# Use this only for comparison. The final architecture is `--semantic_rag` above.

# %%
# !python src/infer.py \
  --input_file data/processed/test.jsonl \
  --output_file results/predictions/rag_predictions_baseline.jsonl \
  --use_rag \
  --rag-corpus train,rag_docs
# !python src/evaluate.py \
  --pred_file results/predictions/rag_predictions_baseline.jsonl \
  --out_file results/metrics/rag_baseline_eval_metrics.json
# !cat results/metrics/rag_baseline_eval_metrics.json
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [RAG] Building index from:
# [RAG]   include data/processed/train.jsonl
# [RAG]   include rag-doc/ex3300.pdf
# [RAG]   exclude data/processed/val.jsonl
# [RAG]   exclude data/processed/test.jsonl
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 59.74it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:22<01:28, 22.17s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  40% 2/5 [00:43<01:05, 21.85s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  60% 3/5 [01:11<00:48, 24.47s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches:  80% 4/5 [01:30<00:22, 22.29s/it][transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [01:44<00:00, 20.84s/it]
# [EVAL] exact_match_accuracy: 0.1733 (26/150)
# [RAG] retrieved chunk counts:
# [RAG]   ex3300.pdf: 22
# [RAG]   train.jsonl: 728
# [RAG] top-1 source distribution:
# [RAG]   ex3300.pdf: 2
# [RAG]   train.jsonl: 148
# [RAG] top-5 source distribution:
# [RAG]   ex3300.pdf: 22
# [RAG]   train.jsonl: 728
# [RAG] wrote failure analysis to outputs/rag_failures_strict.jsonl
# {
#   "overall": {
#     "exact_match": 0.17333333333333334,
#     "normalized_exact_match": 0.5933333333333334,
#     "token_f1": 0.815645051793235,
#     "bleu": 0.6992577147882644,
#     "valid_rate": 0.17333333333333334,
#     "entity_preservation": 0.9533333333333334,
#     "invalid_output_rate": 0.8266666666666667
#   },
#   "per_category": {
#     "": {
#       "exact_match": 0.17333333333333334,
#       "normalized_exact_match": 0.5933333333333334,
#       "token_f1": 0.815645051793235,
#       "bleu": 0.6992577147882644,
#       "valid_rate": 0.17333333333333334,
#       "entity_preservation": 0.9533333333333334,
#       "invalid_output_rate": 0.8266666666666667
#     }
#   }
# }

# %% [markdown]
# ## 12. Save Results To Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/slm-kdn-results
# !cp -r results /content/drive/MyDrive/slm-kdn-results/semantic-rag-results-$(date +%Y%m%d-%H%M%S)
# !cp data/juniper_templates.json /content/drive/MyDrive/slm-kdn-results/juniper_templates-$(date +%Y%m%d-%H%M%S).json
# !ls -lh /content/drive/MyDrive/slm-kdn-results
# Out:
# Mounted at /content/drive
# total 527K
# -rw------- 1 root root 155K May 11 22:48 juniper_templates-20260511-224857.json
# -rw------- 1 root root 155K May 11 23:13 juniper_templates-20260511-231309.json
# -rw------- 1 root root 181K May 11 23:37 juniper_templates-20260511-233741.json
# drwx------ 2 root root 4.0K May 11 18:43 results-rag-20260511-184340
# drwx------ 2 root root 4.0K May 11 19:17 results-rag-20260511-191756
# drwx------ 2 root root 4.0K May 11 19:43 results-rag-20260511-194342
# drwx------ 2 root root 4.0K May 11 20:17 results-rag-20260511-201701
# drwx------ 2 root root 4.0K May 11 20:57 results-rag-20260511-205733
# drwx------ 2 root root 4.0K May 11 21:11 results-rag-20260511-211105
# drwx------ 2 root root 4.0K May 11 22:48 semantic-rag-results-20260511-224855
# drwx------ 2 root root 4.0K May 11 23:13 semantic-rag-results-20260511-231307
# drwx------ 6 root root 4.0K May 11 23:37 semantic-rag-results-20260511-233739

# %%
# !head -n 5 results/predictions/semantic_rag_predictions.jsonl | jq '.semantic_json_raw'
# Out:
# "{\"action\":\"show chassis led\", \"domain\":\"show\", \"sub_domain\":\"chassis\", \"parameters\":{}}\ncommit"
# "{\"action\":\"show configuration protocols sflow\", \"domain\":\"configuration\", \"sub_domain\":\"protocols/sflow\", \"parameters\":{}}\ncommit"
# "{\"action\":\"set protocols sflow traceoptions flag all\", \"domain\":\"set\", \"sub_domain\":\"protocols sflow traceoptions flag all\", \"parameters\":{}}\ncommit"
# "{\"action\":\"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"domain\":\"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"sub_domain\":\"set ethernet-switching-options secure-access-port vlan HR mac-move-limit 2\", \"parameters\":{}}\ncommit"
# "{\"action\":\"set virtual-chassis traceoptions flag csn\", \"domain\":\"set virtual-chassis traceoptions flag csn\", \"sub_domain\":\"set virtual-chassis traceoptions flag csn\", \"parameters\":{}}\ncommit"
