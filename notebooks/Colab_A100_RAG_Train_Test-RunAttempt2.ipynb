# %% [markdown]
# # SLM-KDN Colab Pro A100: RAG + Training + Testing
#
# Use this notebook after syncing your repo to `master`. It clones the GitHub repo, installs dependencies, checks the A100, rebuilds the RAG index over `rag-doc/ex3300.pdf`, runs retrieval smoke tests, then runs preprocess, training, inference, and evaluation.
#
# Before running: in Colab, choose **Runtime -> Change runtime type -> GPU**, then pick an A100 if available.

# %% [markdown]
# ## 1. Check GPU

# %%
# !nvidia-smi

import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("Capability:", torch.cuda.get_device_capability(0))
# Out:
# Mon May 11 19:04:24 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             42W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# CUDA available: True
# GPU: NVIDIA A100-SXM4-40GB
# Capability: (8, 0)

# %% [markdown]
# ## 2. Clone Your Repo from Master

# %%
# %cd /content
# !rm -rf slm-kdn
# !git clone --branch master https://github.com/Surya-Prasad/slm-kdn.git
# %cd /content/slm-kdn
# !git status --short
# !git rev-parse --abbrev-ref HEAD
# !git log -1 --oneline
# Out:
# /content
# Cloning into 'slm-kdn'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 151 (delta 74), reused 90 (delta 39), pack-reused 0 (from 0)
# Receiving objects: 100% (151/151), 2.74 MiB | 7.14 MiB/s, done.
# Resolving deltas: 100% (74/74), done.
# /content/slm-kdn
# master
# 76881e4 (HEAD -> master, origin/master, origin/HEAD) Merge pull request #9 from Surya-Prasad/rag-pipeline

# %% [markdown]
# ## 3. Install Dependencies
#
# This installs the project requirements. `pypdf` is required for `rag-doc/ex3300.pdf` ingestion.

# %%
# !pip install -q -r requirements.txt
# !pip install -q --upgrade transformers peft accelerate bitsandbytes datasets pypdf
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 44.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.8/338.8 kB 31.1 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 136.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 46.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 55.5 MB/s eta 0:00:00

# %% [markdown]
# ## 4. Hugging Face Login
#
# Run this if your base model requires gated access. Use a token that has access to `meta-llama/Meta-Llama-3-8B`.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## 5. Confirm EX3300 Guide Is Present

# %%
# !find rag-doc -maxdepth 2 -type f -print
# !ls -lh rag-doc/ex3300.pdf
# Out:
# rag-doc/ex3300.pdf
# -rw-r--r-- 1 root root 3.5M May 11 19:04 rag-doc/ex3300.pdf

# %% [markdown]
# ## 6. Build/Test RAG Retrieval Only
#
# This does not run training. It rebuilds `results/rag_index.pkl` and prints source file, page, score, and chunk preview.

# %%
# !python src/rag_query.py --rebuild --query "What are the front panel ports on a Juniper EX3300 switch?"
# !python src/rag_query.py --query "How do I interpret ALM SYS MST LEDs on an EX3300?" --top_k 3
# !python src/rag_query.py --query "What are the console port details for EX3300?" --top_k 3
# !python src/rag_query.py --query "What power supply information does the EX3300 guide provide?" --top_k 3
# Out:
# [RAG] Building index from:
# [RAG]   include rag-doc/ex3300.pdf
# ================================================================================
# [RAG] query: What are the front panel ports on a Juniper EX3300 switch?
# [RAG] 1. source=ex3300.pdf, page=25, score=0.5485, preview=Front Panel of an EX3300 Switch The front panel of an EX3300 switch consists of the following components: • Network ports: • Depending on the switch model, 24 or 48 10/100/1000BASE-T Gigabit Ethernet
# [RAG] 2. source=ex3300.pdf, page=26, score=0.4284, preview=Figure 2: Front Panel of an EX3300 Switch with 24 Gigabit Ethernet Ports g021217 0 1 2 3 ALM EX3300 SYS MST LCD panel Network ports Chassis status LEDs Enter buttonSFP+ uplink ports Menu button Rear P
# [RAG] 3. source=ex3300.pdf, page=5, score=0.4206, preview=EX3300 Management Cable Specifications and Pinouts | 68 Management Cable Specifications | 68 Console Port Connector Pinout Information | 69 USB Port Specifications for an EX Series Switch | 70 RJ-45 M
# [RAG] 4. source=ex3300.pdf, page=82, score=0.4132, preview=Unpacking and Mounting the EX3300 Switch IN THIS SECTION Unpacking an EX3300 Switch | 82 Parts Inventory (Packing List) for an EX3300 Switch | 83 Register Products—Mandatory to Validate SLAs | 84 Inst
# [RAG] 5. source=ex3300.pdf, page=19, score=0.4054, preview=Support for Power over Ethernet (PoE)—EX3300-24P and EX3300-48P models support the IEEE 802.3at PoE standard, also known as PoE+, delivering up to 30 watts of power per port to support networked devic
#
# [RAG] prompt:
#
# You are a network intent translation assistant. Convert the user intent into the correct Juniper Junos CLI command.
#
# Use retrieved NIT examples for command pattern matching.
# Use retrieved documentation for hardware/device-specific grounding.
# Prefer the Juniper EX3300 hardware config guide when the question is about EX3300 hardware, ports, LEDs, power, installation, interfaces, LCDs, or CLI/config behavior.
#
# Rules:
# - Output only the final CLI command.
# - Do not explain.
# - Do not include source citations in the answer.
# - If the retrieved context does not contain enough information for a CLI command, output the best command implied by the user intent and NIT examples.
#
# Retrieved NIT examples:
# None retrieved.
#
# Retrieved documentation:
# [Source: ex3300.pdf, page 25]
# Front Panel of an EX3300 Switch
# The front panel of an EX3300 switch consists of the following components:
# • Network ports:
# • Depending on the switch model, 24 or 48 10/100/1000BASE-T Gigabit Ethernet ports (ports labeled
# 0 through 23 or 0 through 47)
# • Power over Ethernet Plus (PoE+) available in all network ports in EX3300-24P and EX3300-48P models
# • Power over Ethernet Plus (PoE+) not available in any network port in EX3300-24T, EX3300-24T-DC,
# EX3300-48T, and EX3300-48T-BF models
# • Four built-in uplink ports:
# • The uplink ports support 1-gigabit small form-factor pluggable (SFP) transceivers, 10-gigabit small
# form-factor pluggable (SFP+) transceivers, or a combination of these transceivers.
# • Ports labeled 0 and 1 are, by default, configured as network ports. You can configure these ports as
# Virtual Chassis ports (VCPs).
# • Ports labeled 2 and 3 are, by default, configured as VCPs. You can configure these ports as network
# ports.
# • Network port and uplink port LEDs
# • Three chassis status LEDs
# • LCD panel and the LCD navigation buttons
# • Air intake or air exhaust, depending on the switch model—The intake or exhaust is located immediately
# below the top edge of the front panel.
# Figure 1 on page 25 shows the front panel of an EX3300 switch with 48 Gigabit Ethernet ports.
# Figure 2 on page 26 shows the front panel of an EX3300 switch with 24 Gigabit Ethernet ports.
# Figure 1: Front Panel of an EX3300 Switch with 48 Gigabit Ethernet Ports
# g021216
# 0 1 2 3
# ALM
# EX3300 PoE+
# SYS
# MST
# LCD panel
# Network ports
# Chassis
# status
# LEDs
# Enter buttonSFP+ uplink ports
# Menu button
# 25
#
# ---
#
# [Source: ex3300.pdf, page 26]
# Figure 2: Front Panel of an EX3300 Switch with 24 Gigabit Ethernet Ports
# g021217
# 0 1 2 3
# ALM
# EX3300
# SYS
# MST
# LCD panel
# Network ports
# Chassis
# status
# LEDs
# Enter buttonSFP+ uplink ports
# Menu button
# Rear Panel of an EX3300 Switch
# The rear panel of the EX3300 switch consists of the following components:
# • Management Ethernet port
# • USB port
# • Console port
# • Protective earthing terminal
# • Redundant power system (RPS) port
# • ESD point
# • Air intake or air exhaust, depending on the switch model
# • Serial number ID label
# • AC power cord inlet or DC power terminal block
# Figure 3 on page 26 shows the rear panel of an EX3300 switch with AC power supply.
# The power cord retainer extends out of the chassis by 3 in. (7.62 cm).
# Figure 3: Rear Panel of an EX3300 Switch with an AC Power Supply
# AC power
# cord inlet
# Air exhaust
# with fan
# Serial number
# ID label
# USB
# port
# Management
# Ethernet port
# Console RPS
# portport
# Protective
# earthing terminal
# ESD
# point
# g021202
# Figure 4 on page 27 shows the rear panel of an EX3300 switch with DC power supply.
# 26
#
# ---
#
# [Source: ex3300.pdf, page 5]
# EX3300 Management Cable Specifications and Pinouts | 68
# Management Cable Specifications | 68
# Console Port Connector Pinout Information | 69
# USB Port Specifications for an EX Series Switch | 70
# RJ-45 Management Port Connector Pinout Information | 70
# RJ-45 Port, SFP Port, SFP+ Port, QSFP+ Port, and QSFP28 Port Connector Pinout
# Information | 71
# RJ-45 to DB-9 Serial Port Adapter Pinout Information | 76
# EX3300 Virtual Chassis | 77
# Planning EX3300 Virtual Chassis | 77
# Understanding EX3300 Virtual Chassis Hardware Configuration | 78
# Virtual Chassis Cabling Configuration Examples for EX3300 Switches | 78
# Initial Installation and Configuration
# 3
# Unpacking and Mounting the EX3300 Switch | 82
# Unpacking an EX3300 Switch | 82
# Parts Inventory (Packing List) for an EX3300 Switch | 83
# Register Products—Mandatory to Validate SLAs | 84
# Installing and Connecting an EX3300 Switch | 85
# Mounting an EX3300 Switch | 86
# Mounting an EX3300 Switch on a Desk or Other Level Surface | 86
# Mounting an EX3300 Switch on Two Posts in a Rack or Cabinet | 87
# Mounting an EX3300 Switch on Four Posts in a Rack or Cabinet | 90
# Mounting an EX3300 Switch in a Recessed Position in a Rack or Cabinet | 93
# Mounting an EX3300 Switch on a Wall | 94
# Connecting the EX3300 to Power | 97
# Connect Earth Ground to an EX Series Switch | 97
# Parts and Tools Required for Connecting an EX Series Switch to Earth Ground | 98
# Special Instructions to Follow Before Connecting Earth Ground to an EX Series Switch | 102
# Connecting Earth Ground to an EX Series Switch | 103
# Connecting AC Power to an EX3300 Switch | 104
# Connecting DC Power to an EX3300 Switch | 106
# v
#
# ---
#
# [Source: ex3300.pdf, page 82]
# Unpacking and Mounting the EX3300 Switch
# IN THIS SECTION
# Unpacking an EX3300 Switch | 82
# Parts Inventory (Packing List) for an EX3300 Switch | 83
# Register Products—Mandatory to Validate SLAs | 84
# Installing and Connecting an EX3300 Switch | 85
# Mounting an EX3300 Switch | 86
# Mounting an EX3300 Switch on a Desk or Other Level Surface | 86
# Mounting an EX3300 Switch on Two Posts in a Rack or Cabinet | 87
# Mounting an EX3300 Switch on Four Posts in a Rack or Cabinet | 90
# Mounting an EX3300 Switch in a Recessed Position in a Rack or Cabinet | 93
# Mounting an EX3300 Switch on a Wall | 94
# Unpacking an EX3300 Switch
# The EX3300 switches are shipped in a cardboard carton, secured with foam packing material. The carton
# also contains an accessory box.
# CAUTION: EX3300 switches are maximally protected inside the shipping carton. Do
# not unpack the switches until you are ready to begin installation.
# To unpack the switch:
# 1. Move the shipping carton to a staging area as close to the installation site as possible, but where you
# have enough room to remove the system components.
# 2. Position the carton so that the arrows are pointing up.
# 3. Open the top flaps on the shipping carton.
# 4. Remove the accessory box and verify the contents in it against the parts inventory on the label attached
# to the carton.
# 82
#
# ---
#
# [Source: ex3300.pdf, page 19]
# Support for Power over Ethernet (PoE)—EX3300-24P and EX3300-48P models support the IEEE 802.3at
# PoE standard, also known as PoE+, delivering up to 30 watts of power per port to support networked
# devices such as telephones, video cameras, IEEE 802.11n wireless LAN (WLAN) access points, and video
# phones.
# EX3300 Switches First View
# EX3300 switches provide:
# • Either 24 or 48 built-in network ports with 10/100/1000BASE-T Gigabit Ethernet connectors (ports
# labeled 0 through 23 or 0 through 47)
# • Four uplink ports (ports labeled 0 through 3)
# • Virtual Chassis capability—You can connect up to ten EX3300 switches together to form one unit that
# you manage as a single chassis, called a Virtual Chassis.
# • Power over Ethernet Plus (PoE+) on all network ports (in PoE+-capable models only)
# Uplink Ports
# Each EX3300 switch has four autosensing uplink ports. You can use the uplink ports on the switch to:
# • Connect an access switch to a distribution switch
# • Interconnect member switches of a Virtual Chassis
# The uplink ports labeled 0 and 1 (interfaces ge-0/1/0 and ge-0/1/1 or xe-0/1/0 and xe-0/1/1) are
# configuredby default as network ports. To use uplink ports 0 and 1 to interconnectVirtual Chassis members,
# you must configure them as Virtual Chassis ports (VCPs).
# The uplink ports labeled 2 and 3 (interfaces ge-0/1/2 and ge-0/1/3 or xe-0/1/2 and xe-0/1/3) are
# configured by default as VCPs. You can use these uplink ports to interconnect Virtual Chassis members.
# To use uplink ports 2 and 3 as network ports, you must configure them as network ports.
# The uplink ports support SFP and SFP+ transceivers. For a list of supported transceivers, see “Pluggable
# Transceivers Supported on EX3300 Switches” on page 61.
# Power over Ethernet Plus Ports
# EX3300 switches are available in models with or without PoE+ capability. Models that support PoE+
# provide that support on all network ports.
# PoE+ ports provide electrical current to devices—such as IP phones, wireless access points, and security
# cameras—through network cables, thus eliminating the need for separate power cords for those devices.
# 19
#
# Question:
# What are the front panel ports on a Juniper EX3300 switch?
#
# Answer:
#
#
# [RAG] final answer preview:
#
# From ex3300.pdf, page 25: Front Panel of an EX3300 Switch The front panel of an EX3300 switch consists of the following components: • Network ports: • Depending on the switch model, 24 or 48 10/100/1000BASE-T Gigabit Ethernet ports (ports labeled 0 through 23 or 0 through 47) • Power over Ethernet Plus (PoE+) available in all network ports in EX3300-24P and EX3300-48P models • Power over Ethernet Plus (PoE+) not available in any network port in EX3300-24T, EX3300-24T-DC, EX3300-48T, and EX3300-48T-BF models • Four built-in uplink ports: • The uplink ports support 1-gigabit small form-factor pluggable (SFP) transceivers, 10-gigabit small form-factor pluggable (SFP+) transceivers, or a combination of these transceivers. • Ports labeled 0 and 1 are, by default, configured as network ports. You can configure these ports as Virtual Chassis ports (VCPs). • Ports labeled 2 and 3 are, by default, configured as VCPs. You
# ================================================================================
# [RAG] query: How do I interpret ALM SYS MST LEDs on an EX3300?
# [RAG] 1. source=ex3300.pdf, page=34, score=0.8408, preview=Table 7: Chassis Status LEDs in an EX3300 Switch State and DescriptionColorLED Label There is no alarm or the switch is halted.UnlitALM (Alarm) There is a major alarm. NOTE: When you connect power to
# [RAG] 2. source=ex3300.pdf, page=33, score=0.6321, preview=Table 6: LCD Panel Menu Options (continued) DescriptionMenu If you do not want users to use Maintenance menu options, disable the entire menu or individual menu options. See “Configuring the LCD Panel
# [RAG] 3. source=ex3300.pdf, page=183, score=0.3869, preview=Table 53: Chassis Component Alarm Conditions on EX3300 Switches (continued) RemedyAlarm SeverityAlarm ConditionChassis Component Clean up the system file storage space on the switch. For more informat
#
# [RAG] prompt:
#
# You are a network intent translation assistant. Convert the user intent into the correct Juniper Junos CLI command.
#
# Use retrieved NIT examples for command pattern matching.
# Use retrieved documentation for hardware/device-specific grounding.
# Prefer the Juniper EX3300 hardware config guide when the question is about EX3300 hardware, ports, LEDs, power, installation, interfaces, LCDs, or CLI/config behavior.
#
# Rules:
# - Output only the final CLI command.
# - Do not explain.
# - Do not include source citations in the answer.
# - If the retrieved context does not contain enough information for a CLI command, output the best command implied by the user intent and NIT examples.
#
# Retrieved NIT examples:
# None retrieved.
#
# Retrieved documentation:
# [Source: ex3300.pdf, page 34]
# Table 7: Chassis Status LEDs in an EX3300 Switch
# State and DescriptionColorLED Label
# There is no alarm or the switch is halted.UnlitALM (Alarm)
# There is a major alarm.
# NOTE: When you connect power to the switch, the Alarm
# (ALM) LED lights red. This behavior is normal. Plugging
# an active Ethernet cable into the management (MGMT)
# port on the switch completes the network link and turns
# off the ALM LED. (See “Connect a Device to a Network
# for Out-of-Band Management” on page 110.)
# Connecting the switch to a dedicated management
# console instead of a network does not affect the ALM
# LED. The LED remains red until the switch is connected
# to a network.
# Red
# There is a minor alarm.
# NOTE: The Alarm (ALM) LED lights amber if you commit
# a configuration to make it active on the switch and do not
# also create a rescue configuration to back it up. To save
# the most recently committed configuration as the rescue
# configuration, enter the operational mode command
# request system configuration rescue save.
# Amber
# • On steadily—Junos OS for EX Series switches has been
# loaded on the switch.
# • Blinking—The switch is booting.
# • Off—The switch is powered off or is halted.
# GreenSYS (System)
# In a standalone EX3300 switch:
# • On steadily—The switch is functioning normally.
# • Off—The switch is powered off or is halted.
# In a Virtual chassis configuration:
# • On steadily—The switch is the primary in the Virtual
# Chassis configuration.
# • Blinking—Theswitch is the backup in the Virtual Chassis
# configuration.
# • Off—The switch is a linecard member in the Virtual
# Chassis configuration or is halted.
# GreenMST (Primary)
# 34
#
# ---
#
# [Source: ex3300.pdf, page 33]
# Table 6: LCD Panel Menu Options (continued)
# DescriptionMenu
# If you do not want users to use Maintenance menu options, disable the entire menu or individual
# menu options. See “Configuring the LCD Panel on EX Series Switches (CLI Procedure)” on page 129.
# SEE ALSO
# Connecting and Configuring an EX Series Switch (CLI Procedure) | 121
# Chassis Status LEDs in EX3300 Switches
# The front panel of an EX3300 switch has three chassis status LEDs labeled ALM, SYS, and MST on the far
# right side of the panel, above the uplink ports (see Figure 6 on page 33).
# You can view the colors of the LEDs remotely through the CLI by issuing the operational mode command
# show chassis lcd.
# Figure 6: Chassis Status LEDs in an EX3300 Switch
# Table 7 on page 34 describes the chassis status LEDs in an EX3300 switch, their colors and states, and
# the status they indicate.
# 33
#
# ---
#
# [Source: ex3300.pdf, page 183]
# Table 53: Chassis Component Alarm Conditions on EX3300 Switches (continued)
# RemedyAlarm SeverityAlarm ConditionChassis Component
# Clean up the system file
# storage space on the
# switch. For more
# information, see Freeing Up
# System Storage Space.
# Minor (yellow)/var partition usage is
# high.
# Routing Engine
# Clean up the system file
# storage space on the
# switch. For more
# information, see Freeing Up
# System Storage Space.
# Major (red)/var partition is full.
# Use the request system
# configuration rescue save
# command to set the rescue
# configuration.
# Minor (yellow)Rescue configuration is
# not set.
# Install the required license
# for the feature specified in
# the alarm. For more
# information, see
# Understanding Software
# Licenses for EX Series
# Switches.
# Minor (yellow)Feature usage requires a
# license or the license for
# the feature usage has
# expired.
# SEE ALSO
# Chassis Status LEDs in EX3300 Switches | 33
# Check Active Alarms with the J-Web Interface
# Purpose
# NOTE: This topic applies only to the J-Web Application package.
# 183
#
# Question:
# How do I interpret ALM SYS MST LEDs on an EX3300?
#
# Answer:
#
#
# [RAG] final answer preview:
#
# From ex3300.pdf, page 34: Table 7: Chassis Status LEDs in an EX3300 Switch State and DescriptionColorLED Label There is no alarm or the switch is halted.UnlitALM (Alarm) There is a major alarm. NOTE: When you connect power to the switch, the Alarm (ALM) LED lights red. This behavior is normal. Plugging an active Ethernet cable into the management (MGMT) port on the switch completes the network link and turns off the ALM LED. (See “Connect a Device to a Network for Out-of-Band Management” on page 110.) Connecting the switch to a dedicated management console instead of a network does not affect the ALM LED. The LED remains red until the switch is connected to a network. Red There is a minor alarm. NOTE: The Alarm (ALM) LED lights amber if you commit a configuration to make it active on the switch and do not also create a rescue configuration to back it up. To save the most recently committed configuration as the re
# ================================================================================
# [RAG] query: What are the console port details for EX3300?
# [RAG] 1. source=ex3300.pdf, page=69, score=0.6350, preview=Table 24: Specifications of Cables to Connect to Management Devices (continued) Additional InformationReceptacleCable SpecificationsPorts “Connect a Device to a Network for Out-of-Band Management” on
# [RAG] 2. source=ex3300.pdf, page=5, score=0.5781, preview=EX3300 Management Cable Specifications and Pinouts | 68 Management Cable Specifications | 68 Console Port Connector Pinout Information | 69 USB Port Specifications for an EX Series Switch | 70 RJ-45 M
# [RAG] 3. source=ex3300.pdf, page=68, score=0.5304, preview=(13 dBm) – (0.5 dBm [HOL]) – ((5) * (0.5 dBm)) – ((2) * (0.5 dBm)) – ((2 km) * (1.0 dBm/km)) – (1 dB [CRM]) = P M 13 dBm – 0.5 dBm – 2.5 dBm – 1 dBm – 2 dBm – 1 dBm = P M P M = 6 dBm The calculated po
#
# [RAG] prompt:
#
# You are a network intent translation assistant. Convert the user intent into the correct Juniper Junos CLI command.
#
# Use retrieved NIT examples for command pattern matching.
# Use retrieved documentation for hardware/device-specific grounding.
# Prefer the Juniper EX3300 hardware config guide when the question is about EX3300 hardware, ports, LEDs, power, installation, interfaces, LCDs, or CLI/config behavior.
#
# Rules:
# - Output only the final CLI command.
# - Do not explain.
# - Do not include source citations in the answer.
# - If the retrieved context does not contain enough information for a CLI command, output the best command implied by the user intent and NIT examples.
#
# Retrieved NIT examples:
# None retrieved.
#
# Retrieved documentation:
# [Source: ex3300.pdf, page 69]
# Table 24: Specifications of Cables to Connect to Management Devices (continued)
# Additional InformationReceptacleCable SpecificationsPorts
# “Connect a Device to a
# Network for Out-of-Band
# Management” on page 110
# RJ-45Ethernet cable with an
# RJ-45 connector
# Management Ethernet port
# Mini-USBMini-USB cable with
# standard-A and Mini-USB
# Type-B (5-pin) connector
# Mini-USB Type-B Console
# port
# Console Port Connector Pinout Information
# The console port on a Juniper Networks device is an RS-232 serial interface that uses an RJ-45 connector
# to connect to a console management device. The default baud rate for the console port is 9600 baud.
# Table 25 on page 69 provides the pinout information for the RJ-45 console connector.
# NOTE: If your laptop or desktop PC does not have a DB-9 plug connector pin and you want to
# connect your laptop or desktop PC directly to a device, use a combination of the RJ-45 to DB-9
# socket adapter and a USB to DB-9 plug adapter. You must provide the USB to DB-9 plug adapter.
# Table 25: Console Port Connector Pinout Information
# DescriptionSignalPin
# Request to sendRTS Output1
# Data terminal readyDTR Output2
# Transmit dataTxD Output3
# Signal groundSignal Ground4
# Signal groundSignal Ground5
# Receive dataRxD Input6
# Data carrier detectCD Input7
# 69
#
# ---
#
# [Source: ex3300.pdf, page 5]
# EX3300 Management Cable Specifications and Pinouts | 68
# Management Cable Specifications | 68
# Console Port Connector Pinout Information | 69
# USB Port Specifications for an EX Series Switch | 70
# RJ-45 Management Port Connector Pinout Information | 70
# RJ-45 Port, SFP Port, SFP+ Port, QSFP+ Port, and QSFP28 Port Connector Pinout
# Information | 71
# RJ-45 to DB-9 Serial Port Adapter Pinout Information | 76
# EX3300 Virtual Chassis | 77
# Planning EX3300 Virtual Chassis | 77
# Understanding EX3300 Virtual Chassis Hardware Configuration | 78
# Virtual Chassis Cabling Configuration Examples for EX3300 Switches | 78
# Initial Installation and Configuration
# 3
# Unpacking and Mounting the EX3300 Switch | 82
# Unpacking an EX3300 Switch | 82
# Parts Inventory (Packing List) for an EX3300 Switch | 83
# Register Products—Mandatory to Validate SLAs | 84
# Installing and Connecting an EX3300 Switch | 85
# Mounting an EX3300 Switch | 86
# Mounting an EX3300 Switch on a Desk or Other Level Surface | 86
# Mounting an EX3300 Switch on Two Posts in a Rack or Cabinet | 87
# Mounting an EX3300 Switch on Four Posts in a Rack or Cabinet | 90
# Mounting an EX3300 Switch in a Recessed Position in a Rack or Cabinet | 93
# Mounting an EX3300 Switch on a Wall | 94
# Connecting the EX3300 to Power | 97
# Connect Earth Ground to an EX Series Switch | 97
# Parts and Tools Required for Connecting an EX Series Switch to Earth Ground | 98
# Special Instructions to Follow Before Connecting Earth Ground to an EX Series Switch | 102
# Connecting Earth Ground to an EX Series Switch | 103
# Connecting AC Power to an EX3300 Switch | 104
# Connecting DC Power to an EX3300 Switch | 106
# v
#
# ---
#
# [Source: ex3300.pdf, page 68]
# (13 dBm) – (0.5 dBm [HOL]) – ((5) * (0.5 dBm)) – ((2) * (0.5 dBm)) – ((2 km) * (1.0 dBm/km)) – (1 dB
# [CRM]) = P
# M
# 13 dBm – 0.5 dBm – 2.5 dBm – 1 dBm – 2 dBm – 1 dBm = P
# M
# P
# M
# = 6 dBm
# The calculated power margin is greater than zero, indicating that the link has sufficient power for
# transmission. Also, the power margin value does not exceed the maximum receiver input power. Refer
# to the specification for your receiver to find the maximum receiver input power.
# EX3300ManagementCableSpecificationsand Pinouts
# IN THIS SECTION
# Management Cable Specifications | 68
# Console Port Connector Pinout Information | 69
# USB Port Specifications for an EX Series Switch | 70
# RJ-45 Management Port Connector Pinout Information | 70
# RJ-45 Port, SFP Port, SFP+ Port, QSFP+ Port, and QSFP28 Port Connector Pinout Information | 71
# RJ-45 to DB-9 Serial Port Adapter Pinout Information | 76
# Management Cable Specifications
# Table 24 on page 68 lists the specifications for the cables that connect the console and management ports
# to management devices.
# Table 24: Specifications of Cables to Connect to Management Devices
# Additional InformationReceptacleCable SpecificationsPorts
# “Connect a Device to a
# ManagementConsoleUsing
# an RJ-45 Connector” on
# page 110
# RJ-45CAT5e UTP (unshielded
# twisted pair) cable
# RJ-45 Console port
# 68
#
# Question:
# What are the console port details for EX3300?
#
# Answer:
#
#
# [RAG] final answer preview:
#
# From ex3300.pdf, page 69: Table 24: Specifications of Cables to Connect to Management Devices (continued) Additional InformationReceptacleCable SpecificationsPorts “Connect a Device to a Network for Out-of-Band Management” on page 110 RJ-45Ethernet cable with an RJ-45 connector Management Ethernet port Mini-USBMini-USB cable with standard-A and Mini-USB Type-B (5-pin) connector Mini-USB Type-B Console port Console Port Connector Pinout Information The console port on a Juniper Networks device is an RS-232 serial interface that uses an RJ-45 connector to connect to a console management device. The default baud rate for the console port is 9600 baud. Table 25 on page 69 provides the pinout information for the RJ-45 console connector. NOTE: If your laptop or desktop PC does not have a DB-9 plug connector pin and you want to connect your laptop or desktop PC directly to a device, use a combination of the RJ-45 to DB-
# ================================================================================
# [RAG] query: What power supply information does the EX3300 guide provide?
# [RAG] 1. source=ex3300.pdf, page=44, score=0.5749, preview=Power Specifications for EX3300 Switches This topic describes the power supply electrical specifications for EX3300 switches. Table 15 on page 44 provides the AC power supply electrical specifications
# [RAG] 2. source=ex3300.pdf, page=109, score=0.5741, preview=a. Secure the ring lug of the positive (+) DC power source cable from the first DC power source to the A+ terminal on the power supply. b. Secure the ring lug of the negative (–) DC power source cable
# [RAG] 3. source=ex3300.pdf, page=23, score=0.5337, preview=Table 4: CLI Equivalents of Terms Used in Documentation for EX3300 Switches (continued) Additional Information Item in Documentation Value (Field as Displayed in CLI) Description (Field as Displayed i
#
# [RAG] prompt:
#
# You are a network intent translation assistant. Convert the user intent into the correct Juniper Junos CLI command.
#
# Use retrieved NIT examples for command pattern matching.
# Use retrieved documentation for hardware/device-specific grounding.
# Prefer the Juniper EX3300 hardware config guide when the question is about EX3300 hardware, ports, LEDs, power, installation, interfaces, LCDs, or CLI/config behavior.
#
# Rules:
# - Output only the final CLI command.
# - Do not explain.
# - Do not include source citations in the answer.
# - If the retrieved context does not contain enough information for a CLI command, output the best command implied by the user intent and NIT examples.
#
# Retrieved NIT examples:
# None retrieved.
#
# Retrieved documentation:
# [Source: ex3300.pdf, page 44]
# Power Specifications for EX3300 Switches
# This topic describes the power supply electrical specifications for EX3300 switches.
# Table 15 on page 44 provides the AC power supply electrical specifications for EX3300 switches.
# Table 16 on page 44 provides the DC power supply electrical specifications for EX3300 switches.
# Table 15: AC Power Supply Electrical Specifications for EX3300 Switches
# SpecificationItem
# 100 through 240 VACAC input voltage
# 50 Hz/60 Hz nominalAC input line frequency
# • 7 A at 100 VAC and 2.9 A at 230 VAC (for switches with ports enabled
# for PoE)
# • 1.8 A at 100 VAC and 0.5 A at 230 VAC (for switches with no ports
# enabled for PoE)
# AC system current rating
# Table 16: DC Power Supply Electrical Specifications for EX3300 Switches
# SpecificationItem
# -43 through -75 VDCDC input voltage
# 2 A maximumDC input current
# 100 WPower supply output
# 1 ms minimumOutput holdup time
# NOTE: For DC power supplies, we recommend that you provide at least 2.5 A at 48 VDC and
# use a facility circuit breaker rated for 10 A minimum. Doing so enables you to operate the switch
# in any configurationwithout upgrading the power infrastructure,and allows the switch to function
# at full capacity using multiple power supplies.
# 44
#
# ---
#
# [Source: ex3300.pdf, page 109]
# a. Secure the ring lug of the positive (+) DC power source cable from the first DC power source to
# the A+ terminal on the power supply.
# b. Secure the ring lug of the negative (–) DC power source cable from the first DC power source to
# the A– terminal on the power supply.
# c. Secure the ring lug of the positive (+) DC power source cable from the second DC power source
# to the B+ terminal on the power supply.
# d. Secure the ring lug of the negative (–) DC power source cable from the second DC power source
# to the B– terminal on the power supply.
# e. Tighten the screws on the power supply terminals on both the power supplies until snug by using
# the screwdriver. Do not overtighten—apply between 8 in.-lb (0.9 Nm) and 9 in.-lb (1.02 Nm) of
# torque to the screws.
# 5. Hook the plastic cover on one side of the terminal block and gently flex it inward to hook it on the
# other side also.
# 6. Close the input circuit breaker.
# SEE ALSO
# Connecting and Configuring an EX Series Switch (CLI Procedure) | 121
# Power Supply in EX3300 Switches | 43
# Connecting the EX3300 to External Devices
# IN THIS SECTION
# Connect a Device to a Network for Out-of-Band Management | 110
# Connect a Device to a Management Console Using an RJ-45 Connector | 110
# 109
#
# ---
#
# [Source: ex3300.pdf, page 23]
# Table 4: CLI Equivalents of Terms Used in Documentation for EX3300 Switches (continued)
# Additional Information
# Item in
# Documentation
# Value (Field as
# Displayed in
# CLI)
# Description
# (Field as
# Displayed in
# CLI)
# Hardware
# Item (Field as
# Displayed in
# CLI)
# Understanding Interface Naming
# Conventions
# The switch does
# not have actual
# PIC devices; see
# entries for PIC 0
# through PIC 1
# for the
# equivalent item
# on the switch.
# n is a value in
# the range of
# 0–1.
# Abbreviated
# name of the
# Physical
# Interface Card
# (PIC)
# PIC (n)
# “Front Panel of an EX3300 Switch” on
# page 25
# Built-innetwork
# ports on the
# front panel of
# the switch
# PIC 0One of the
# following:
# • 24x
# 10/100/1000
# BASE-T
# • 48x
# 10/100/1000
# BASE-T
# “Front Panel of an EX3300 Switch” on
# page 25
# Built-in uplink
# ports on the
# front panel of
# the switch
# PIC 14x GE/XE SFP+
# “Pluggable Transceivers Supported on
# EX3300 Switches” on page 61
# Optical
# transceivers
# n is a value
# equivalent to
# the number of
# the port in
# which the
# transceiver is
# installed.
# Abbreviated
# name of the
# transceiver
# Xcvr (n)
# “Power Supply in EX3300 Switches” on
# page 43
# Power supplyValue of n is
# always 0.
# Built-in power
# supply
# Power Supply
# (n)
# “EX3300 Cooling System” on page 39Fan tray–Built-in fan trayFan Tray
# 23
#
# Question:
# What power supply information does the EX3300 guide provide?
#
# Answer:
#
#
# [RAG] final answer preview:
#
# From ex3300.pdf, page 44: Power Specifications for EX3300 Switches This topic describes the power supply electrical specifications for EX3300 switches. Table 15 on page 44 provides the AC power supply electrical specifications for EX3300 switches. Table 16 on page 44 provides the DC power supply electrical specifications for EX3300 switches. Table 15: AC Power Supply Electrical Specifications for EX3300 Switches SpecificationItem 100 through 240 VACAC input voltage 50 Hz/60 Hz nominalAC input line frequency • 7 A at 100 VAC and 2.9 A at 230 VAC (for switches with ports enabled for PoE) • 1.8 A at 100 VAC and 0.5 A at 230 VAC (for switches with no ports enabled for PoE) AC system current rating Table 16: DC Power Supply Electrical Specifications for EX3300 Switches SpecificationItem -43 through -75 VDCDC input voltage 2 A maximumDC input current 100 WPower supply output 1 ms minimumOutput holdup time NOTE: For DC

# %% [markdown]
# ## 7. Preprocess NIT Dataset
#
# This preserves the original NIT pipeline and creates `data/processed/*.jsonl` files.

# %%
# !bash scripts/run_preprocess.sh
# !find data/processed -maxdepth 1 -type f -print | sort
# !head -n 1 data/processed/test.jsonl
# Out:
# README.md: 4.31kB [00:00, 5.53MB/s]
# NIT_dataset.json: 273kB [00:00, 163MB/s]
# Generating train split: 100% 1000/1000 [00:00<00:00, 114617.26 examples/s]
# data/processed/clean_test.jsonl
# data/processed/noisy_test.jsonl
# data/processed/paraphrased_test.jsonl
# data/processed/test_intent_only.jsonl
# data/processed/test_intent_with_context.jsonl
# data/processed/test.jsonl
# data/processed/train_intent_only.jsonl
# data/processed/train_intent_with_context.jsonl
# data/processed/train.jsonl
# data/processed/val_intent_only.jsonl
# data/processed/val_intent_with_context.jsonl
# data/processed/val.jsonl
# {"intent": "How to display the LED status", "context": "show chassis led", "target_command": "show chassis led", "target_json": "{\"action\":\"show\",\"parameters\":{\"prefix\":\"\",\"unit\":0,\"vlan_id\":null,\"vlan_name\":\"\"},\"target\":\"\",\"target_type\":\"unknown\"}", "category": ""}

# %% [markdown]
# ## 8. Rebuild RAG After NIT Preprocessing
#
# After preprocessing, the RAG index includes both the processed NIT JSONL records and the EX3300 guide.

# %%
# !python src/rag_query.py --rebuild --query "What are the front panel ports on a Juniper EX3300 switch?" --top_k 5
# Out:
# [RAG] Building index from:
# [RAG]   include data/processed/train.jsonl
# [RAG]   include data/processed/val.jsonl
# [RAG]   include rag-doc/ex3300.pdf
# [RAG]   exclude data/processed/test.jsonl
# ================================================================================
# [RAG] query: What are the front panel ports on a Juniper EX3300 switch?
# [RAG] 1. source=ex3300.pdf, page=25, score=0.5100, preview=Front Panel of an EX3300 Switch The front panel of an EX3300 switch consists of the following components: • Network ports: • Depending on the switch model, 24 or 48 10/100/1000BASE-T Gigabit Ethernet
# [RAG] 2. source=ex3300.pdf, page=26, score=0.4158, preview=Figure 2: Front Panel of an EX3300 Switch with 24 Gigabit Ethernet Ports g021217 0 1 2 3 ALM EX3300 SYS MST LCD panel Network ports Chassis status LEDs Enter buttonSFP+ uplink ports Menu button Rear P
# [RAG] 3. source=ex3300.pdf, page=5, score=0.4141, preview=EX3300 Management Cable Specifications and Pinouts | 68 Management Cable Specifications | 68 Console Port Connector Pinout Information | 69 USB Port Specifications for an EX Series Switch | 70 RJ-45 M
# [RAG] 4. source=ex3300.pdf, page=82, score=0.4086, preview=Unpacking and Mounting the EX3300 Switch IN THIS SECTION Unpacking an EX3300 Switch | 82 Parts Inventory (Packing List) for an EX3300 Switch | 83 Register Products—Mandatory to Validate SLAs | 84 Inst
# [RAG] 5. source=ex3300.pdf, page=19, score=0.3740, preview=Support for Power over Ethernet (PoE)—EX3300-24P and EX3300-48P models support the IEEE 802.3at PoE standard, also known as PoE+, delivering up to 30 watts of power per port to support networked devic
#
# [RAG] prompt:
#
# You are a network intent translation assistant. Convert the user intent into the correct Juniper Junos CLI command.
#
# Use retrieved NIT examples for command pattern matching.
# Use retrieved documentation for hardware/device-specific grounding.
# Prefer the Juniper EX3300 hardware config guide when the question is about EX3300 hardware, ports, LEDs, power, installation, interfaces, LCDs, or CLI/config behavior.
#
# Rules:
# - Output only the final CLI command.
# - Do not explain.
# - Do not include source citations in the answer.
# - If the retrieved context does not contain enough information for a CLI command, output the best command implied by the user intent and NIT examples.
#
# Retrieved NIT examples:
# None retrieved.
#
# Retrieved documentation:
# [Source: ex3300.pdf, page 25]
# Front Panel of an EX3300 Switch
# The front panel of an EX3300 switch consists of the following components:
# • Network ports:
# • Depending on the switch model, 24 or 48 10/100/1000BASE-T Gigabit Ethernet ports (ports labeled
# 0 through 23 or 0 through 47)
# • Power over Ethernet Plus (PoE+) available in all network ports in EX3300-24P and EX3300-48P models
# • Power over Ethernet Plus (PoE+) not available in any network port in EX3300-24T, EX3300-24T-DC,
# EX3300-48T, and EX3300-48T-BF models
# • Four built-in uplink ports:
# • The uplink ports support 1-gigabit small form-factor pluggable (SFP) transceivers, 10-gigabit small
# form-factor pluggable (SFP+) transceivers, or a combination of these transceivers.
# • Ports labeled 0 and 1 are, by default, configured as network ports. You can configure these ports as
# Virtual Chassis ports (VCPs).
# • Ports labeled 2 and 3 are, by default, configured as VCPs. You can configure these ports as network
# ports.
# • Network port and uplink port LEDs
# • Three chassis status LEDs
# • LCD panel and the LCD navigation buttons
# • Air intake or air exhaust, depending on the switch model—The intake or exhaust is located immediately
# below the top edge of the front panel.
# Figure 1 on page 25 shows the front panel of an EX3300 switch with 48 Gigabit Ethernet ports.
# Figure 2 on page 26 shows the front panel of an EX3300 switch with 24 Gigabit Ethernet ports.
# Figure 1: Front Panel of an EX3300 Switch with 48 Gigabit Ethernet Ports
# g021216
# 0 1 2 3
# ALM
# EX3300 PoE+
# SYS
# MST
# LCD panel
# Network ports
# Chassis
# status
# LEDs
# Enter buttonSFP+ uplink ports
# Menu button
# 25
#
# ---
#
# [Source: ex3300.pdf, page 26]
# Figure 2: Front Panel of an EX3300 Switch with 24 Gigabit Ethernet Ports
# g021217
# 0 1 2 3
# ALM
# EX3300
# SYS
# MST
# LCD panel
# Network ports
# Chassis
# status
# LEDs
# Enter buttonSFP+ uplink ports
# Menu button
# Rear Panel of an EX3300 Switch
# The rear panel of the EX3300 switch consists of the following components:
# • Management Ethernet port
# • USB port
# • Console port
# • Protective earthing terminal
# • Redundant power system (RPS) port
# • ESD point
# • Air intake or air exhaust, depending on the switch model
# • Serial number ID label
# • AC power cord inlet or DC power terminal block
# Figure 3 on page 26 shows the rear panel of an EX3300 switch with AC power supply.
# The power cord retainer extends out of the chassis by 3 in. (7.62 cm).
# Figure 3: Rear Panel of an EX3300 Switch with an AC Power Supply
# AC power
# cord inlet
# Air exhaust
# with fan
# Serial number
# ID label
# USB
# port
# Management
# Ethernet port
# Console RPS
# portport
# Protective
# earthing terminal
# ESD
# point
# g021202
# Figure 4 on page 27 shows the rear panel of an EX3300 switch with DC power supply.
# 26
#
# ---
#
# [Source: ex3300.pdf, page 5]
# EX3300 Management Cable Specifications and Pinouts | 68
# Management Cable Specifications | 68
# Console Port Connector Pinout Information | 69
# USB Port Specifications for an EX Series Switch | 70
# RJ-45 Management Port Connector Pinout Information | 70
# RJ-45 Port, SFP Port, SFP+ Port, QSFP+ Port, and QSFP28 Port Connector Pinout
# Information | 71
# RJ-45 to DB-9 Serial Port Adapter Pinout Information | 76
# EX3300 Virtual Chassis | 77
# Planning EX3300 Virtual Chassis | 77
# Understanding EX3300 Virtual Chassis Hardware Configuration | 78
# Virtual Chassis Cabling Configuration Examples for EX3300 Switches | 78
# Initial Installation and Configuration
# 3
# Unpacking and Mounting the EX3300 Switch | 82
# Unpacking an EX3300 Switch | 82
# Parts Inventory (Packing List) for an EX3300 Switch | 83
# Register Products—Mandatory to Validate SLAs | 84
# Installing and Connecting an EX3300 Switch | 85
# Mounting an EX3300 Switch | 86
# Mounting an EX3300 Switch on a Desk or Other Level Surface | 86
# Mounting an EX3300 Switch on Two Posts in a Rack or Cabinet | 87
# Mounting an EX3300 Switch on Four Posts in a Rack or Cabinet | 90
# Mounting an EX3300 Switch in a Recessed Position in a Rack or Cabinet | 93
# Mounting an EX3300 Switch on a Wall | 94
# Connecting the EX3300 to Power | 97
# Connect Earth Ground to an EX Series Switch | 97
# Parts and Tools Required for Connecting an EX Series Switch to Earth Ground | 98
# Special Instructions to Follow Before Connecting Earth Ground to an EX Series Switch | 102
# Connecting Earth Ground to an EX Series Switch | 103
# Connecting AC Power to an EX3300 Switch | 104
# Connecting DC Power to an EX3300 Switch | 106
# v
#
# ---
#
# [Source: ex3300.pdf, page 82]
# Unpacking and Mounting the EX3300 Switch
# IN THIS SECTION
# Unpacking an EX3300 Switch | 82
# Parts Inventory (Packing List) for an EX3300 Switch | 83
# Register Products—Mandatory to Validate SLAs | 84
# Installing and Connecting an EX3300 Switch | 85
# Mounting an EX3300 Switch | 86
# Mounting an EX3300 Switch on a Desk or Other Level Surface | 86
# Mounting an EX3300 Switch on Two Posts in a Rack or Cabinet | 87
# Mounting an EX3300 Switch on Four Posts in a Rack or Cabinet | 90
# Mounting an EX3300 Switch in a Recessed Position in a Rack or Cabinet | 93
# Mounting an EX3300 Switch on a Wall | 94
# Unpacking an EX3300 Switch
# The EX3300 switches are shipped in a cardboard carton, secured with foam packing material. The carton
# also contains an accessory box.
# CAUTION: EX3300 switches are maximally protected inside the shipping carton. Do
# not unpack the switches until you are ready to begin installation.
# To unpack the switch:
# 1. Move the shipping carton to a staging area as close to the installation site as possible, but where you
# have enough room to remove the system components.
# 2. Position the carton so that the arrows are pointing up.
# 3. Open the top flaps on the shipping carton.
# 4. Remove the accessory box and verify the contents in it against the parts inventory on the label attached
# to the carton.
# 82
#
# ---
#
# [Source: ex3300.pdf, page 19]
# Support for Power over Ethernet (PoE)—EX3300-24P and EX3300-48P models support the IEEE 802.3at
# PoE standard, also known as PoE+, delivering up to 30 watts of power per port to support networked
# devices such as telephones, video cameras, IEEE 802.11n wireless LAN (WLAN) access points, and video
# phones.
# EX3300 Switches First View
# EX3300 switches provide:
# • Either 24 or 48 built-in network ports with 10/100/1000BASE-T Gigabit Ethernet connectors (ports
# labeled 0 through 23 or 0 through 47)
# • Four uplink ports (ports labeled 0 through 3)
# • Virtual Chassis capability—You can connect up to ten EX3300 switches together to form one unit that
# you manage as a single chassis, called a Virtual Chassis.
# • Power over Ethernet Plus (PoE+) on all network ports (in PoE+-capable models only)
# Uplink Ports
# Each EX3300 switch has four autosensing uplink ports. You can use the uplink ports on the switch to:
# • Connect an access switch to a distribution switch
# • Interconnect member switches of a Virtual Chassis
# The uplink ports labeled 0 and 1 (interfaces ge-0/1/0 and ge-0/1/1 or xe-0/1/0 and xe-0/1/1) are
# configuredby default as network ports. To use uplink ports 0 and 1 to interconnectVirtual Chassis members,
# you must configure them as Virtual Chassis ports (VCPs).
# The uplink ports labeled 2 and 3 (interfaces ge-0/1/2 and ge-0/1/3 or xe-0/1/2 and xe-0/1/3) are
# configured by default as VCPs. You can use these uplink ports to interconnect Virtual Chassis members.
# To use uplink ports 2 and 3 as network ports, you must configure them as network ports.
# The uplink ports support SFP and SFP+ transceivers. For a list of supported transceivers, see “Pluggable
# Transceivers Supported on EX3300 Switches” on page 61.
# Power over Ethernet Plus Ports
# EX3300 switches are available in models with or without PoE+ capability. Models that support PoE+
# provide that support on all network ports.
# PoE+ ports provide electrical current to devices—such as IP phones, wireless access points, and security
# cameras—through network cables, thus eliminating the need for separate power cords for those devices.
# 19
#
# Question:
# What are the front panel ports on a Juniper EX3300 switch?
#
# Answer:
#
#
# [RAG] final answer preview:
#
# From ex3300.pdf, page 25: Front Panel of an EX3300 Switch The front panel of an EX3300 switch consists of the following components: • Network ports: • Depending on the switch model, 24 or 48 10/100/1000BASE-T Gigabit Ethernet ports (ports labeled 0 through 23 or 0 through 47) • Power over Ethernet Plus (PoE+) available in all network ports in EX3300-24P and EX3300-48P models • Power over Ethernet Plus (PoE+) not available in any network port in EX3300-24T, EX3300-24T-DC, EX3300-48T, and EX3300-48T-BF models • Four built-in uplink ports: • The uplink ports support 1-gigabit small form-factor pluggable (SFP) transceivers, 10-gigabit small form-factor pluggable (SFP+) transceivers, or a combination of these transceivers. • Ports labeled 0 and 1 are, by default, configured as network ports. You can configure these ports as Virtual Chassis ports (VCPs). • Ports labeled 2 and 3 are, by default, configured as VCPs. You

# %% [markdown]
# ## 9. Train LoRA on A100
#
# The repo config is already A100-oriented. If Colab runs out of memory, lower `training.max_seq_len` or batch settings in `config.yaml` before running this cell.

# %%
# !bash scripts/run_train.sh
# Out:
# config.json: 100% 654/654 [00:00<00:00, 2.47MB/s]
# tokenizer_config.json: 50.6kB [00:00, 76.5MB/s]
# tokenizer.json: 9.09MB [00:00, 33.1MB/s]
# special_tokens_map.json: 100% 73.0/73.0 [00:00<00:00, 376kB/s]
# model.safetensors.index.json: 23.9kB [00:00, 46.2MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 100% 16.1G/16.1G [00:42<00:00, 446MB/s]
# Fetching 4 files:  25% 1/4 [00:42<02:08, 42.67s/it]
# Fetching 4 files: 100% 4/4 [00:43<00:00, 10.77s/it]
# Download complete: 100% 16.1G/16.1G [00:43<00:00, 372MB/s]
# Loading weights: 100% 291/291 [00:04<00:00, 65.14it/s]
# generation_config.json: 100% 177/177 [00:00<00:00, 1.00MB/s]
# Map: 100% 722/722 [00:00<00:00, 2160.32 examples/s]
# {'loss': '0.3484', 'grad_norm': '0.7025', 'learning_rate': '0.000187', 'epoch': '0.2216'}
# {'loss': '0.1039', 'grad_norm': '0.76', 'learning_rate': '0.0001725', 'epoch': '0.4432'}
# {'loss': '0.05978', 'grad_norm': '1.261', 'learning_rate': '0.000158', 'epoch': '0.6648'}
# {'loss': '0.04285', 'grad_norm': '0.2097', 'learning_rate': '0.0001435', 'epoch': '0.8864'}
# {'loss': '0.03768', 'grad_norm': '0.3057', 'learning_rate': '0.000129', 'epoch': '1.089'}
# {'loss': '0.05929', 'grad_norm': '0.304', 'learning_rate': '0.0001145', 'epoch': '1.31'}
# {'loss': '0.03723', 'grad_norm': '0.617', 'learning_rate': '0.0001', 'epoch': '1.532'}
# {'loss': '0.03629', 'grad_norm': '0.2569', 'learning_rate': '8.551e-05', 'epoch': '1.753'}
# {'loss': '0.01497', 'grad_norm': '0.03881', 'learning_rate': '7.101e-05', 'epoch': '1.975'}
# {'loss': '0.01537', 'grad_norm': '0.06702', 'learning_rate': '5.652e-05', 'epoch': '2.177'}
# {'loss': '0.0196', 'grad_norm': '0.5325', 'learning_rate': '4.203e-05', 'epoch': '2.399'}
# {'loss': '0.0168', 'grad_norm': '0.2995', 'learning_rate': '2.754e-05', 'epoch': '2.62'}
# {'loss': '0.02028', 'grad_norm': '0.0991', 'learning_rate': '1.304e-05', 'epoch': '2.842'}
# {'train_runtime': '276.9', 'train_samples_per_second': '7.822', 'train_steps_per_second': '0.498', 'train_loss': '0.05952', 'epoch': '3'}
# 100% 138/138 [04:36<00:00,  2.01s/it]

# %% [markdown]
# ## 10. RAG Inference Smoke Test
#
# Create a tiny input file with EX3300-specific questions and run inference with retrieved EX3300 context. The `--rag_debug` output should show chunks from `ex3300.pdf`.

# %%
# !pip install --upgrade torchao
# Out:
# Requirement already satisfied: torchao in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Collecting torchao
#   Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 59.1 MB/s eta 0:00:00
# Installing collected packages: torchao
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
# Successfully installed torchao-0.17.0

# %%
import json, os
os.makedirs("data/processed", exist_ok=True)
rows = [
    {"intent": "What are the front panel ports on a Juniper EX3300 switch?", "context": "", "target_command": "", "category": "rag_ex3300"},
    {"intent": "How do I interpret ALM SYS MST LEDs on an EX3300?", "context": "", "target_command": "", "category": "rag_ex3300"},
    {"intent": "What are the console port details for EX3300?", "context": "", "target_command": "", "category": "rag_ex3300"},
]
with open("data/processed/rag_smoke.jsonl", "w", encoding="utf-8") as f:
    for row in rows:
        f.write(json.dumps(row) + "\n")

# !python src/infer.py \
  --input_file data/processed/rag_smoke.jsonl \
  --output_file results/predictions/rag_smoke_predictions.jsonl \
  --use_rag \
  --rebuild_rag \
  --rag_debug

# !cat results/predictions/rag_smoke_predictions.jsonl
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [RAG] Building index from:
# [RAG]   include data/processed/train.jsonl
# [RAG]   include data/processed/val.jsonl
# [RAG]   include rag-doc/ex3300.pdf
# [RAG]   exclude data/processed/test.jsonl
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:05<00:00, 58.07it/s]
#
# [INFO] Starting BATCHED inference on 3 instances for rag_smoke.jsonl...
# Batches:   0% 0/1 [00:00<?, ?it/s][RAG] query: What are the front panel ports on a Juniper EX3300 switch?
# [RAG] 1. source=ex3300.pdf, page=25, score=0.5100, preview=Front Panel of an EX3300 Switch The front panel of an EX3300 switch consists of the following components: • Network ports: • Depending on the switch model, 24 or 48 10/100/1000BASE-T Gigabit Ethernet
# [RAG] 2. source=ex3300.pdf, page=26, score=0.4158, preview=Figure 2: Front Panel of an EX3300 Switch with 24 Gigabit Ethernet Ports g021217 0 1 2 3 ALM EX3300 SYS MST LCD panel Network ports Chassis status LEDs Enter buttonSFP+ uplink ports Menu button Rear P
# [RAG] 3. source=ex3300.pdf, page=5, score=0.4141, preview=EX3300 Management Cable Specifications and Pinouts | 68 Management Cable Specifications | 68 Console Port Connector Pinout Information | 69 USB Port Specifications for an EX Series Switch | 70 RJ-45 M
# [RAG] 4. source=ex3300.pdf, page=82, score=0.4086, preview=Unpacking and Mounting the EX3300 Switch IN THIS SECTION Unpacking an EX3300 Switch | 82 Parts Inventory (Packing List) for an EX3300 Switch | 83 Register Products—Mandatory to Validate SLAs | 84 Inst
# [RAG] 5. source=ex3300.pdf, page=19, score=0.3740, preview=Support for Power over Ethernet (PoE)—EX3300-24P and EX3300-48P models support the IEEE 802.3at PoE standard, also known as PoE+, delivering up to 30 watts of power per port to support networked devic
# [RAG] query: How do I interpret ALM SYS MST LEDs on an EX3300?
# [RAG] 1. source=ex3300.pdf, page=34, score=0.8484, preview=Table 7: Chassis Status LEDs in an EX3300 Switch State and DescriptionColorLED Label There is no alarm or the switch is halted.UnlitALM (Alarm) There is a major alarm. NOTE: When you connect power to
# [RAG] 2. source=ex3300.pdf, page=33, score=0.6459, preview=Table 6: LCD Panel Menu Options (continued) DescriptionMenu If you do not want users to use Maintenance menu options, disable the entire menu or individual menu options. See “Configuring the LCD Panel
# [RAG] 3. source=ex3300.pdf, page=183, score=0.3946, preview=Table 53: Chassis Component Alarm Conditions on EX3300 Switches (continued) RemedyAlarm SeverityAlarm ConditionChassis Component Clean up the system file storage space on the switch. For more informat
# [RAG] 4. source=ex3300.pdf, page=36, score=0.3131, preview=Table 9: Status LED on the Management Port on an EX3300 Switch State and DescriptionLCD IndicatorLED Indicates the speed. The speed indicators are: • One blink per second—10 Mbps • Two blinks per seco
# [RAG] 5. source=ex3300.pdf, page=79, score=0.2873, preview=NOTE: For increased availability and redundancy, we recommend that you always configure your Virtual Chassis in a ring topology. Figure 17 on page 79, Figure 18 on page 79, and Figure 19 on page 80 sh
# [RAG] query: What are the console port details for EX3300?
# [RAG] 1. source=ex3300.pdf, page=69, score=0.6418, preview=Table 24: Specifications of Cables to Connect to Management Devices (continued) Additional InformationReceptacleCable SpecificationsPorts “Connect a Device to a Network for Out-of-Band Management” on
# [RAG] 2. source=ex3300.pdf, page=5, score=0.5888, preview=EX3300 Management Cable Specifications and Pinouts | 68 Management Cable Specifications | 68 Console Port Connector Pinout Information | 69 USB Port Specifications for an EX Series Switch | 70 RJ-45 M
# [RAG] 3. source=ex3300.pdf, page=68, score=0.5212, preview=(13 dBm) – (0.5 dBm [HOL]) – ((5) * (0.5 dBm)) – ((2) * (0.5 dBm)) – ((2 km) * (1.0 dBm/km)) – (1 dB [CRM]) = P M 13 dBm – 0.5 dBm – 2.5 dBm – 1 dBm – 2 dBm – 1 dBm = P M P M = 6 dBm The calculated po
# [RAG] 4. source=ex3300.pdf, page=123, score=0.4842, preview=To connect and configure the switch from the console by using the CLI: 1. Connect the console port to a laptop or PC by using the RJ-45 to DB-9 serial port adapter. An Ethernet cable that has an RJ-45
# [RAG] 5. source=ex3300.pdf, page=70, score=0.4615, preview=Table 25: Console Port Connector Pinout Information (continued) DescriptionSignalPin CTS InputNC8 USB Port Specifications for an EX Series Switch The following Juniper Networks USB flash drives have b
# [transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches: 100% 1/1 [00:04<00:00,  4.96s/it]
# [RAG] retrieved chunk counts:
# [RAG]   ex3300.pdf: 15
# {"intent": "What are the front panel ports on a Juniper EX3300 switch?", "context": "", "target_command": "", "category": "rag_ex3300", "prediction": "The front panel of an EX3300 switch consists of the following components: • Network ports: • Depending on the switch model, 24 or 48 10/100/1000BASE-T Gigabit Ethernet ports (ports labeled 0 through 23 or 0 through 47) • Power over Ethernet Plus", "rag_sources": [{"source_file": "ex3300.pdf", "page": 25, "score": 0.5100342135239742}, {"source_file": "ex3300.pdf", "page": 26, "score": 0.4157786387486886}, {"source_file": "ex3300.pdf", "page": 5, "score": 0.414130274740105}, {"source_file": "ex3300.pdf", "page": 82, "score": 0.4086445626287404}, {"source_file": "ex3300.pdf", "page": 19, "score": 0.3739680518102625}]}
# {"intent": "How do I interpret ALM SYS MST LEDs on an EX3300?", "context": "", "target_command": "", "category": "rag_ex3300", "prediction": "commit", "rag_sources": [{"source_file": "ex3300.pdf", "page": 34, "score": 0.848366566112028}, {"source_file": "ex3300.pdf", "page": 33, "score": 0.6459248774461026}, {"source_file": "ex3300.pdf", "page": 183, "score": 0.39464366439232823}, {"source_file": "ex3300.pdf", "page": 36, "score": 0.3131111022439627}, {"source_file": "ex3300.pdf", "page": 79, "score": 0.2872693351548548}]}
# {"intent": "What are the console port details for EX3300?", "context": "", "target_command": "", "category": "rag_ex3300", "prediction": "commit", "rag_sources": [{"source_file": "ex3300.pdf", "page": 69, "score": 0.6418369694243446}, {"source_file": "ex3300.pdf", "page": 5, "score": 0.5887532407729219}, {"source_file": "ex3300.pdf", "page": 68, "score": 0.5211780948988419}, {"source_file": "ex3300.pdf", "page": 123, "score": 0.48416672630985624}, {"source_file": "ex3300.pdf", "page": 70, "score": 0.46150113886069916}]}

# %% [markdown]
# ## 11. Full Test Inference + Evaluation
#
# Use this for the original NIT evaluation. Keep `--use_rag` on if you want retrieved context included during inference.

# %%
# !mkdir -p results/predictions results/metrics
# !python src/infer.py \
  --input_file data/processed/test.jsonl \
  --output_file results/predictions/rag_predictions.jsonl \
  --use_rag \
  --rag_debug

# !python src/evaluate.py --pred_file results/predictions/rag_predictions.jsonl
# !cat results/metrics/eval_metrics.json
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:05<00:00, 55.86it/s]
#
# [INFO] Starting BATCHED inference on 150 instances for test.jsonl...
# Batches:   0% 0/5 [00:00<?, ?it/s][RAG] query: How to display the LED status
# [RAG] 1. source=ex3300.pdf, page=34, score=0.8546, preview=Table 7: Chassis Status LEDs in an EX3300 Switch State and DescriptionColorLED Label There is no alarm or the switch is halted.UnlitALM (Alarm) There is a major alarm. NOTE: When you connect power to
# [RAG] 2. source=train.jsonl, score=0.5075, preview=Intent: Show LED status Context: show chassis led Target command: show chassis led
# [RAG] 3. source=ex3300.pdf, page=33, score=0.4292, preview=Table 6: LCD Panel Menu Options (continued) DescriptionMenu If you do not want users to use Maintenance menu options, disable the entire menu or individual menu options. See “Configuring the LCD Panel
# [RAG] 4. source=ex3300.pdf, page=225, score=0.4161, preview=Class 1 LED Product Warning WARNING: Class 1 LED product. Waarschuwing Klasse 1 LED-product. Varoitus Luokan 1 valodiodituote. Avertissement Alarme de produit LED Class I. Warnung Class 1 LED-Produktw
# [RAG] 5. source=ex3300.pdf, page=36, score=0.4052, preview=Table 9: Status LED on the Management Port on an EX3300 Switch State and DescriptionLCD IndicatorLED Indicates the speed. The speed indicators are: • One blink per second—10 Mbps • Two blinks per seco
# [RAG] query: Show sFlow protocol configurations in the operational mode
# [RAG] 1. source=train.jsonl, score=0.4806, preview=Intent: Show sFlow protocol configurations in the operational mode in the set format Context: show configuration protocols sflow | display set Target command: show configuration protocols sflow | disp
# [RAG] 2. source=train.jsonl, score=0.4806, preview=Intent: Show sFlow protocol configurations in the operational mode in the set format Context: show configuration protocols sflow | display set Target command: show configuration protocols sflow | disp
# [RAG] 3. source=train.jsonl, score=0.4156, preview=Intent: show sflow configurations from the operational mode Context: show configuration protocols sflow Target command: show configuration protocols sflow
# [RAG] 4. source=train.jsonl, score=0.4043, preview=Intent: how to show RSTP protocol configurations from the operational mode Context: show configuration protocols rstp Target command: show configuration protocols rstp
# [RAG] 5. source=train.jsonl, score=0.3998, preview=Intent: Display RSTP protocol configurations from the operational mode Context: show configuration protocols rstp Target command: show configuration protocols rstp
# [RAG] query: Set sFlow taceoptions to trace all events
# [RAG] 1. source=train.jsonl, score=0.4176, preview=Intent: Set sFlow taceoptions to trace interface events Context: set protocols sflow traceoptions flag interface Target command: set protocols sflow traceoptions flag interface commit
# [RAG] 2. source=train.jsonl, score=0.3647, preview=Intent: Set sFlow taceoptions to trace configuration changes Context: set protocols sflow traceoptions flag configuration Target command: set protocols sflow traceoptions flag configuration commit
# [RAG] 3. source=train.jsonl, score=0.3576, preview=Intent: Set sFlow taceoptions to trace rtsock events Context: set protocols sflow traceoptions flag rtsock Target command: set protocols sflow traceoptions flag rtsock commit
# [RAG] 4. source=train.jsonl, score=0.3174, preview=Intent: Set sFlow taceoptions to trace client-server events Context: set protocols sflow traceoptions flag client-server Target command: set protocols sflow traceoptions flag client-server commit
# [RAG] 5. source=train.jsonl, score=0.3058, preview=Intent: Disable RSTP taceoptions to trace events to the protocol state machine Context: set protocols rstp traceoptions flag events Target command: set protocols rstp traceoptions flag events commit
# [RAG] query: set a mac moving limit of 2 on vlan HR
# [RAG] 1. source=train.jsonl, score=0.4544, preview=Intent: set a mac moving limit of 3 on vlan 20 Context: set ethernet-switching-options secure-access-port vlan <vlan-id-or-name> mac-move-limit <limit> Target command: set ethernet-switching-options s
# [RAG] 2. source=val.jsonl, score=0.4303, preview=Intent: how to configure a mac moving limit on a vlan Context: set ethernet-switching-options secure-access-port vlan <vlan-id-or-name> mac-move-limit <limit> Target command: set ethernet-switching-op
# [RAG] 3. source=train.jsonl, score=0.3856, preview=Intent: set a mac moving limit of 5 on vlan 10 and generate a systme log entry whenever the limit is reached Context: set ethernet-switching-options secure-access-port vlan <vlan-id-or-name> mac-move-
# [RAG] 4. source=train.jsonl, score=0.2604, preview=Intent: delete vlan HR Context: delete vlans <vlan-name> Target command: delete vlans HR commit
# [RAG] 5. source=train.jsonl, score=0.2432, preview=Intent: set the IGMP snooping immediate leave on VLAN HR Context: set igmp-snooping vlan <vlan-name> immediate-leave Target command: set igmp-snooping vlan HR immediate-leave commit
# [RAG] query: Trace the virtual chassis complete sequence number (CSN) packets
# [RAG] 1. source=val.jsonl, score=0.6045, preview=Intent: Disable the virtual chassis complete sequence number (csn) packets traceoption Context: set virtual-chassis traceoptions flag csn disable Target command: set virtual-chassis traceoptions flag
# [RAG] 2. source=train.jsonl, score=0.2684, preview=Intent: Trace virtual chassis packets Context: set virtual-chassis traceoptions flag packets Target command: set virtual-chassis traceoptions flag packets commit
# [RAG] 3. source=train.jsonl, score=0.2601, preview=Intent: Trace virtual chassis partial sequence number (PSN) packets Context: set virtual-chassis traceoptions flag psn Target command: set virtual-chassis traceoptions flag psn commit
# [RAG] 4. source=train.jsonl, score=0.2078, preview=Intent: Disable virtual chassis partial sequence number (PSN) packets traceoption Context: set virtual-chassis traceoptions psn disable Target command: set virtual-chassis traceoptions flag psn disabl
# [RAG] 5. source=train.jsonl, score=0.2023, preview=Intent: Disable virtual chassis packets traceoption Context: set virtual-chassis traceoptions packets disable Target command: set virtual-chassis traceoptions flag packets disable commit
# [RAG] query: put a mac limit of 1 on interface ge-0/0/15 and log the event when the mac limit is exceeded
# [RAG] 1. source=train.jsonl, score=0.5723, preview=Intent: set a mac limit of 2 on interface ge-0/0/7 Context: set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <mac-limit> Target command: set ethernet-switching-op
# [RAG] 2. source=train.jsonl, score=0.5558, preview=Intent: how to set a mac limit on an interface Context: set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <mac-limit> Target command: set ethernet-switching-option
# [RAG] 3. source=val.jsonl, score=0.5399, preview=Intent: put a mac limit of 4 on interface ge-0/0/15 and set the action to log Context: set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <limit> action log Target
# [RAG] 4. source=train.jsonl, score=0.5103, preview=Intent: set a mac limit of 10 on interface ge-0/0/8 Context: set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <mac-limit> Target command: set ethernet-switching-o
# [RAG] 5. source=train.jsonl, score=0.5069, preview=Intent: how to set a mac limit on interface range Context: set ethernet-switching-options secure-access-port interface <range-name> mac-limit <mac-limit> commit Target command: set ethernet-switching-
# [RAG] query: set the sflow egress sampling rate to 1000
# [RAG] 1. source=train.jsonl, score=0.5413, preview=Intent: how to set the sflow egress sampling rate Context: set protocols sflow sample-rate egress <rate> Target command: set protocols sflow sample-rate egress <rate> commit
# [RAG] 2. source=val.jsonl, score=0.5230, preview=Intent: set the sflow egress sampling rate to 1100 Context: set protocols sflow sample-rate egress <rate> Target command: set protocols sflow sample-rate egress 1100 commit
# [RAG] 3. source=train.jsonl, score=0.4143, preview=Intent: set the sflow ingress sampling rate to 1000 Context: set protocols sflow sample-rate ingress <rate> Target command: set protocols sflow sample-rate ingress 1000 commit
# [RAG] 4. source=train.jsonl, score=0.3076, preview=Intent: how to set the sflow ingress sampling rate Context: set protocols sflow sample-rate ingress <rate> Target command: set protocols sflow sample-rate ingress <rate> commit
# [RAG] 5. source=train.jsonl, score=0.2843, preview=Intent: set the sflow ingress sampling rate to 1100 Context: set protocols sflow sample-rate ingress <rate> Target command: set protocols sflow sample-rate ingress 1100 commit
# [RAG] query: Show LCD active menu items
# [RAG] 1. source=ex3300.pdf, page=130, score=0.5408, preview=The LCD panel on the front panel of EX Series switches displays a variety of information about the switch in the Status menu and provides the Maintenance menu to enable you to perform basic operations
# [RAG] 2. source=ex3300.pdf, page=29, score=0.4303, preview=LCD Panel Menus The LCD panel has three menus: Idle, Status, and Maintenance. Toggle between the LCD panel menus by pressing the Menu button. Navigate through the menu options by pressing the Enter bu
# [RAG] 3. source=ex3300.pdf, page=31, score=0.3947, preview=Table 6: LCD Panel Menu Options (continued) DescriptionMenu MAINT (Maintenance Menu) 31
# [RAG] 4. source=ex3300.pdf, page=27, score=0.3730, preview=Figure 4: Rear Panel of an EX3300 Switch with a DC Power Supply g021203 DC power terminals Air exhaust with fan Serial number ID label USB port Management Ethernet port Console RPS portport Protective
# [RAG] 5. source=ex3300.pdf, page=30, score=0.3690, preview=Table 6: LCD Panel Menu Options (continued) DescriptionMenu The Status menu has the following options: • Show VCP status—Choose one of the following: • Press the Enter button to display the Virtual Ch
# [RAG] query: disable IGMP snooping routing information taceoption
# [RAG] 1. source=train.jsonl, score=0.5285, preview=Intent: Show IGMP snooping routing information Context: show igmp-snooping route Target command: show igmp-snooping route
# [RAG] 2. source=train.jsonl, score=0.5210, preview=Intent: Display the IGMP snooping routing information Context: show igmp-snooping route Target command: show igmp-snooping route
# [RAG] 3. source=train.jsonl, score=0.4427, preview=Intent: disable IGMP snooping routing protocol timer processing taceoption Context: set protocols igmp-snooping traceoptions flag timer disable Target command: set protocols igmp-snooping traceoptions
# [RAG] 4. source=train.jsonl, score=0.4347, preview=Intent: disable IGMP snooping routing protocol task processing taceoption Context: set protocols igmp-snooping traceoptions flag task disable Target command: set protocols igmp-snooping traceoptions f
# [RAG] 5. source=train.jsonl, score=0.3847, preview=Intent: disable IGMP snooping on all VLANs Context: set protocols igmp-snooping vlan all disable Target command: set protocols igmp-snooping vlan all disable commit
# [RAG] query: help me configure ntp server on a juniper switch using command line
# [RAG] 1. source=train.jsonl, score=0.5841, preview=Intent: how to synchronize time to ntp server on a juniper switch using command line Context: set system ntp server <ntp-server-address> Target command: set system ntp server <ntp-server-address> comm
# [RAG] 2. source=train.jsonl, score=0.3679, preview=Intent: delete the configured ntp server Context: delete system ntp server <ntp-server-address> Target command: delete system ntp server <ntp-server-address> commit
# [RAG] 3. source=train.jsonl, score=0.3153, preview=Intent: make the switch synchronize its time with the ntp server 192.168.1.100 Context: set system ntp server <ntp-server-address> Target command: set system ntp server 192.168.1.100 commit
# [RAG] 4. source=train.jsonl, score=0.3136, preview=Intent: set ntp server address to 10.200.1.90 and add the following comment "configured ntp server" to the commit Context: set system ntp server <ntp-server-address> commit comment <"string-comment">
# [RAG] 5. source=train.jsonl, score=0.3104, preview=Intent: set ntp server address to 10.200.1.90 and add the following comment "added ntp server" to the commit Context: set system ntp server <ntp-server-address> commit comment <"string-comment"> Targe
# [RAG] query: set the SNMP VRRP notifications for the trap-group MONITOR-GROUP
# [RAG] 1. source=train.jsonl, score=0.6999, preview=Intent: delete the SNMP VRRP notifications for the trap-group MONITOR-GROUP Context: delete snmp trap-group <trap-group-name> categories vrrp-events Target command: delete snmp trap-group MONITOR-GROU
# [RAG] 2. source=train.jsonl, score=0.6714, preview=Intent: disable the SNMP VRRP notifications for the trap-group MONITOR-GROUP-L1 Context: delete snmp trap-group <trap-group-name> categories vrrp-events Target command: delete snmp trap-group MONITOR-
# [RAG] 3. source=train.jsonl, score=0.6696, preview=Intent: Enable the SNMP VRRP event trap for the trap-group MONITOR-GROUP Context: set snmp trap-group <trap-group-name> categories vrrp-events Target command: set snmp trap-group MONITOR-GROUP categor
# [RAG] 4. source=train.jsonl, score=0.6238, preview=Intent: set the SNMP routing protocol notifications trap for the trap-group MONITOR-GROUP Context: set snmp trap-group <trap-group-name> categories routing Target command: set snmp trap-group MONITOR-
# [RAG] 5. source=train.jsonl, score=0.6205, preview=Intent: set the SNMP services notifications trap for the trap-group MONITOR-GROUP Context: set snmp trap-group <trap-group-name> categories services Target command: set snmp trap-group MONITOR-GROUP c
# [RAG] query: How to set the RSTP maximum age of received protocol BPDUs
# [RAG] 1. source=train.jsonl, score=0.5592, preview=Intent: Set the RSTP maximum age of received protocol BPDUs to 30 Context: set protocols rstp max-age <max-age-interval> Target command: set protocols rstp max-age 30 commit
# [RAG] 2. source=train.jsonl, score=0.3989, preview=Intent: Set the RSTP max age of received protocol BPDUs to 15 Context: set protocols rstp max-age <max-age-interval> Target command: set protocols rstp max-age 15 commit
# [RAG] 3. source=train.jsonl, score=0.1180, preview=Intent: Set RSTP taceoptions to trace all operations Context: set protocols rstp traceoptions flag all Target command: set protocols rstp traceoptions flag all commit
# [RAG] 4. source=val.jsonl, score=0.1070, preview=Intent: Disable RSTP protocol Context: set protocols rstp disable Target command: set protocols rstp disable commit
# [RAG] 5. source=train.jsonl, score=0.1070, preview=Intent: how to disable the RSTP protocol Context: set protocols rstp disable Target command: set protocols rstp disable commit
# [RAG] query: Enable sFlow protocol on interface ge-0/0/8
# [RAG] 1. source=train.jsonl, score=0.5933, preview=Intent: Enable sFlow protocol on interface ge-0/0/0 Context: set protocols sflow interfaces <interface-name> Target command: set protocols sflow interfaces ge-0/0/0 commit
# [RAG] 2. source=val.jsonl, score=0.4932, preview=Intent: Enable sFlow protocol on interface ge-0/0/8 and ge-1/0/1 Context: set protocols sflow interfaces <interface-name> Target command: set protocols sflow interfaces ge-0/0/8 set protocols sflow in
# [RAG] 3. source=train.jsonl, score=0.4021, preview=Intent: disable sFlow protocol on interface ge-0/0/8 Context: delete protocols sflow interfaces <interface-name> Target command: delete protocols sflow interfaces ge-0/0/8 commit
# [RAG] 4. source=train.jsonl, score=0.3488, preview=Intent: disable sFlow protocol on interface ge-0/0/18 Context: delete protocols sflow interfaces <interface-name> Target command: delete protocols sflow interfaces ge-0/0/18 commit
# [RAG] 5. source=val.jsonl, score=0.3374, preview=Intent: how to disable sFlow protocol on an interface Context: delete protocols sflow interfaces <interface-name> Target command: delete protocols sflow interfaces <interface-name> commit
# [RAG] query: Notify all logged users when any emergency level event occurs
# [RAG] 1. source=val.jsonl, score=0.3877, preview=Intent: Notify all logged users when any security related event of any severity level occurs Context: set system syslog user * security any Target command: set system syslog user * security any commit
# [RAG] 2. source=train.jsonl, score=0.2489, preview=Intent: who are the users currently logged in Context: show system users Target command: show system users
# [RAG] 3. source=train.jsonl, score=0.2130, preview=Intent: Notify the user alaa when any security related event of panic severity level occurs Context: set system syslog user <user-name> security emergency Target command: set system syslog user alaa s
# [RAG] 4. source=train.jsonl, score=0.2070, preview=Intent: how to check who is currently logged in to the switch Context: show system users Target command: show system users
# [RAG] 5. source=train.jsonl, score=0.1403, preview=Intent: Notify the user alaa when any security related event of any severity level occurs Context: set system syslog user <user-name> security any Target command: set system syslog user alaa security
# [RAG] query: Display IGMP snooping detailed flows information
# [RAG] 1. source=val.jsonl, score=0.6183, preview=Intent: Display igmp-snooping flows Context: show igmp-snooping flows Target command: show igmp-snooping flows
# [RAG] 2. source=train.jsonl, score=0.4381, preview=Intent: Display the IGMP snooping routing information Context: show igmp-snooping route Target command: show igmp-snooping route
# [RAG] 3. source=train.jsonl, score=0.3887, preview=Intent: Display IGMP snooping task information Context: show igmp-snooping task Target command: show igmp-snooping task
# [RAG] 4. source=train.jsonl, score=0.3648, preview=Intent: Display the IGMP snooping statistics Context: show igmp-snooping statistics Target command: show igmp-snooping statistics
# [RAG] 5. source=train.jsonl, score=0.3502, preview=Intent: show IGMP snooping VLAN information Context: show igmp-snooping vlans Target command: show igmp-snooping vlans
# [RAG] query: Disable IGMPv2 protocol leave group messages traceoptions
# [RAG] 1. source=train.jsonl, score=0.5083, preview=Intent: set the IGMPv2 protocol traceoptions to trace leave group messages Context: set protocols igmp traceoptions flag leave Target command: set protocols igmp traceoptions flag leave commit
# [RAG] 2. source=train.jsonl, score=0.3678, preview=Intent: Set IGMP snooping taceoptions to trace IGMPv2 leave group messages Context: set protocols igmp-snooping traceoptions flag leave Target command: set protocols igmp-snooping traceoptions flag le
# [RAG] 3. source=train.jsonl, score=0.3278, preview=Intent: disable IGMP v2 snooping leave group messages taceoption Context: set protocols igmp-snooping traceoptions flag leave disable Target command: set protocols igmp-snooping traceoptions flag leav
# [RAG] 4. source=train.jsonl, score=0.1956, preview=Intent: Disable IGMP protocol membership query messages traceoptions Context: set protocols igmp traceoptions flag query disable Target command: set protocols igmp traceoptions flag query disable comm
# [RAG] 5. source=train.jsonl, score=0.1897, preview=Intent: Disable IGMP protocol membership report messages traceoptions Context: set protocols igmp traceoptions flag report disable Target command: set protocols igmp traceoptions flag report disable c
# [RAG] query: Determine the interface to which the MAC address 00:19:99:93:93:3a is connected
# [RAG] 1. source=train.jsonl, score=0.2572, preview=Intent: How to find the interface to which a specific MAC address is connected Context: show ethernet-switching table | match <mac-address> Target command: show ethernet-switching table |match <mac-ad
# [RAG] 2. source=train.jsonl, score=0.2275, preview=Intent: schdule a commit at 8:00:00 Context: commit at <time> Target command: commit at 08:00:00
# [RAG] 3. source=train.jsonl, score=0.2077, preview=Intent: commit the current candidate configuration at 13:00:00 Context: commit at <time> Target command: commit at 13:00:00
# [RAG] 4. source=train.jsonl, score=0.2068, preview=Intent: How to find the interface to which a device is connected Context: show ethernet-switching table | match <mac-address> Target command: show ethernet-switching table |match <mac-address>
# [RAG] 5. source=train.jsonl, score=0.1823, preview=Intent: how to set a list of allowed Mac addresses on a specific interface Context: set ethernet-switching-options secure-access-port interface interface-name allowed-mac <mac-address> Target command:
# [RAG] query: set the IGMP protocol expected packet loss on a subnet to 3
# [RAG] 1. source=train.jsonl, score=0.4295, preview=Intent: set the IGMP protocol expected packet loss to 2 Context: set protocols igmp robust-count <robust-count> Target command: set protocols igmp robust-count 2 commit
# [RAG] 2. source=train.jsonl, score=0.1621, preview=Intent: set the IGMP protocol traceoptions to trace all events Context: set protocols igmp traceoptions flag all Target command: set protocols igmp traceoptions flag all commit
# [RAG] 3. source=val.jsonl, score=0.1437, preview=Intent: set the IGMP protocol traceoptions to trace all IGMP packets Context: set protocols igmp traceoptions flag packets Target command: set protocols igmp traceoptions flag packets commit
# [RAG] 4. source=train.jsonl, score=0.1388, preview=Intent: set the IGMP protocol traceoptions to trace routing protocol timer processing Context: set protocols igmp traceoptions flag timer Target command: set protocols igmp traceoptions flag timer com
# [RAG] 5. source=train.jsonl, score=0.1385, preview=Intent: set the IGMP protocol traceoptions to trace routing information Context: set protocols igmp traceoptions flag route Target command: set protocols igmp traceoptions flag route commit
# [RAG] query: create SNMP community with the name CAMPUS-COMMUNITY and set authorization to read only
# [RAG] 1. source=train.jsonl, score=0.7719, preview=Intent: create a new SNMP community with the name CAMPUS-COMMUNITY and set authorization to read-write Context: set snmp community <community-name> authorization <authorization> Target command: set sn
# [RAG] 2. source=train.jsonl, score=0.6106, preview=Intent: set the SNMP community to SNMP-COMMUNITY and set authorization to read-write Context: set snmp community <community-name> authorization <authorization> Target command: set snmp community SNMP-
# [RAG] 3. source=train.jsonl, score=0.5881, preview=Intent: create SNMP community with the name COMMUNITY-1 and a read-only authorization Context: set snmp community <community-name> authorization <authorization> Target command: set snmp community COMM
# [RAG] 4. source=train.jsonl, score=0.5262, preview=Intent: how to create SNMP community Context: set snmp community <community-name> authorization <authorization> Target command: set snmp community <community-name> authorization <authorization> commit
# [RAG] 5. source=train.jsonl, score=0.4610, preview=Intent: set the client list snmp-clients for the community CAMPUS-COMMUNITY Context: set snmp community <community-name> client-list-name <client-list-name> Target command: set snmp community CAMPUS-C
# [RAG] query: how to disable the OSPF protocol
# [RAG] 1. source=train.jsonl, score=0.2781, preview=Intent: configure OSPF protocol of area 0.0.0.1 on interface ge-0/0/15 as point to point Context: set protocols ospf area <ospf-area> interface <interface-name> interface-type p2p Target command: set
# [RAG] 2. source=train.jsonl, score=0.2549, preview=Intent: Display the status of OSPF interfacs Context: show ospf interface Target command: show ospf interface
# [RAG] 3. source=train.jsonl, score=0.2508, preview=Intent: Show OSPF routing table Context: show ospf route Target command: show ospf route
# [RAG] 4. source=train.jsonl, score=0.2473, preview=Intent: display OSPF routing table Context: show ospf route Target command: show ospf route
# [RAG] 5. source=val.jsonl, score=0.2346, preview=Intent: Show OSPF interface status information Context: show ospf interface Target command: show ospf interface
# [RAG] query: Show users who are currently logged in
# [RAG] 1. source=train.jsonl, score=0.6892, preview=Intent: who are the users currently logged in Context: show system users Target command: show system users
# [RAG] 2. source=train.jsonl, score=0.5286, preview=Intent: how to check who is currently logged in to the switch Context: show system users Target command: show system users
# [RAG] 3. source=train.jsonl, score=0.3336, preview=Intent: Show users currently editing configuration Context: status Target command: status
# [RAG] 4. source=train.jsonl, score=0.2687, preview=Intent: which users are currently locked out Context: show system login lockout Target command: show system login lockout
# [RAG] 5. source=train.jsonl, score=0.1697, preview=Intent: Display information about users who have logged in to the switch Context: show log user Target command: show log user
# [RAG] query: Display information about LLDP neighbors.
# [RAG] 1. source=train.jsonl, score=0.6813, preview=Intent: Display LLDP neighbor information Context: show lldp neighbors Target command: show lldp neighbors
# [RAG] 2. source=val.jsonl, score=0.6635, preview=Intent: Show LLDP neighbor information Context: show lldp neighbors Target command: show lldp neighbors
# [RAG] 3. source=train.jsonl, score=0.3872, preview=Intent: Display the information that the switch provides in LLDP advertisements to its neighbors Context: show lldp local-information Target command: show lldp local-information
# [RAG] 4. source=train.jsonl, score=0.3803, preview=Intent: Display the local information that are advertisements to LLDP neighbors Context: show lldp local-information Target command: show lldp local-information
# [RAG] 5. source=train.jsonl, score=0.2882, preview=Intent: Display detailed LLDP information Context: show lldp detail Target command: show lldp detail
# [RAG] query: Show command-line interface settings
# [RAG] 1. source=train.jsonl, score=0.1541, preview=Intent: Help me configure RSTP protocol on interface ge-0/0/1 to connect another switch on that port on a juniper switch ex3300 using command line Context: set protocols rstp interface <interface-name
# [RAG] 2. source=ex3300.pdf, page=21, score=0.0972, preview=NOTE: In rare cases, EX3300 switches running a Junos OS release prior to Release 11.3R4 or Release 11.4R2 might experience some traffic loss or a link failure as a result of non-user-configurable sett
# [RAG] 3. source=train.jsonl, score=0.0925, preview=Intent: how to check the power consumption of an interface Context: show poe interface <interface-name> Target command: show poe interface <interface-name>
# [RAG] 4. source=train.jsonl, score=0.0911, preview=Intent: how to synchronize time to ntp server on a juniper switch using command line Context: set system ntp server <ntp-server-address> Target command: set system ntp server <ntp-server-address> comm
# [RAG] 5. source=train.jsonl, score=0.0844, preview=Intent: how to show the mac information of an interface Context: show ethernet-switching table interface <interface-name> Target command: show ethernet-switching table interface <interface-name>
# [RAG] query: Override existing configuration with factory default
# [RAG] 1. source=val.jsonl, score=0.5240, preview=Intent: load the factory default configuration Context: load factory-default Target command: load factory-default commit
# [RAG] 2. source=ex3300.pdf, page=122, score=0.3260, preview=This topic describes the CLI procedure. NOTE: To run the ezsetup script, the switch must have the factory-default configuration as the active configuration. If you have configured anything on the swit
# [RAG] 3. source=ex3300.pdf, page=116, score=0.2986, preview=Configuring Junos OS on the EX3300 IN THIS SECTION EX3300 Switch Default Configuration | 116 Connecting and Configuring an EX Series Switch (CLI Procedure) | 121 Connecting and Configuring an EX Serie
# [RAG] 4. source=train.jsonl, score=0.2158, preview=Intent: remove all data files and user-created files and sets the switch to the factory default configuration Context: request system zeroize Target command: request system zeroize
# [RAG] 5. source=ex3300.pdf, page=127, score=0.1382, preview=To connect and configure the switch by using the J-Web interface: 1. Transition the switch into initial setup mode: • EX2200 and EX2200-C switch—Press the mode button located on the lower right corner
# [RAG] query: Clear all MAC address entries in the ethernet switching table
# [RAG] 1. source=train.jsonl, score=0.5547, preview=Intent: How to find the interface to which a specific MAC address is connected Context: show ethernet-switching table | match <mac-address> Target command: show ethernet-switching table |match <mac-ad
# [RAG] 2. source=train.jsonl, score=0.5321, preview=Intent: display MAC address information of the switch ports Context: show ethernet-switching table Target command: show ethernet-switching table
# [RAG] 3. source=train.jsonl, score=0.5142, preview=Intent: show the ethernet switching table Context: show ethernet-switching table Target command: show ethernet-switching table
# [RAG] 4. source=train.jsonl, score=0.5117, preview=Intent: How to find the interface to which a device is connected Context: show ethernet-switching table | match <mac-address> Target command: show ethernet-switching table |match <mac-address>
# [RAG] 5. source=train.jsonl, score=0.5072, preview=Intent: display the ethernet switching table Context: show ethernet-switching table Target command: show ethernet-switching table
# [RAG] query: enable the virtual chassis preprovisioned mode
# [RAG] 1. source=train.jsonl, score=0.5907, preview=Intent: set the virtual-chassis to only accept preprovisioned members Context: set virtual-chassis preprovisioned Target command: set virtual-chassis preprovisioned commit
# [RAG] 2. source=train.jsonl, score=0.2624, preview=Intent: How to configure preprovisioned virtual-chassis for ex3300 switches Context: set virtual-chassis preprovisioned set virtual-chassis member <member-id> serial-number <serial-number> role routin
# [RAG] 3. source=train.jsonl, score=0.2309, preview=Intent: Enable all traceoptions for virtual chassis Context: set virtual-chassis traceoptions flag all Target command: set virtual-chassis traceoptions flag all commit
# [RAG] 4. source=train.jsonl, score=0.2120, preview=Intent: Enable virtual chassis fast failover on XE VC uplink ports Context: set virtual-chassis fast-failover xe Target command: set virtual-chassis fast-failover xe commit
# [RAG] 5. source=train.jsonl, score=0.2079, preview=Intent: Display the virtual chassis configurations Context: show configuration virtual-chassis Target command: show configuration virtual-chassis
# [RAG] query: Set RSTP taceoptions to trace all failure conditions
# [RAG] 1. source=train.jsonl, score=0.3542, preview=Intent: Set RSTP taceoptions to trace all operations Context: set protocols rstp traceoptions flag all Target command: set protocols rstp traceoptions flag all commit
# [RAG] 2. source=train.jsonl, score=0.2683, preview=Intent: Disable RSTP all failure conditions taceoption Context: set protocols rstp traceoptions flag all-failures disable Target command: set protocols rstp traceoptions flag all-failures disable comm
# [RAG] 3. source=train.jsonl, score=0.2676, preview=Intent: Set RSTP taceoptions to trace BPDU reception and transmission Context: set protocols rstp traceoptions flag bpdu Target command: set protocols rstp traceoptions flag bpdu commit
# [RAG] 4. source=train.jsonl, score=0.2663, preview=Intent: Set RSTP taceoptions to trace protocol timers Context: set protocols rstp traceoptions flag timers Target command: set protocols rstp traceoptions flag timers commit
# [RAG] 5. source=val.jsonl, score=0.2504, preview=Intent: Set RSTP taceoptions to trace state and events for ppmd process Context: set protocols rstp traceoptions flag ppmd Target command: set protocols rstp traceoptions flag ppmd commit
# [RAG] query: Notify the user Sami when kernel errors of any severity occur
# [RAG] 1. source=train.jsonl, score=0.4928, preview=Intent: Notify the user Sami about NTP protocol actions and errors of any severity occur Context: set system syslog user <user-name> ntp any Target command: set system syslog user Sami ntp any commit
# [RAG] 2. source=train.jsonl, score=0.4890, preview=Intent: Notify all users when kernel errors of any severity occur Context: set system syslog user * kernel any Target command: set system syslog user * kernel any commit
# [RAG] 3. source=train.jsonl, score=0.3334, preview=Intent: Notify the user Alaa when user space actions and errors of any severity occur Context: set system syslog user <user-name> user any Target command: set system syslog user alaa user any commit
# [RAG] 4. source=val.jsonl, score=0.3173, preview=Intent: Notify the user Omar when system actions and errors of any severity occur Context: set system syslog user <user-name> daemon any Target command: set system syslog user omar daemon any commit
# [RAG] 5. source=train.jsonl, score=0.2920, preview=Intent: Log out all sessions owned by user sami Context: request system logout user <user-name> all Target command: request system logout user sami all
# [RAG] query: set the IGMP protocol traceoptions to trace normal events
# [RAG] 1. source=val.jsonl, score=0.4472, preview=Intent: Set IGMP snooping taceoptions to trace normal events Context: set protocols igmp-snooping traceoptions flag normal Target command: set protocols igmp-snooping traceoptions flag normal commit
# [RAG] 2. source=train.jsonl, score=0.4400, preview=Intent: set the IGMP protocol traceoptions to trace all events Context: set protocols igmp traceoptions flag all Target command: set protocols igmp traceoptions flag all commit
# [RAG] 3. source=train.jsonl, score=0.3714, preview=Intent: Disable IGMP protocol normal events traceoptions Context: set protocols igmp traceoptions flag normal disable Target command: set protocols igmp traceoptions flag normal disable commit
# [RAG] 4. source=train.jsonl, score=0.3425, preview=Intent: set the IGMP protocol traceoptions to trace routing information Context: set protocols igmp traceoptions flag route Target command: set protocols igmp traceoptions flag route commit
# [RAG] 5. source=val.jsonl, score=0.3342, preview=Intent: set the IGMP protocol traceoptions to trace all IGMP packets Context: set protocols igmp traceoptions flag packets Target command: set protocols igmp traceoptions flag packets commit
# [RAG] query: Show any pending halt or reboot requests
# [RAG] 1. source=val.jsonl, score=0.7190, preview=Intent: check if there is any pending halt or reboot requests Context: show system reboot Target command: show system reboot
# [RAG] 2. source=train.jsonl, score=0.5540, preview=Intent: Show pending halt requests Context: show system reboot Target command: show system reboot
# [RAG] 3. source=train.jsonl, score=0.4926, preview=Intent: Show pending reboot requests Context: show system reboot Target command: show system reboot
# [RAG] 4. source=train.jsonl, score=0.2171, preview=Intent: How to halt the EX3300 switch Context: request system halt Target command: request system halt
# [RAG] 5. source=val.jsonl, score=0.1996, preview=Intent: Reboot the switch Context: request system reboot Target command: request system reboot
# [RAG] query: show 2 records of POE telemetry of all interfaces
# [RAG] 1. source=train.jsonl, score=0.3712, preview=Intent: show all records of poe telemetry of interface ge-0/0/1 Context: show poe telemetries interface <interface-name> count all Target command: show poe telemetries interface ge-0/0/1 count all
# [RAG] 2. source=train.jsonl, score=0.3529, preview=Intent: how to display all records of poe telemetry of a specific interface Context: show poe telemetries interface <interface-name> count all Target command: show poe telemetries interface <interface
# [RAG] 3. source=train.jsonl, score=0.3419, preview=Intent: how to display a specific number of POE telemetry records of an interfaces Context: show poe telemetries interface <interface-name> count <num-of-records> Target command: show poe telemetries
# [RAG] 4. source=val.jsonl, score=0.3126, preview=Intent: enable poe telemetry on all interfaces Context: set poe interface all telemetries interval <interval> Target command: set poe interface all telemetries interval <interval> commit
# [RAG] 5. source=train.jsonl, score=0.1396, preview=Intent: show the power consumption of all interfaces Context: show poe interface Target command: show poe interface
# [RAG] query: remove the configured ntp server
# [RAG] 1. source=train.jsonl, score=0.6888, preview=Intent: delete the configured ntp server Context: delete system ntp server <ntp-server-address> Target command: delete system ntp server <ntp-server-address> commit
# [RAG] 2. source=train.jsonl, score=0.6375, preview=Intent: set ntp server address to 10.200.1.90 and add the following comment "configured ntp server" to the commit Context: set system ntp server <ntp-server-address> commit comment <"string-comment">
# [RAG] 3. source=train.jsonl, score=0.5880, preview=Intent: how to synchronize time to ntp server on a juniper switch using command line Context: set system ntp server <ntp-server-address> Target command: set system ntp server <ntp-server-address> comm
# [RAG] 4. source=train.jsonl, score=0.5071, preview=Intent: set ntp server address to 10.200.1.90 and add the following comment "added ntp server" to the commit Context: set system ntp server <ntp-server-address> commit comment <"string-comment"> Targe
# [RAG] 5. source=train.jsonl, score=0.5048, preview=Intent: make the switch synchronize its time with the ntp server 192.168.1.100 Context: set system ntp server <ntp-server-address> Target command: set system ntp server 192.168.1.100 commit
# [transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Batches:  20% 1/5 [00:07<00:28,  7.09s/it][RAG] query: how to set the sflow collector IP address and port number
# [RAG] 1. source=train.jsonl, score=0.4424, preview=Intent: Show sFlow collectors Context: show sflow collector Target command: show sflow collector
# [RAG] 2. source=train.jsonl, score=0.4401, preview=Intent: set the sflow collector IP to 10.200.1.201 and use udp port 5800 Context: set protocols sflow collector <collector-IP> udp-port <udp-port> Target command: set protocols sflow collector 10.200.
# [RAG] 3. source=train.jsonl, score=0.4289, preview=Intent: set the sflow collector IP to 10.20.11.21 and use udp port 5800 Context: set protocols sflow collector <collector-IP> udp-port <udp-port> Target command: set protocols sflow collector 10.20.11
# [RAG] 4. source=train.jsonl, score=0.3939, preview=Intent: Display the configured sFlow collectors and their properties Context: show sflow collector Target command: show sflow collector
# [RAG] 5. source=train.jsonl, score=0.2944, preview=Intent: how to configure the source IP address used for the sFlow datagrams Context: set protocols sflow source-ip <ip-address> Target command: set protocols sflow source-ip <ip-address> commit
# [RAG] query: Display the PIC mode for all members of the Virtual Chassis configuration
# [RAG] 1. source=val.jsonl, score=0.6210, preview=Intent: Show all members' chassis pic-mode Context: show chassis pic-mode all-members Target command: show chassis pic-mode all-members
# [RAG] 2. source=train.jsonl, score=0.5018, preview=Intent: Display the PIC mode of member 1 of the Virtual Chassis configuration Context: show chassis pic-mode member <member-id> Target command: show chassis pic-mode member 1
# [RAG] 3. source=train.jsonl, score=0.4679, preview=Intent: How to display the PIC mode of a specific member of the Virtual Chassis configuration Context: show chassis pic-mode member <member-id> Target command: show chassis pic-mode member <member-id>
# [RAG] 4. source=train.jsonl, score=0.3544, preview=Intent: Show member 0 chassis pic-mode Context: show chassis pic-mode member <member-id> Target command: show chassis pic-mode member 0
# [RAG] 5. source=train.jsonl, score=0.2506, preview=Intent: Display the virtual chassis configurations Context: show configuration virtual-chassis Target command: show configuration virtual-chassis
# [RAG] query: Show autonomous-system domains
# [RAG] 1. source=train.jsonl, score=0.2787, preview=Intent: Show known autonomous system paths Context: show as-path Target command: show as-path
# [RAG] query: set the aging timer of the mac table entries to 500 second
# [RAG] 1. source=train.jsonl, score=0.5444, preview=Intent: set the MAC table aging timer to 500 second Context: set ethernet-switching-options mac-table-aging-time <interval> Target command: set ethernet-switching-options mac-table-aging-time 500 comm
# [RAG] 2. source=train.jsonl, score=0.4030, preview=Intent: set the MAC table aging timer to 400 second Context: set ethernet-switching-options mac-table-aging-time <interval> Target command: set ethernet-switching-options mac-table-aging-time 400 comm
# [RAG] 3. source=train.jsonl, score=0.3955, preview=Intent: how to set the MAC table aging timer Context: set ethernet-switching-options mac-table-aging-time <interval> Target command: set ethernet-switching-options mac-table-aging-time <interval> comm
# [RAG] 4. source=train.jsonl, score=0.3573, preview=Intent: set the MAC table aging timer to unlimited Context: set ethernet-switching-options mac-table-aging-time unlimited Target command: set ethernet-switching-options mac-table-aging-time unlimited
# [RAG] 5. source=train.jsonl, score=0.2769, preview=Intent: Disable MAC-aging for the entire switch Context: set ethernet-switching-options mac-table-aging-time unlimited Target command: set ethernet-switching-options mac-table-aging-time unlimited com
# [RAG] query: how to configure persistent mac learning on an interface
# [RAG] 1. source=train.jsonl, score=0.5284, preview=Intent: enable persistent mac learning on interface ge-0/0/9 Context: set ethernet-switching-options secure-access-port interface <interface-name> persistent-learning Target command: set ethernet-swit
# [RAG] 2. source=val.jsonl, score=0.5284, preview=Intent: Enable persistent mac learning on interface ge-0/0/0 Context: set ethernet-switching-options secure-access-port interface <interface-name> persistent-learning Target command: set ethernet-swit
# [RAG] 3. source=val.jsonl, score=0.5038, preview=Intent: delete the persistent mac learning on interface ge-0/0/9 Context: delete ethernet-switching-options secure-access-port interface <interface-name> persistent-learning Target command: delete eth
# [RAG] 4. source=val.jsonl, score=0.4768, preview=Intent: remove the persistent mac learning on interface ge-0/0/19 Context: delete ethernet-switching-options secure-access-port interface <interface-name> persistent-learning Target command: delete et
# [RAG] 5. source=train.jsonl, score=0.4009, preview=Intent: Show MAC learning statistics Context: show ethernet-switching statistics mac-learning Target command: show ethernet-switching statistics mac-learning
# [RAG] query: make the interface range DIV-RANGE member of vlan DATA
# [RAG] 1. source=val.jsonl, score=0.5056, preview=Intent: Define an interface range named DATA-RANGE that consists of the interfaces ge-0/0/0 to ge-0/0/25 Context: set interfaces interface-range <range-name> member-range <interface-name> to <interfac
# [RAG] 2. source=train.jsonl, score=0.4800, preview=Intent: Define an interface range named DATA-RANGE that consists of the following interfaces ge-0/0/0 to ge-0/0/25 and set the port mode of the range to access Context: set interfaces interface-range
# [RAG] 3. source=val.jsonl, score=0.4654, preview=Intent: how to make an interface range a member of a vlan Context: set interfaces interface-range <range-name> unit <unit-number> family ethernet-switching vlan members <valn-name-or-id> Target comman
# [RAG] 4. source=train.jsonl, score=0.4497, preview=Intent: Delete the interface range named DATA-RANGE Context: delete interfaces interface-range <range-name> Target command: delete interfaces interface-range DATA-RANGE commit
# [RAG] 5. source=train.jsonl, score=0.4276, preview=Intent: Assign the interface range WIRELESS-RANGE member of vlan 150 Context: set interfaces interface-range <range-name> unit <unit-number> family ethernet-switching vlan members <valn-name-or-id> Ta
# [RAG] query: Disable IGMP protocol mtrace packets traceoptions
# [RAG] 1. source=train.jsonl, score=0.5068, preview=Intent: set the IGMP protocol traceoptions to trace mtrace packets Context: set protocols igmp traceoptions flag mtrace Target command: set protocols igmp traceoptions flag mtrace commit
# [RAG] 2. source=train.jsonl, score=0.4575, preview=Intent: Disable IGMP protocol all IGMP packets traceoptions Context: set protocols igmp traceoptions flag packets disable Target command: set protocols igmp traceoptions flag packets disable commit
# [RAG] 3. source=val.jsonl, score=0.3108, preview=Intent: set the IGMP protocol traceoptions to trace all IGMP packets Context: set protocols igmp traceoptions flag packets Target command: set protocols igmp traceoptions flag packets commit
# [RAG] 4. source=val.jsonl, score=0.2979, preview=Intent: Disable all IGMP protocol traceoptions Context: set protocols igmp traceoptions flag all disable Target command: set protocols igmp traceoptions flag all disable commit
# [RAG] 5. source=train.jsonl, score=0.2832, preview=Intent: disable all IGMP snooping packets taceoption Context: set protocols igmp-snooping traceoptions flag packets disable Target command: set protocols igmp-snooping traceoptions flag packets disabl
# [RAG] query: How to configure RSTP protocol on interface ge-1/0/5 to connect another switch on that port on a juniper switch ex3300 using command line
# [RAG] 1. source=train.jsonl, score=0.6106, preview=Intent: Help me configure RSTP protocol on interface ge-0/0/1 to connect another switch on that port on a juniper switch ex3300 using command line Context: set protocols rstp interface <interface-name
# [RAG] 2. source=ex3300.pdf, page=85, score=0.2698, preview=Installing and Connecting an EX3300 Switch To install and connect an EX3300 switch: 1. Follow instructions in “Unpacking an EX3300 Switch” on page 82. 2. Mount the switch by following instructions app
# [RAG] 3. source=ex3300.pdf, page=5, score=0.2654, preview=EX3300 Management Cable Specifications and Pinouts | 68 Management Cable Specifications | 68 Console Port Connector Pinout Information | 69 USB Port Specifications for an EX Series Switch | 70 RJ-45 M
# [RAG] 4. source=ex3300.pdf, page=145, score=0.2621, preview=Table 41: Chassis Viewer for EX2200-C Switches (continued) DescriptionField In the image, the following colors denote the interface status: • Green—Interface is up and operational. • Yellow—Interface
# ...
# [RAG] 2. source=train.jsonl, score=0.2337, preview=Intent: create a new vlan with the name FIN and vlan-id 11 Context: set vlans <vlan-name> vlan-id <vlan-id-number> Target command: set vlans FIN vlan-id 11 commit
# [RAG] 3. source=val.jsonl, score=0.1751, preview=Intent: how to make an interface range a member of a vlan Context: set interfaces interface-range <range-name> unit <unit-number> family ethernet-switching vlan members <valn-name-or-id> Target comman
# [RAG] 4. source=train.jsonl, score=0.1353, preview=Intent: make port ge-0/0/7 carry traffic from vlans HR, FIN, and MGMT Context: set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode trunk vlan members <vlan-name-or-i
# [RAG] 5. source=train.jsonl, score=0.1308, preview=Intent: show the power consumption of interface ge-0/0/10 Context: show poe interface <interface-name> Target command: show poe interface ge-0/0/10
# [RAG] query: Disable RSTP root-protect feature on interface ge-0/0/42
# [RAG] 1. source=train.jsonl, score=0.5203, preview=Intent: set the RSTP root-protect feature on interface ge-0/0/23 Context: set protocols rstp interface <interface-name> no-root-port Target command: set protocols rstp interface ge-0/0/23 no-root-port
# [RAG] 2. source=train.jsonl, score=0.5194, preview=Intent: Enable RSTP root-protect feature on interface ge-0/0/13 Context: set protocols rstp interface <interface-name> no-root-port Target command: set protocols rstp interface ge-0/0/13 no-root-port
# [RAG] 3. source=train.jsonl, score=0.5063, preview=Intent: how to set the RSTP root-protect feature on interface Context: set protocols rstp interface <interface-name> no-root-port Target command: set protocols rstp interface <interface-name> no-root-
# [RAG] 4. source=train.jsonl, score=0.4136, preview=Intent: how to delete RSTP root-protect feature on a specific interface Context: delete protocols rstp interface <interface-name> no-root-port Target command: delete protocols rstp interface <interfac
# [RAG] 5. source=train.jsonl, score=0.3049, preview=Intent: Disable RSTP protocol on interface ge-0/0/0 Context: set protocols rstp interface <interface-name> disable Target command: set protocols rstp interface ge-0/0/0 disable commit
# [RAG] query: how to enable an interface to carry traffic from multiple vlans
# [RAG] 1. source=train.jsonl, score=0.3407, preview=Intent: how to allow an interface to carry traffic from multiple vlans Context: set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode trunk Target command: set interfa
# [RAG] 2. source=train.jsonl, score=0.2957, preview=Intent: allow port ge-0/0/6 to carry traffic from multiple vlans Context: set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode trunk Target command: set interfaces ge
# [RAG] 3. source=train.jsonl, score=0.2889, preview=Intent: enable the port ge-0/0/16 to carry traffic from multiple vlans Context: set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode trunk Target command: set interfa
# [RAG] 4. source=train.jsonl, score=0.1941, preview=Intent: How to make an interface carry traffic from all vlans Context: set interfaces <interface-name> unit <unit-number> family ethernet-switching port-mode trunk vlan members all Target command: set
# [RAG] 5. source=train.jsonl, score=0.1682, preview=Intent: enable interface ge-1/0/3 Context: delete interfaces <interface-name> disable Target command: delete interfaces ge-1/0/3 disable commit
# [RAG] query: disable the virtual chassis fast failover for XE VC uplink ports
# [RAG] 1. source=train.jsonl, score=0.8139, preview=Intent: Enable virtual chassis fast failover on XE VC uplink ports Context: set virtual-chassis fast-failover xe Target command: set virtual-chassis fast-failover xe commit
# [RAG] 2. source=train.jsonl, score=0.8077, preview=Intent: set the Fast failover for XE VC uplink ports Context: set virtual-chassis fast-failover xe Target command: set virtual-chassis fast-failover xe commit
# [RAG] 3. source=train.jsonl, score=0.7628, preview=Intent: delete the virtual chassis fast failover for XE VC uplink ports Context: delete virtual-chassis fast-failover xe Target command: delete virtual-chassis fast-failover xe commit
# [RAG] 4. source=val.jsonl, score=0.5953, preview=Intent: disable the virtual chassis Fast failover for GE VC uplink ports Context: delete virtual-chassis fast-failover ge Target command: delete virtual-chassis fast-failover ge commit
# [RAG] 5. source=train.jsonl, score=0.5716, preview=Intent: set the virtual chassis Fast failover for GE VC uplink ports Context: set virtual-chassis fast-failover ge Target command: set virtual-chassis fast-failover ge commit
# [RAG] query: automatically enable interfaces blocked due to receiving a bpdu after 200 seconds
# [RAG] 1. source=train.jsonl, score=0.2014, preview=Intent: set the disable timeout of the interfaces blocked due to receving a bpdu to 300 seconds Context: set ethernet-switching-options bpdu-block disable-timeout <timeout-interval-second> Target comm
# [RAG] 2. source=train.jsonl, score=0.1476, preview=Intent: restore the interfaces blocked due to storm control violation Context: clear ethernet-switching port-error Target command: clear ethernet-switching port-error
# [RAG] 3. source=train.jsonl, score=0.1368, preview=Intent: Change the IP 10.200.1.1 to 10.200.2.1 Context: replace pattern <pattern_regular_expression> with <new_value> Target command: replace pattern 10.200.1.1 with 10.200.2.1 commit
# [RAG] 4. source=train.jsonl, score=0.1270, preview=Intent: Set RSTP taceoptions to trace BPDU reception and transmission Context: set protocols rstp traceoptions flag bpdu Target command: set protocols rstp traceoptions flag bpdu commit
# [RAG] 5. source=train.jsonl, score=0.1251, preview=Intent: clear bpdu errors Context: clear ethernet-switching bpdu-error Target command: clear ethernet-switching bpdu-error
# [RAG] query: Find the interface to which the MAC address ac:b9:2f:2f:81:26 is connected
# [RAG] 1. source=train.jsonl, score=0.3904, preview=Intent: How to find the interface to which a specific MAC address is connected Context: show ethernet-switching table | match <mac-address> Target command: show ethernet-switching table |match <mac-ad
# [RAG] 2. source=train.jsonl, score=0.3140, preview=Intent: How to find the interface to which a device is connected Context: show ethernet-switching table | match <mac-address> Target command: show ethernet-switching table |match <mac-address>
# [RAG] 3. source=train.jsonl, score=0.2767, preview=Intent: how to set a list of allowed Mac addresses on a specific interface Context: set ethernet-switching-options secure-access-port interface interface-name allowed-mac <mac-address> Target command:
# [RAG] 4. source=train.jsonl, score=0.2343, preview=Intent: how to set a mac limit on an interface Context: set ethernet-switching-options secure-access-port interface <interface-name> mac-limit <mac-limit> Target command: set ethernet-switching-option
# [RAG] 5. source=train.jsonl, score=0.2328, preview=Intent: Limit the number of connected devices to one on each interface on the EX3300 switch Context: set ethernet-switching-options secure-access-port interface all mac-limit <mac-limit> commit Target
# [RAG] query: Disable IGMP protocol general events traceoptions
# [RAG] 1. source=train.jsonl, score=0.3994, preview=Intent: disable IGMP snooping general events taceoptions Context: set protocols igmp-snooping traceoptions flag general disable Target command: set protocols igmp-snooping traceoptions flag general di
# [RAG] 2. source=train.jsonl, score=0.3719, preview=Intent: Disable IGMP protocol normal events traceoptions Context: set protocols igmp traceoptions flag normal disable Target command: set protocols igmp traceoptions flag normal disable commit
# [RAG] 3. source=val.jsonl, score=0.3398, preview=Intent: Set IGMP snooping taceoptions to trace general events Context: set protocols igmp-snooping traceoptions flag general Target command: set protocols igmp-snooping traceoptions flag general commi
# [RAG] 4. source=val.jsonl, score=0.3225, preview=Intent: Disable all IGMP protocol traceoptions Context: set protocols igmp traceoptions flag all disable Target command: set protocols igmp traceoptions flag all disable commit
# [RAG] 5. source=train.jsonl, score=0.2715, preview=Intent: Disable IGMP protocol all IGMP packets traceoptions Context: set protocols igmp traceoptions flag packets disable Target command: set protocols igmp traceoptions flag packets disable commit
# [RAG] query: set the IGMP protocol traceoptions to trace state transitions
# [RAG] 1. source=train.jsonl, score=0.4319, preview=Intent: Set IGMP snooping taceoptions to trace state transitions Context: set protocols igmp-snooping traceoptions flag state Target command: set protocols igmp-snooping traceoptions flag state commit
# [RAG] 2. source=train.jsonl, score=0.4046, preview=Intent: set the IGMP protocol traceoptions to trace all events Context: set protocols igmp traceoptions flag all Target command: set protocols igmp traceoptions flag all commit
# [RAG] 3. source=train.jsonl, score=0.3759, preview=Intent: Disable IGMP protocol state transitions traceoptions Context: set protocols igmp traceoptions flag state disable Target command: set protocols igmp traceoptions flag state disable commit
# [RAG] 4. source=train.jsonl, score=0.3457, preview=Intent: set the IGMP protocol traceoptions to trace routing information Context: set protocols igmp traceoptions flag route Target command: set protocols igmp traceoptions flag route commit
# [RAG] 5. source=val.jsonl, score=0.3372, preview=Intent: set the IGMP protocol traceoptions to trace all IGMP packets Context: set protocols igmp traceoptions flag packets Target command: set protocols igmp traceoptions flag packets commit
# [RAG] query: disable the SNMP system warm and cold starts trap for the trap-group MONITOR-GROUP-1
# [RAG] 1. source=val.jsonl, score=0.7113, preview=Intent: Enable the SNMP system warm and cold starts trap for the trap-group MONITOR-GROUP-1 Context: set snmp trap-group <trap-group-name> categories startup Target command: set snmp trap-group MONITO
# [RAG] 2. source=train.jsonl, score=0.6832, preview=Intent: delete the SNMP system warm and cold starts trap for the trap-group MONITOR-GROUP-1 Context: delete snmp trap-group <trap-group-name> categories startup Target command: delete snmp trap-group
# [RAG] 3. source=train.jsonl, score=0.6355, preview=Intent: set the SNMP system warm and cold starts notifications for the trap-group MONITOR-GROUP Context: set snmp trap-group <trap-group-name> categories startup Target command: set snmp trap-group MO
# [RAG] 4. source=train.jsonl, score=0.5066, preview=Intent: Disable SNMP services notifications trap for the trap-group MONITOR-GROUP-v2 Context: delete snmp trap-group <trap-group-name> categories services Target command: delete snmp trap-group MONITO
# [RAG] 5. source=train.jsonl, score=0.5001, preview=Intent: set the SNMP routing protocol notifications trap for the trap-group MONITOR-GROUP Context: set snmp trap-group <trap-group-name> categories routing Target command: set snmp trap-group MONITOR-
# [RAG] query: Enable Fast failover on XE VC uplink ports
# [RAG] 1. source=train.jsonl, score=0.7155, preview=Intent: set the Fast failover for XE VC uplink ports Context: set virtual-chassis fast-failover xe Target command: set virtual-chassis fast-failover xe commit
# [RAG] 2. source=train.jsonl, score=0.6867, preview=Intent: Enable virtual chassis fast failover on XE VC uplink ports Context: set virtual-chassis fast-failover xe Target command: set virtual-chassis fast-failover xe commit
# [RAG] 3. source=train.jsonl, score=0.6286, preview=Intent: delete the virtual chassis fast failover for XE VC uplink ports Context: delete virtual-chassis fast-failover xe Target command: delete virtual-chassis fast-failover xe commit
# [RAG] 4. source=train.jsonl, score=0.5119, preview=Intent: Enable Fast failover on GE VC uplink ports Context: set virtual-chassis fast-failover ge Target command: set virtual-chassis fast-failover ge commit
# [RAG] 5. source=val.jsonl, score=0.4948, preview=Intent: Enable Fast failover on ET VC uplink ports Context: set virtual-chassis fast-failover et Target command: set virtual-chassis fast-failover et commit
# [RAG] query: compare the candidate configuration to the active configuration
# [RAG] 1. source=train.jsonl, score=0.3884, preview=Intent: compare the candidate configuration to rollback 5 Context: show | compare rollback <rollback-number> Target command: show | compare rollback 5
# [RAG] 2. source=train.jsonl, score=0.2094, preview=Intent: Display the candidate configuration in the set format Context: show | display set Target command: show | display set
# [RAG] 3. source=train.jsonl, score=0.1857, preview=Intent: compare the configuration in rollback 9 to the configuration in rollback 7 Context: show system rollback <rollback-number> compare <rollback-number> Target command: show system rollback 9 comp
# [RAG] 4. source=train.jsonl, score=0.1652, preview=Intent: compare the configuration in rollback 7 to rollback 6 Context: show system rollback <rollback-number> compare <rollback-number> Target command: show system rollback 7 compare 6
# [RAG] 5. source=ex3300.pdf, page=122, score=0.1608, preview=This topic describes the CLI procedure. NOTE: To run the ezsetup script, the switch must have the factory-default configuration as the active configuration. If you have configured anything on the swit
# [RAG] query: set the voip feature on port ge-0/0/11 given the voice vlan is VOICE
# [RAG] 1. source=train.jsonl, score=0.2873, preview=Intent: how to set the voip feature for an interface Context: set ethernet-switching-options voip interface <interface-name> vlan <vlan-name> Target command: set ethernet-switching-options voip interf
# [RAG] 2. source=val.jsonl, score=0.2454, preview=Intent: set up the configuration required on port ge-0/0/10 to connect it to a IP phone Context: set interfaces <interface-name> unit 0 family ethernet-switching vlan members <vlan-name> set interface
# [RAG] 3. source=train.jsonl, score=0.1635, preview=Intent: set a mac limit of 1 on interface ge-0/0/11 and shutdown the interface if a violation occur Context: set ethernet-switching-options secure-access-port interface ge-0/0/11 mac-limit <limit> act
# [RAG] 4. source=train.jsonl, score=0.1550, preview=Intent: allow the assignment of static ip address on ge-0/0/11 Context: set ethernet-switching-options secure-access-port interface <interface-name> dhcp-trusted Target command: set ethernet-switching
# [RAG] 5. source=train.jsonl, score=0.1534, preview=Intent: enable the assignment of static ip address on ge-1/0/11 Context: set ethernet-switching-options secure-access-port interface <interface-name> dhcp-trusted Target command: set ethernet-switchin
# [transformers] Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [transformers] Both `max_new_tokens` (=64) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Batches: 100% 5/5 [00:31<00:00,  6.21s/it]
# [RAG] retrieved chunk counts:
# [RAG]   ex3300.pdf: 35
# [RAG]   train.jsonl: 596
# [RAG]   val.jsonl: 115
# {
#   "overall": {
#     "exact_match": 0.18,
#     "normalized_exact_match": 0.64,
#     "token_f1": 0.8611981955504344,
#     "bleu": 0.7525069742715248,
#     "valid_rate": 0.18,
#     "entity_preservation": 0.9666666666666667,
#     "invalid_output_rate": 0.8200000000000001
#   },
#   "per_category": {
#     "": {
#       "exact_match": 0.18,
#       "normalized_exact_match": 0.64,
#       "token_f1": 0.8611981955504344,
#       "bleu": 0.7525069742715248,
#       "valid_rate": 0.18,
#       "entity_preservation": 0.9666666666666667,
#       "invalid_output_rate": 0.8200000000000001
#     }
#   }
# }

# %% [markdown]
# ## 12. Save Results to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/slm-kdn-results
# !cp -r results /content/drive/MyDrive/slm-kdn-results/results-rag-$(date +%Y%m%d-%H%M%S)
# !ls -lh /content/drive/MyDrive/slm-kdn-results
# Out:
# Mounted at /content/drive
# total 8.0K
# drwx------ 2 root root 4.0K May 11 18:43 results-rag-20260511-184340
# drwx------ 5 root root 4.0K May 11 19:17 results-rag-20260511-191756
